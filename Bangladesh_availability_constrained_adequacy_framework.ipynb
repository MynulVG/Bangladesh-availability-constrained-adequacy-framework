# %% [markdown]
# # Availability-constrained dispatch reconstruction of the 2022–2024 Bangladesh power crisis
#
# **Complete reproduction notebook.** Every table, figure and reported number in
# the manuscript and supplementary material is produced here, in manuscript order.
#
# Inputs: `generation_data.csv`, `base_network.nc`.
# Outputs: `outputs/tables/*.csv`, `outputs/figures/*.{tiff,pdf}`.
#
# ---
#
# ### Structure
#
# | Section | Content |
# |---|---|
# | 1 | Data, integrity, anomaly screen |
# | 2 | Operational regimes, effect sizes, changepoint |
# | 3 | Network, closed-form reduction **(gate)** |
# | 4 | Idle capacity and robustness to the capacity assumption |
# | 5 | Transmission across all crisis months |
# | 6 | Seasonality |
# | 7 | Payra event study (difference-in-differences) |
# | 8 | Reliability metrics |
# | 9 | Reconstruction fidelity and the model boundary |
# | 10 | Ablation |
# | 11 | Out-of-sample validation with null models |
# | 12 | Interventions, Monte Carlo, capacity sweep, reserve margin |
# | 13 | Storage |
# | 14 | Sensitivity analysis |
# | 15 | Figures 3–14 |
# | 16 | **Alignment checklist** — every number, printed from this run |
#
# ### Runtime
#
# ≈ 35–55 min end to end on Colab. The Morris screening (510 LPs) and the
# 35-month transmission sweep (105 LPs) dominate; both are gated in the config
# cell below.

# %% [markdown]
# ## 0. Configuration and setup

# %%
# ---- gates for the slow sections -------------------------------------------
RUN_GSA          = True    # Morris screening, 510 LPs, ~15 min
RUN_TRANSMISSION = True    # 35-month corridor sweep, 105 LPs, ~4 min
RUN_SWEEP        = True    # capacity-level sweep, 48 LPs, ~2 min
MORRIS_N         = 30      # 30 -> 510 evaluations, as in the manuscript
BOOTSTRAP_B      = 2000    # PCA loading stability and changepoint CI

# ---- reproducibility --------------------------------------------------------
SEED = 42

# %%
# !pip -q install pypsa==1.2.4 highspy ruptures==1.1.10 SALib statsmodels
# !apt-get -qq install -y fonts-liberation > /dev/null 2>&1

import os, sys, copy, time, logging, warnings
from collections import Counter
logging.disable(logging.WARNING)
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import pypsa
from scipy import stats

from importlib.metadata import version
print("environment")
for m in ["pypsa","linopy","pandas","numpy","scipy","scikit-learn",
          "statsmodels","ruptures","salib","matplotlib"]:
    try:    print(f"  {m:14s} {version(m)}")
    except Exception: pass

T_START = time.time()
# Out:
# environment
#   pypsa          1.2.4
#   linopy         0.9.1
#   pandas         2.2.3
#   numpy          2.1.3
#   scipy          1.16.3
#   scikit-learn   1.6.1
#   statsmodels    0.14.6
#   ruptures       1.1.10
#   salib          1.5.2
#   matplotlib     3.10.0

# %%
from urllib.request import urlretrieve

# ---- INPUT FILES FROM GITHUB -----------------------------------------------
CSV_URL = (
    "https://raw.githubusercontent.com/"
    "MynulVG/Bangladesh-availability-constrained-adequacy-framework/"
    "main/generation_data.csv"
)

BASE_URL = (
    "https://raw.githubusercontent.com/"
    "MynulVG/Bangladesh-availability-constrained-adequacy-framework/"
    "main/base_network.nc"
)

# Local Colab paths used by the rest of the notebook
CSV_PATH = "/content/generation_data.csv"
BASE_PATH = "/content/base_network.nc"

print("Downloading input files from GitHub...")

urlretrieve(CSV_URL, CSV_PATH)
urlretrieve(BASE_URL, BASE_PATH)

# Check that valid, nonempty files were downloaded
for path in (CSV_PATH, BASE_PATH):
    assert os.path.exists(path), f"Download failed: {path}"
    assert os.path.getsize(path) > 1000, (
        f"Downloaded file appears invalid or incomplete: {path}"
    )

OUT_TAB = "/content/outputs/tables"
OUT_FIG = "/content/outputs/figures"

os.makedirs(OUT_TAB, exist_ok=True)
os.makedirs(OUT_FIG, exist_ok=True)

print("Inputs downloaded successfully:")
print(f"  {CSV_PATH} ({os.path.getsize(CSV_PATH) / 1e6:.2f} MB)")
print(f"  {BASE_PATH} ({os.path.getsize(BASE_PATH) / 1e6:.2f} MB)")

def save_table(df, name):
    path = f"{OUT_TAB}/{name}.csv"
    df.to_csv(path, index=False)
    print(f"  table -> {name}.csv")
    return path

def rule(title=""):
    print("\n" + "=" * 78)
    if title:
        print(title)
        print("=" * 78)
# Out:
# Downloading input files from GitHub...
# Inputs downloaded successfully:
#   /content/generation_data.csv (5.68 MB)
#   /content/base_network.nc (0.46 MB)

# %% [markdown]
# ## 1. Data
#
# 84,186 consecutive hourly observations, 20 April 2015 00:00 to 25 November 2024
# 17:00, compiled from BPDB and PGCB/NLDC daily generation reports.

# %%
TECHS   = ["Gas","Coal","Liquid Fuel","Import","Hydro","Solar","Wind"]
THERMAL = ["Gas","Coal","Liquid Fuel"]
DISPATCHABLE = ["Gas","Coal","Liquid Fuel","Import","Hydro"]
PERIODS = ["2016-12","2022-08","2023-06","2023-08"]

def load_data(path=CSV_PATH):
    """
    Load the record and apply two documented single-point repairs.

    2021-08-16 01:00 - demand/generation spike to 17,407 MW between neighbours
      of 12,516 and 11,530 MW. ALL columns are interpolated, aggregate and
      disaggregated: availability is calibrated from the fuel columns, and
      repairing only the aggregate leaves them summing to 17,407 MW.

    2015-06-08 14:00 - generation drops to 2,798 MW between 6,663 and 6,795 MW
      with a missing gas observation.
    """
    d = pd.read_csv(path)
    d["datetime"] = pd.to_datetime(d["Date"].astype(str)+" "+d["Time"].astype(str),
                                   format="%d.%m.%Y %H:%M:%S")
    assert d["datetime"].notna().all()
    d = d.sort_values("datetime").reset_index(drop=True)
    for c in ["Bheramara HVDC","Tripura","Adani"]:
        d[c] = pd.to_numeric(d[c], errors="coerce").fillna(0.0)
    d["Import"] = d[["Bheramara HVDC","Tripura","Adani"]].sum(axis=1)
    for c in ["Demand","Generation","Loadshed"]+TECHS:
        d[c] = pd.to_numeric(d[c], errors="coerce")

    i = d.index[d["datetime"]==pd.Timestamp("2021-08-16 01:00")][0]
    for c in ["Demand","Generation"]+TECHS:
        d.loc[i,c] = round(0.5*(d.loc[i-1,c]+d.loc[i+1,c]), 1)
    j = d.index[d["datetime"]==pd.Timestamp("2015-06-08 14:00")][0]
    for c in ["Demand","Generation","Gas"]:
        d.loc[j,c] = round(0.5*(d.loc[j-1,c]+d.loc[j+1,c]), 1)
    return d

def slice_month(ym, frame=None):
    f = df if frame is None else frame
    y,m = int(ym[:4]), int(ym[5:7])
    s = pd.Timestamp(y,m,1); e = pd.Timestamp(y+(m==12),(m%12)+1,1)
    return f[(f["datetime"]>=s)&(f["datetime"]<e)].set_index("datetime")

def crisis_months(start="2022-01", end="2024-11"):
    return [str(p) for p in pd.period_range(start, end, freq="M")]

df = load_data()
print(f"loaded {len(df):,} rows   {df['datetime'].min()} -> {df['datetime'].max()}")
# Out:
# loaded 84,186 rows   2015-04-20 00:00:00 -> 2024-11-25 17:00:00

# %% [markdown]
# ### 1.1 Integrity

# %%
lo, hi = df["datetime"].min(), df["datetime"].max()
exp = int((hi-lo).total_seconds()//3600)+1
fuels = df[["Gas","Liquid Fuel","Coal","Hydro","Solar","Wind",
            "Bheramara HVDC","Tripura","Adani"]].sum(axis=1)
eq1_resid = fuels - df["Generation"]
eq1_gap   = (df["Demand"]-fuels).clip(lower=0) - df["Loadshed"]

INTEG = dict(start=str(lo), end=str(hi), rows=len(df), expected=exp,
             missing=exp-len(df), duplicated=int(df["datetime"].duplicated().sum()),
             eq2_max=float((df["Demand"]-df["Generation"]-df["Loadshed"]).abs().max()),
             eq1_mean=round(float(eq1_resid.mean()),2),
             eq1_mean_abs=round(float(eq1_resid.abs().mean()),2),
             eq1_gap_gt1_pct=round(100*float((eq1_gap.abs()>1).mean()),1))
for k,v in INTEG.items(): print(f"  {k:16s} {v}")
assert INTEG["missing"]==0 and INTEG["duplicated"]==0

print("\nEq.2  D = G + L holds exactly.")
print("Eq.1  the disaggregated identity does NOT: the reported generation total and")
print("      the sum of the technology columns differ by a mean of "
      f"{INTEG['eq1_mean']:+.1f} MW (mean absolute {INTEG['eq1_mean_abs']:.1f} MW).")
print("      This residual is the source of the limited charging headroom in Section 13.")
# Out:
#   start            2015-04-20 00:00:00
#   end              2024-11-25 17:00:00
#   rows             84186
#   expected         84186
#   missing          0
#   duplicated       0
#   eq2_max          0.0
#   eq1_mean         7.84
#   eq1_mean_abs     17.2
#   eq1_gap_gt1_pct  15.7
#
# Eq.2  D = G + L holds exactly.
# Eq.1  the disaggregated identity does NOT: the reported generation total and
#       the sum of the technology columns differ by a mean of +7.8 MW (mean absolute 17.2 MW).
#       This residual is the source of the limited charging headroom in Section 13.

# %% [markdown]
# ### 1.2 Interpolation audit
#
# Detects runs of constant first difference, i.e. linearly interpolated stretches
# in the source reports.

# %%
def audit(series):
    s = pd.to_numeric(series, errors="coerce"); dd = s.diff()
    same  = (np.abs(dd - dd.shift(-1)) < 1e-6).fillna(False).values
    slope = (np.abs(dd.shift(-1)) > 1e-6).fillna(False).values
    ramp = same & slope
    runs, cur = [], 0
    for v in ramp:
        if v: cur += 1
        else:
            if cur > 0: runs.append(cur+1)
            cur = 0
    if cur > 0: runs.append(cur+1)
    runs = np.array(runs) if runs else np.array([0])
    return round(100*runs[runs>=3].sum()/int(s.notna().sum()), 2)

print("Interpolated share (% of hours):")
for c in ["Demand","Gas","Coal","Liquid Fuel","Hydro","Bheramara HVDC","Tripura","Adani"]:
    print(f"  {c:16s} {audit(df[c]):.2f}%")
print("\nModelled months, non-integer share of Demand:")
for ym in PERIODS:
    m = slice_month(ym)
    print(f"  {ym}: {(m['Demand']%1!=0).mean()*100:.2f}%  ({len(m)} hours)")
# Out:
# Interpolated share (% of hours):
#   Demand           0.88%
#   Gas              0.86%
#   Coal             1.73%
#   Liquid Fuel      0.98%
#   Hydro            2.70%
#   Bheramara HVDC   1.03%
#   Tripura          3.84%
#   Adani            0.02%
#
# Modelled months, non-integer share of Demand:
#   2016-12: 0.00%  (744 hours)
#   2022-08: 0.00%  (744 hours)
#   2023-06: 0.14%  (720 hours)
#   2023-08: 0.00%  (744 hours)

# %% [markdown]
# ### 1.3 Anomaly screen and sensitivity
#
# An explicit screen, not a correction. Flagged hours are **retained**, because
# the screen cannot separate transcription error from genuine disturbance — the
# 4 October 2022 national grid failure is correctly flagged and is a real event.
# The table below shows that no crisis-period result depends on them.

# %%
def anomaly_flags(d, thresh=0.5, min_series=3, floor=200.0):
    cnt = Counter()
    for c in ["Demand","Generation"]+TECHS:
        s = d[c]; nb = (s.shift(1)+s.shift(-1))/2
        f = (((s-s.shift(1)).abs() > thresh*nb) &
             ((s-s.shift(-1)).abs() > thresh*nb) &
             (nb > floor) & ((s-nb).abs() > thresh*nb))
        for k in d.index[f.fillna(False)]: cnt[k] += 1
    return sorted(k for k,n in cnt.items() if n >= min_series)

FLAG = anomaly_flags(df)
print(f"flagged hours: {len(FLAG)}  |  inside 2022-2024: "
      f"{sum(1 for k in FLAG if df.loc[k,'datetime'].year>=2022)}")
yr = pd.Series([df.loc[k,"datetime"].year for k in FLAG]).value_counts().sort_index()
print("by year: " + ", ".join(f"{y}:{n}" for y,n in yr.items()))

print("\nTen largest by departure from neighbours:")
dev = sorted(FLAG, key=lambda i: -abs(df.loc[i,"Demand"]
             - 0.5*(df.loc[i-1,"Demand"]+df.loc[i+1,"Demand"])))[:10]
for i in dev:
    print(f"  {df.loc[i,'datetime']}  Demand {df.loc[i,'Demand']:>7.0f}  "
          f"neighbours {df.loc[i-1,'Demand']:.0f} / {df.loc[i+1,'Demand']:.0f}")

print("\nAnnual peak demand, as-is vs excluding flagged hours:")
clean = df.drop(index=FLAG)
A = df.groupby(df["datetime"].dt.year)["Demand"].max()
Bc = clean.groupby(clean["datetime"].dt.year)["Demand"].max()
peaks = pd.DataFrame({"year":A.index,"as_is":A.values,"cleaned":Bc.values,
                      "delta":(Bc-A).values})
print(peaks.to_string(index=False))
print("\n>> Pre-2020 peaks move materially; 2020 onward are unaffected. Re-check any")
print("   manuscript statement resting on pre-2020 peak demand.")
save_table(peaks, "TS_annual_peaks")
# Out:
# flagged hours: 91  |  inside 2022-2024: 9
# by year: 2015:5, 2016:16, 2017:11, 2018:16, 2019:12, 2020:12, 2021:10, 2022:4, 2023:2, 2024:3
#
# Ten largest by departure from neighbours:
#   2024-05-28 00:00:00  Demand   13081  neighbours 4369 / 3986
#   2022-10-24 00:00:00  Demand    3033  neighbours 12190 / 10973
#   2024-05-27 00:00:00  Demand    4240  neighbours 12784 / 12011
#   2020-03-05 07:00:00  Demand   13668  neighbours 6156 / 7418
#   2019-05-20 14:00:00  Demand    3864  neighbours 10314 / 10827
#   2019-08-12 20:00:00  Demand   15778  neighbours 9206 / 9799
#   2018-10-12 04:00:00  Demand   12784  neighbours 6734 / 6369
#   2021-05-17 18:00:00  Demand    3280  neighbours 9118 / 9733
#   2016-02-29 15:00:00  Demand   12341  neighbours 6216 / 6288
#   2021-03-28 09:00:00  Demand    3722  neighbours 9362 / 10196
#
# Annual peak demand, as-is vs excluding flagged hours:
#  year   as_is  cleaned   delta
#  2015 11160.0  10121.0 -1039.0
#  2016 12341.0  10194.0 -2147.0
#  2017 12921.0  10832.0 -2089.0
#  2018 12784.0  12329.2  -454.8
#  2019 16292.0  14538.0 -1754.0
#  2020 14001.0  14001.0     0.0
#  2021 14957.0  14957.0     0.0
#  2022 15208.0  15208.0     0.0
#  2023 16606.0  16606.0     0.0
#  2024 17128.0  17128.0     0.0
#
# >> Pre-2020 peaks move materially; 2020 onward are unaffected. Re-check any
#    manuscript statement resting on pre-2020 peak demand.
#   table -> TS_annual_peaks.csv
# '/content/outputs/tables/TS_annual_peaks.csv'

# %% [markdown]
# ## 2. Operational regimes
#
# The clustering below operates on demand and realised generation mix. Both are
# **operational outcomes** of dispatch under prevailing fuel availability, not
# structural properties of the system. It therefore identifies operational
# regimes and is not a structural-break test. Regime *dating* uses the changepoint
# analysis in §2.3.

# %% [markdown]
# ### 2.1 Annual context

# %%
a2 = df.copy(); a2["Year"] = a2["datetime"].dt.year
a2["Renewable"] = a2[["Solar","Wind","Hydro"]].sum(axis=1)
annual2 = a2.groupby("Year").agg(
    Demand_mean=("Demand","mean"), Gas_mean=("Gas","mean"), Coal_mean=("Coal","mean"),
    Liquid_mean=("Liquid Fuel","mean"), Import_mean=("Import","mean"),
    Renewable_mean=("Renewable","mean"),
    Loadshed_GWh=("Loadshed", lambda s: s.sum()/1000),
    Loadshed_hrs=("Loadshed", lambda s: int((s>0).sum())),
    hours=("Demand","size")).reset_index()
print(annual2.round(1).to_string(index=False))
print("\nNOTE: 2015 and 2024 are partial years (April onward / to 25 November).")
save_table(annual2, "TS_annual_context")
# Out:
#  Year  Demand_mean  Gas_mean  Coal_mean  Liquid_mean  Import_mean  Renewable_mean  Loadshed_GWh  Loadshed_hrs  hours
#  2015       5887.4    4184.7      114.6       1040.5        417.6           126.7           7.5            21   6144
#  2016       6436.9    4283.6      133.4       1436.1        483.4           103.3           7.3            35   8784
#  2017       6847.6    4487.1      127.5       1565.0        549.8           120.7           0.2             4   8760
#  2018       7604.4    4982.0      211.0       1713.3        602.7           103.7           3.3            11   8760
#  2019       8328.1    5843.7      235.7       1308.8        847.5           102.8           2.5            12   8760
#  2020       8374.6    5530.1      533.9       1438.1        791.7            89.9           4.3             4   8784
#  2021       9383.4    5755.9      548.3       2151.7        837.4           105.2           0.6             3   8760
#  2022      10216.0    5068.5      872.4       2989.5        947.8           137.4        1881.5          2282   8760
#  2023      10840.7    5440.4     2318.5       1636.2        968.7           175.6        2748.0          4988   8760
#  2024      11684.3    5196.8     3391.2       1408.2       1169.4           239.0        2205.4          5020   7914
#
# NOTE: 2015 and 2024 are partial years (April onward / to 25 November).
#   table -> TS_annual_context.csv
# '/content/outputs/tables/TS_annual_context.csv'

# %% [markdown]
# ### 2.2 PCA, loading stability and clustering

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

gmon = df.copy(); gmon["ym"] = gmon["datetime"].dt.to_period("M")
gmon["Supply_Gap"] = gmon["Demand"] - gmon[TECHS].sum(axis=1)
monthly_state = gmon.groupby("ym").agg(
    Demand=("Demand","mean"), Avg_Gap=("Supply_Gap","mean"),
    Gas=("Gas","mean"), Coal=("Coal","mean"),
    Import=("Import","mean"), Hydro=("Hydro","mean"),
    Loadshed=("Loadshed","sum"))
state_cols = list(monthly_state.columns)
X_state = monthly_state[state_cols].dropna()
Xs = StandardScaler().fit_transform(X_state)

pca = PCA().fit(Xs)
evr = pca.explained_variance_ratio_*100; cum = np.cumsum(evr)
n_keep = int(np.argmax(cum >= 85) + 1)
print("PCA on 7 monthly variables:", state_cols)
for k in range(len(evr)): print(f"  PC{k+1}: {evr[k]:5.1f}%  (cum {cum[k]:5.1f}%)")
print(f"=> retain {n_keep} components ({cum[n_keep-1]:.1f}% of variance)")

baseline_load = pd.DataFrame(pca.components_.T, index=state_cols,
                             columns=[f"PC{i+1}" for i in range(len(state_cols))])
print("\nBaseline loadings (retained PCs):")
print(baseline_load.iloc[:, :n_keep].round(3).to_string())

rng = np.random.default_rng(SEED)
boots = {f"PC{i+1}": [] for i in range(n_keep)}
for _ in range(BOOTSTRAP_B):
    idx = rng.integers(0, len(X_state), size=len(X_state))
    pb_ = PCA().fit(StandardScaler().fit_transform(X_state.iloc[idx]))
    lb = pd.DataFrame(pb_.components_.T, index=state_cols,
                      columns=[f"PC{i+1}" for i in range(len(state_cols))])
    for pc in boots:
        v = lb[pc].values
        if np.dot(v, baseline_load[pc].values) < 0: v = -v
        boots[pc].append(v)
print(f"\nBootstrap loading stability ({BOOTSTRAP_B} resamples):")
for pc, arr in boots.items():
    arr = np.array(arr)
    ag = (np.sign(arr) == np.sign(baseline_load[pc].values)).mean(axis=0)
    print(f"  {pc}: mean sign-agreement {ag.mean()*100:.1f}%  (min {ag.min()*100:.1f}%)")

Z = PCA(n_components=n_keep).fit_transform(Xs)
km = KMeans(2, init="k-means++", n_init=10, random_state=SEED).fit(Z)
lab = pd.Series(km.labels_, index=X_state.index)
crisis_cluster = lab[X_state["Loadshed"].idxmax()]
SIL = silhouette_score(Z, km.labels_)
CLUSTER = lab[lab==crisis_cluster].index.astype(str).tolist()
span = (pd.Period(CLUSTER[-1]) - pd.Period(CLUSTER[0])).n + 1
EXCLUDED = [str(p) for p in pd.period_range(CLUSTER[0], CLUSTER[-1], freq="M")
            if str(p) not in CLUSTER]
print(f"\nK-means (K=2): sizes {lab.value_counts().to_dict()} | silhouette {SIL:.3f}")
print(f"high-stress cluster: {len(CLUSTER)} NON-CONSECUTIVE months between "
      f"{CLUSTER[0]} and {CLUSTER[-1]} (calendar span {span})")
print(f"  members : {', '.join(CLUSTER)}")
print(f"  excluded within the window ({len(EXCLUDED)}): {', '.join(EXCLUDED)}")
print("\n>> The excluded months are the cool-season demand trough. The crisis regime")
print("   binds seasonally rather than continuously (see Section 6).")
# Out:
# PCA on 7 monthly variables: ['Demand', 'Avg_Gap', 'Gas', 'Coal', 'Import', 'Hydro', 'Loadshed']
#   PC1:  55.9%  (cum  55.9%)
#   PC2:  16.0%  (cum  71.9%)
#   PC3:  14.3%  (cum  86.2%)
#   PC4:   8.9%  (cum  95.1%)
#   PC5:   4.1%  (cum  99.1%)
#   PC6:   0.9%  (cum 100.0%)
#   PC7:   0.0%  (cum 100.0%)
# => retain 3 components (86.2% of variance)
#
# Baseline loadings (retained PCs):
#             PC1    PC2    PC3
# Demand    0.475  0.247 -0.009
# Avg_Gap   0.421 -0.470 -0.017
# Gas       0.304  0.604 -0.206
# Coal      0.394 -0.137  0.037
# Import    0.407  0.337  0.011
# Hydro     0.070  0.108  0.977
# Loadshed  0.423 -0.457 -0.033
#
# Bootstrap loading stability (2000 resamples):
#   PC1: mean sign-agreement 97.4%  (min 82.0%)
#   PC2: mean sign-agreement 90.4%  (min 52.2%)
#   PC3: mean sign-agreement 60.4%  (min 47.6%)
#
# K-means (K=2): sizes {0: 96, 1: 20} | silhouette 0.537
# high-stress cluster: 20 NON-CONSECUTIVE months between 2022-07 and 2024-11 (calendar span 29)
#   members : 2022-07, 2022-08, 2022-09, 2022-10, 2023-04, 2023-05, 2023-06, 2023-07, 2023-08, 2023-09, 2023-10, 2024-03, 2024-04, 2024-05, 2024-06, 2024-07, 2024-08, 2024-09, 2024-10, 2024-11
#   excluded within the window (9): 2022-11, 2022-12, 2023-01, 2023-02, 2023-03, 2023-11, 2023-12, 2024-01, 2024-02
#
# >> The excluded months are the cool-season demand trough. The crisis regime
#    binds seasonally rather than continuously (see Section 6).

# %% [markdown]
# ### 2.3 Effect sizes and regime tests

# %%
d0 = df.copy(); d0["year"] = d0["datetime"].dt.year
normal = d0[d0["year"].between(2015,2021)]
crisis = d0[d0["year"].between(2022,2024)]

def cohens_d(x, y):
    x, y = pd.Series(x).dropna().values, pd.Series(y).dropna().values
    sp = np.sqrt(((len(x)-1)*x.var(ddof=1)+(len(y)-1)*y.var(ddof=1))/(len(x)+len(y)-2))
    return (y.mean()-x.mean())/sp

rows = []
for name, col in [("Demand","Demand"),("Gas","Gas"),("Coal","Coal"),
                  ("Liquid fuel","Liquid Fuel"),("Import","Import"),
                  ("Hydro","Hydro"),("Load shedding","Loadshed")]:
    rows.append({"Variable":name, "Normal":round(normal[col].mean(),1),
                 "Crisis":round(crisis[col].mean(),1),
                 "Cohen_d":round(cohens_d(normal[col],crisis[col]),2)})
eff_hourly = pd.DataFrame(rows)
print("Hourly effect sizes (crisis - normal, pooled SD):")
print(eff_hourly.to_string(index=False))
save_table(eff_hourly, "TS_effect_sizes_hourly")
# Out:
# Hourly effect sizes (crisis - normal, pooled SD):
#      Variable  Normal  Crisis  Cohen_d
#        Demand  7625.7 10888.0     1.57
#           Gas  5046.2  5236.5     0.21
#          Coal   279.1  2154.2     2.66
#   Liquid fuel  1543.3  2031.4     0.42
#        Import   657.4  1023.9     1.38
#         Hydro   100.3    92.6    -0.13
# Load shedding     0.4   268.7     1.01
#   table -> TS_effect_sizes_hourly.csv
# '/content/outputs/tables/TS_effect_sizes_hourly.csv'

# %%
_g = df.copy(); _g["ym"] = _g["datetime"].dt.to_period("M")
_g["Supply_Gap"] = _g["Demand"] - _g[TECHS].sum(axis=1)
mon_reg = _g.groupby("ym").agg(
    Demand=("Demand","mean"), Supply_gap=("Supply_Gap","mean"),
    Gas=("Gas","mean"), Coal=("Coal","mean"), Liquid_fuel=("Liquid Fuel","mean"),
    Import=("Import","mean"), Hydro=("Hydro","mean"), Load_shedding=("Loadshed","sum"))
mon_reg["year"] = mon_reg.index.year
mon_n = mon_reg[mon_reg["year"] <= 2021]; mon_c = mon_reg[mon_reg["year"] >= 2022]
print(f"monthly units: normal n={len(mon_n)}, crisis n={len(mon_c)}")

_HOURLY = {"Demand":"Demand","Gas":"Gas","Coal":"Coal","Liquid_fuel":"Liquid Fuel",
           "Import":"Import","Hydro":"Hydro","Load_shedding":"Loadshed"}
_rng = np.random.default_rng(SEED)
rows = []
for v in ["Demand","Supply_gap","Gas","Coal","Liquid_fuel","Import","Hydro","Load_shedding"]:
    a = mon_n[v].dropna().values; b = mon_c[v].dropna().values
    t = stats.ttest_ind(a,b,equal_var=False); u = stats.mannwhitneyu(a,b,alternative="two-sided")
    d_m = cohens_d(a,b)
    bs = [cohens_d(_rng.choice(a,len(a)), _rng.choice(b,len(b))) for _ in range(BOOTSTRAP_B)]
    lo, hi = np.percentile(bs,[2.5,97.5])
    d_h = cohens_d(normal[_HOURLY[v]].dropna().values,
                   crisis[_HOURLY[v]].dropna().values) if v in _HOURLY else np.nan
    rows.append(dict(Variable=v, Normal_mean=round(a.mean(),2), Crisis_mean=round(b.mean(),2),
                     Welch_p=t.pvalue, MWU_p=u.pvalue, d_monthly=round(d_m,3),
                     CI_lo=round(lo,3), CI_hi=round(hi,3),
                     d_hourly=(round(d_h,3) if np.isfinite(d_h) else np.nan)))
regime_tests = pd.DataFrame(rows)
_f = regime_tests.copy()
for c in ["Welch_p","MWU_p"]:
    _f[c] = _f[c].map(lambda p: f"{p:.2e}" if p < 1e-4 else f"{p:.4f}")
print("\nRegime-shift tests, monthly aggregates (positive d = higher during the crisis)")
print(_f.to_string(index=False))
save_table(regime_tests, "TS_regime_tests")
# Out:
# monthly units: normal n=81, crisis n=35
#
# Regime-shift tests, monthly aggregates (positive d = higher during the crisis)
#      Variable  Normal_mean  Crisis_mean  Welch_p    MWU_p  d_monthly  CI_lo  CI_hi  d_hourly
#        Demand      7604.49     10875.04 7.32e-13 3.89e-12      1.969  1.500  2.574     1.573
#    Supply_gap        -6.82       257.99 3.15e-06 1.29e-09      1.721  1.348  2.248       NaN
#           Gas      5037.32      5232.21   0.2123   0.1740      0.246 -0.135  0.653     0.208
#          Coal       278.37      2149.72 5.87e-11 8.05e-17      2.811  2.319  3.578     2.660
#   Liquid_fuel      1534.15      2026.13   0.0079   0.0169      0.634  0.218  1.096     0.418
#        Import       655.52      1026.64 1.94e-09 3.82e-10      1.594  1.299  1.984     1.384
#         Hydro        99.66        92.50   0.5507   0.2710     -0.131 -0.553  0.305    -0.127
# Load_shedding       317.99    195281.46 3.27e-06 4.18e-12      1.719  1.351  2.233     1.012
#   table -> TS_regime_tests.csv
# '/content/outputs/tables/TS_regime_tests.csv'

# %% [markdown]
# ### 2.4 Changepoint
#
# Reported with the settings, a sweep over cost functions, penalties and minimum
# segment lengths, and a confidence interval. A moving-block bootstrap is
# **invalid** for a changepoint date — it scrambles temporal order — so a
# segment-preserving residual bootstrap is used.

# %%
import ruptures as rpt
mo_shed = df.groupby(df["datetime"].dt.to_period("M"))["Loadshed"].mean()
sig = mo_shed.values.astype(float)

CP = {}
print("Binary segmentation, n_bkps=1, by cost function:")
for cost in ["l2","l1","rbf","normal"]:
    try:
        bk = rpt.Binseg(model=cost).fit(sig).predict(n_bkps=1)
        CP[f"binseg_{cost}"] = str(mo_shed.index[bk[0]-1])
        print(f"  {cost:8s} {CP[f'binseg_{cost}']}")
    except Exception: print(f"  {cost:8s} error")

print("\nPELT, l2, min_size=3, by penalty:")
for f in [0.01,0.05,0.10,0.25,0.50]:
    try:
        bk = rpt.Pelt(model="l2", min_size=3).fit(sig).predict(pen=np.var(sig)*len(sig)*f)
        got = ",".join(str(mo_shed.index[b-1]) for b in bk[:-1]) or "none"
        CP[f"pelt_{f}"] = got; print(f"  pen={f:<5} {got}")
    except Exception: pass

print("\nBinary segmentation by minimum segment length:")
for ms in [2,3,6,12]:
    bk = rpt.Binseg(model="l2", min_size=ms).fit(sig).predict(n_bkps=1)
    CP[f"minsize_{ms}"] = str(mo_shed.index[bk[0]-1])
    print(f"  min_size={ms:<3} {CP[f'minsize_{ms}']}")

bk0 = rpt.Binseg(model="l2").fit(sig).predict(n_bkps=1)[0]
mu  = [sig[:bk0].mean(), sig[bk0:].mean()]
res_ = [sig[:bk0]-mu[0], sig[bk0:]-mu[1]]
rngc = np.random.default_rng(SEED); draws = []
for _ in range(BOOTSTRAP_B):
    sim = np.concatenate([m + rngc.choice(r, size=len(r), replace=True)
                          for m, r in zip(mu, res_)])
    try: draws.append(rpt.Binseg(model="l2").fit(sim).predict(n_bkps=1)[0]-1)
    except Exception: pass
q = np.percentile(draws,[2.5,50,97.5]).astype(int)
CP["point_estimate"] = str(mo_shed.index[bk0-1])
CP["ci95_low"], CP["ci95_high"] = str(mo_shed.index[q[0]]), str(mo_shed.index[q[2]])
CP["exact_recovery_pct"] = round(100*float(np.mean(np.array(draws)==bk0-1)),1)
print(f"\nSegment-preserving residual bootstrap ({BOOTSTRAP_B} resamples):")
print(f"  point estimate {CP['point_estimate']}")
print(f"  95% interval   {CP['ci95_low']} to {CP['ci95_high']}")
print(f"  exact-month recovery {CP['exact_recovery_pct']}%")
print("\n>> Three onset definitions appear in this analysis and are not identical:")
print(f"   changepoint {CP['point_estimate']} | cluster first month {CLUSTER[0]} | "
      "first >=97%-shedding month 2022-08.")
save_table(pd.DataFrame([CP]), "TS_changepoint_robustness")
# Out:
# Binary segmentation, n_bkps=1, by cost function:
#   l2       2022-04
#   l1       2022-04
#   rbf      2022-04
#   normal   2022-04
#
# PELT, l2, min_size=3, by penalty:
#   pen=0.01  2022-04,2023-02,2023-07,2024-05
#   pen=0.05  2022-04
#   pen=0.1   2022-04
#   pen=0.25  2022-04
#   pen=0.5   none
#
# Binary segmentation by minimum segment length:
#   min_size=2   2022-04
#   min_size=3   2022-04
#   min_size=6   2022-04
#   min_size=12  2022-04
#
# Segment-preserving residual bootstrap (2000 resamples):
#   point estimate 2022-04
#   95% interval   2022-04 to 2023-02
#   exact-month recovery 87.5%
#
# >> Three onset definitions appear in this analysis and are not identical:
#    changepoint 2022-04 | cluster first month 2022-07 | first >=97%-shedding month 2022-08.
#   table -> TS_changepoint_robustness.csv
# '/content/outputs/tables/TS_changepoint_robustness.csv'

# %% [markdown]
# ## 3. Network and the closed-form reduction
#
# The baseline system contains **no storage**; battery capacity enters only as an
# explicit intervention (Section 13).

# %%
base_load_shares = {"Load_NW":0.10,"Load_NE":0.12,"Load_Dhaka":0.50,
                    "Load_SW":0.10,"Load_CTG":0.18}

base = pypsa.Network(BASE_PATH)
if len(base.storage_units):
    print(f"stripped {len(base.storage_units)} legacy storage units "
          f"({base.storage_units['p_nom'].sum():.0f} MW) - the baseline is storage-free")
    base.remove("StorageUnit", base.storage_units.index)
assert len(base.storage_units)==0

NETCAP = (base.generators[base.generators.carrier!="Load Shedding"]
          .groupby("carrier")["p_nom"].sum().to_dict())
CAPS = {t: NETCAP[t] for t in THERMAL}
_zc = base.generators[base.generators.carrier!="Load Shedding"].groupby("bus")["p_nom"].sum()

print(f"\nbuses {len(base.buses)} | lines {len(base.lines)} | generators {len(base.generators)}")
print("\nInstalled capacity by zone (MW), excluding virtual shedding:")
for b in ["NW","NE","Dhaka","SW","CTG"]:
    print(f"  {b:6s} {_zc[b]:9,.1f}   load share {base_load_shares['Load_'+b]:.0%}")
print(f"  total  {_zc.sum():9,.1f}")
print("\nInter-zonal corridors (MW):")
for nm, ln in base.lines.iterrows():
    print(f"  {ln['bus0']:>5s} - {ln['bus1']:<5s} {ln['s_nom']:8,.0f}")
print("\nInstalled capacity by carrier (MW):")
for c, v in base.generators.groupby("carrier")["p_nom"].sum().items():
    print(f"  {c:16s} {v:9,.1f}")
# Out:
# stripped 5 legacy storage units (500 MW) - the baseline is storage-free
#
# buses 5 | lines 6 | generators 38
#
# Installed capacity by zone (MW), excluding virtual shedding:
#   NW       2,143.9   load share 10%
#   NE       3,900.8   load share 12%
#   Dhaka    4,265.9   load share 50%
#   SW       2,730.3   load share 10%
#   CTG      3,465.6   load share 18%
#   total   16,506.6
#
# Inter-zonal corridors (MW):
#      NW - Dhaka    6,500
#      NE - Dhaka    7,000
#      SW - Dhaka    6,000
#     CTG - Dhaka    5,000
#      NW - SW       3,000
#      NE - CTG      3,000
#
# Installed capacity by carrier (MW):
#   Coal               4,143.6
#   Gas                6,644.0
#   Hydro                211.0
#   Import             1,093.0
#   Liquid Fuel        3,995.1
#   Load Shedding      5,365.5
#   Solar                390.8
#   Wind                  29.0

# %%
SOLVE_KW = dict(solver_name="highs", solver_options={"output_flag":False},
                include_objective_constant=False)

def fresh_network(b):
    n = copy.deepcopy(b)
    try: n.model = None
    except Exception: pass
    return n

def _shed_gens(n):
    return [g for g in n.generators.index if "load shedding" in g.lower()]

def build_month_network(b, mdf, mode="hourly", size_shedding=False):
    """
    mode='hourly' : p_max_pu(i,t) = min(g_i(t)/P_nom_i, 1)          [Eq. 11]
    mode='daily'  : p_max_pu = 1, with a per-carrier daily energy budget
                    supplied separately by add_daily_budgets()

    size_shedding : the shipped virtual shedding fleet is 5,365.5 MW, smaller
                    than the worst observed shortfall (8,496 MW, 4 Oct 2022),
                    so months containing that hour are INFEASIBLE. Scaling the
                    fleet to zonal peak leaves all other months unchanged.
    """
    n = fresh_network(b); n.set_snapshots(mdf.index)
    dem = pd.to_numeric(mdf["Demand"], errors="coerce").fillna(0.0)
    for L in n.loads.index:
        n.loads_t.p_set[L] = dem.values * base_load_shares.get(L, 0.0)
    for t in TECHS:
        gens = [g for g in n.generators.index if n.generators.loc[g,"carrier"]==t]
        if not gens: continue
        cap = float(n.generators.loc[gens,"p_nom"].sum())
        cf = (pd.Series(1.0, index=mdf.index) if mode=="daily"
              else ((pd.to_numeric(mdf[t],errors="coerce").fillna(0.0)/cap).clip(0,1)
                    if cap>0 else pd.Series(0.0,index=mdf.index)))
        for g in gens: n.generators_t.p_max_pu[g] = cf.values
    for g in _shed_gens(n): n.generators_t.p_max_pu[g] = 1.0
    if size_shedding:
        for g in _shed_gens(n):
            z = n.generators.loc[g,"bus"]
            n.generators.loc[g,"p_nom"] = float(
                dem.max()*base_load_shares.get(f"Load_{z}",0.0)*1.05)
    return n

def add_daily_budgets(n, mdf, b):
    """Per-carrier, per-day energy budget = the energy that carrier delivered."""
    m = n.optimize.create_model(); p = m.variables["Generator-p"]
    days = pd.Series(mdf.index.date, index=mdf.index)
    for t in TECHS:
        gens = [g for g in n.generators.index if n.generators.loc[g,"carrier"]==t]
        if not gens: continue
        cap = float(b.generators.loc[
            [g for g in b.generators.index if b.generators.loc[g,"carrier"]==t],"p_nom"].sum())
        obs = np.minimum(pd.to_numeric(mdf[t],errors="coerce").fillna(0.0), cap)
        for day, idx in mdf.groupby(days).groups.items():
            m.add_constraints(p.sel(snapshot=list(idx), name=gens).sum()
                              <= float(obs.loc[idx].sum()),
                              name=f"budget_{t}_{day}".replace(" ",""))
    return m

def model_shed_series(n, model=None, strict=True):
    """RAISES on a non-optimal solve rather than silently returning zeros."""
    res = n.optimize(**SOLVE_KW) if model is None else \
          n.optimize.solve_model(solver_name="highs", solver_options={"output_flag":False})
    status, cond = (res if isinstance(res, tuple) else (res, ""))
    if str(status) != "ok":
        msg = f"solver not optimal: status={status} condition={cond}"
        if strict: raise RuntimeError(msg)
        print("  !! "+msg); return pd.Series(np.nan, index=n.snapshots)
    return n.generators_t.p[_shed_gens(n)].sum(axis=1)

def shed_stats(n, mdf, model=None):
    mod = model_shed_series(n, model)
    obs = pd.to_numeric(mdf["Loadshed"],errors="coerce").fillna(0.0)
    dd = mod.values - obs.values
    return dict(obs=round(float(obs.mean()),2), model=round(float(mod.mean()),2),
                bias=round(float(dd.mean()),2), mae=round(float(np.abs(dd).mean()),2),
                rmse=round(float(np.sqrt((dd**2).mean())),2),
                corr=(round(float(np.corrcoef(mod.values,obs.values)[0,1]),3)
                      if obs.std()>0 else np.nan))
print("network helpers defined")
# Out:
# network helpers defined

# %% [markdown]
# ### 3.1 Virtual shedding fleet — feasibility

# %%
LS_TOTAL = base.generators[base.generators.carrier=="Load Shedding"]["p_nom"].sum()
print(f"virtual shedding capacity: {LS_TOTAL:,.1f} MW")
print(f"historical maximum shed  : {df['Loadshed'].max():,.0f} MW at "
      f"{df.loc[df['Loadshed'].idxmax(),'datetime']}")
over = df[df["Loadshed"] > LS_TOTAL]
print(f"hours exceeding the fleet: {len(over)}  "
      f"({', '.join(over['datetime'].dt.strftime('%Y-%m-%d %H:%M'))})")
print("\nModelled months:")
for ym in PERIODS:
    mx = slice_month(ym)["Loadshed"].max()
    print(f"  {ym}: max shed {mx:6.0f} MW  {'OK' if mx<LS_TOTAL else 'EXCEEDS'}")
print("\n>> The 4 October 2022 national grid collapse is a transmission-security event,")
print("   outside the adequacy scope and outside all modelled periods. Analyses that")
print("   span the full crisis period pass size_shedding=True.")
# Out:
# virtual shedding capacity: 5,365.5 MW
# historical maximum shed  : 8,496 MW at 2022-10-04 15:00:00
# hours exceeding the fleet: 6  (2022-10-04 15:00, 2022-10-04 16:00, 2022-10-04 17:00, 2022-10-04 18:00, 2022-10-04 19:00, 2022-10-04 20:00)
#
# Modelled months:
#   2016-12: max shed      0 MW  OK
#   2022-08: max shed   2294 MW  OK
#   2023-06: max shed   3419 MW  OK
#   2023-08: max shed   1761 MW  OK
#
# >> The 4 October 2022 national grid collapse is a transmission-security event,
#    outside the adequacy scope and outside all modelled periods. Analyses that
#    span the full crisis period pass size_shedding=True.

# %% [markdown]
# ### 3.2 Closed-form reduction — **GATE**
#
# Under a value of lost load two orders of magnitude above every marginal cost,
# and with corridors non-binding, the linear program admits an exact closed form:
#
# $$\mathrm{shed}(t)=\max\Big(D(t)-\sum_i \min\big(g_i(t),\,P^{\mathrm{nom}}_i\big),\;0\Big)$$
#
# **If this does not return zero, stop.** It also means reconstruction fidelity is
# near-algebraic by construction and is not treated as validation (§9).

# %%
def available(mdf, extra=None, secured=0.0):
    a = sum(np.minimum(mdf[t].fillna(0.0), NETCAP[t]) for t in TECHS)
    if extra:
        for t, mw in extra.items():
            a = a + mw*(mdf[t].fillna(0.0)/NETCAP[t]).clip(0,1)
    return a + float(secured)

def shed_closed_form(mdf, **kw):
    return (mdf["Demand"] - available(mdf, **kw)).clip(lower=0)

rows = []
for ym in PERIODS:
    mdf = slice_month(ym)
    lp = model_shed_series(build_month_network(base, mdf)).mean()
    cf = shed_closed_form(mdf).mean()
    rows.append(dict(period=ym, LP=round(lp,6), closed_form=round(cf,6),
                     abs_diff=round(abs(lp-cf),8)))
cfv = pd.DataFrame(rows)
print(cfv.to_string(index=False))
assert (cfv["abs_diff"] < 1e-6).all(), "closed form does not match the LP - STOP"
print(f"\nGATE PASSED: maximum absolute difference {cfv['abs_diff'].max():.8f} MW/h")
print("\n>> The zonal network, merit order and solver contribute nothing to the")
print("   reconstruction results. The network earns its place by establishing that")
print("   corridors are non-binding (Section 5), not by altering the dispatch result.")
save_table(cfv, "TS_closed_form_verification")
# Out:
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 19.47it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 50.98it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 25.34it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 94.55it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 35.62it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 80.58it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.44it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 105.74it/s]
#  period          LP  closed_form  abs_diff
# 2016-12    6.182796     6.182796       0.0
# 2022-08  904.237473   904.237473       0.0
# 2023-06 1038.807323  1038.807323       0.0
# 2023-08  367.379428   367.379428       0.0
#
# GATE PASSED: maximum absolute difference 0.00000000 MW/h
#
# >> The zonal network, merit order and solver contribute nothing to the
#    reconstruction results. The network earns its place by establishing that
#    corridors are non-binding (Section 5), not by altering the dispatch result.
#   table -> TS_closed_form_verification.csv
# '/content/outputs/tables/TS_closed_form_verification.csv'

# %% [markdown]
# ## 4. Idle capacity
#
# The central empirical finding, and the one part of the paper that requires no
# model at all.

# %%
crisis_all = df[df["datetime"].dt.year.between(2022,2024)]
shed = crisis_all[crisis_all["Loadshed"]>0].copy()
shed["idle_thermal"] = sum((CAPS[t]-shed[t].fillna(0.0)).clip(lower=0) for t in THERMAL)

IDLE = dict(crisis_hours=len(crisis_all), shedding_hours=len(shed),
            mean_idle=round(float(shed["idle_thermal"].mean()),1),
            mean_shortfall=round(float(shed["Loadshed"].mean()),1),
            idle_gt_shortfall=round(100*float((shed["idle_thermal"]>shed["Loadshed"]).mean()),2),
            idle_gt_zero=round(100*float((shed["idle_thermal"]>0).mean()),2))
print(f"crisis hours {IDLE['crisis_hours']:,} | shedding hours {IDLE['shedding_hours']:,}")
print(f"mean idle thermal {IDLE['mean_idle']:,} MW | mean shortfall {IDLE['mean_shortfall']} MW")
print(f"\n  idle > shortfall : {IDLE['idle_gt_shortfall']:.2f}%   <- the reported claim")
print(f"  idle > 0         : {IDLE['idle_gt_zero']:.2f}%   <- 'not fully dispatched'")
print("\n>> These are different statements. The manuscript reports the FIRST number;")
print("   its wording must therefore be 'idle capacity exceeded the entire shortfall',")
print("   not 'the fleet was not fully dispatched'.")

thr = shed["Loadshed"].quantile(0.90)
worst = shed[shed["Loadshed"]>=thr].copy()
print(f"\nWorst decile: n={len(worst):,}, mean shortfall {worst['Loadshed'].mean():,.0f} MW")
wd = []
for t in THERMAL:
    wd.append(dict(carrier=t, util_pct=round(100*worst[t].mean()/CAPS[t],1),
                   idle_clipped_mean=round(float((CAPS[t]-worst[t].fillna(0.0))
                                                 .clip(lower=0).mean()),0),
                   idle_cap_minus_mean=round(float(CAPS[t]-worst[t].mean()),0)))
wd = pd.DataFrame(wd); print(wd.to_string(index=False))
print("\n>> Use idle_clipped_mean throughout for consistency with the aggregate,")
print("   or footnote the difference between the two definitions.")
save_table(wd, "TS_worst_decile")
# Out:
# crisis hours 25,434 | shedding hours 12,290
# mean idle thermal 4,416.7 MW | mean shortfall 556.1 MW
#
#   idle > shortfall : 99.77%   <- the reported claim
#   idle > 0         : 99.98%   <- 'not fully dispatched'
#
# >> These are different statements. The manuscript reports the FIRST number;
#    its wording must therefore be 'idle capacity exceeded the entire shortfall',
#    not 'the fleet was not fully dispatched'.
#
# Worst decile: n=1,229, mean shortfall 1,796 MW
#     carrier  util_pct  idle_clipped_mean  idle_cap_minus_mean
#         Gas      85.5             1009.0                961.0
#        Coal      51.8             2025.0               1999.0
# Liquid Fuel      66.5             1373.0               1337.0
#
# >> Use idle_clipped_mean throughout for consistency with the aggregate,
#    or footnote the difference between the two definitions.
#   table -> TS_worst_decile.csv
# '/content/outputs/tables/TS_worst_decile.csv'

# %% [markdown]
# ### 4.1 Robustness to the capacity assumption
#
# The finding depends on assumed thermal nameplate, which is held fixed across a
# decade of fleet growth. Two checks bound the consequences.

# %%
clean_df = df.drop(index=FLAG)
assumed = sum(CAPS[t] for t in THERMAL)
ssum = clean_df[THERMAL].sum(axis=1); at = ssum.idxmax()
print("(a) The record bounds thermal capacity from BELOW.")
print(f"    {'carrier':13s} {'assumed':>9s} {'max observed':>13s}")
for t in THERMAL:
    print(f"    {t:13s} {CAPS[t]:9.0f} {clean_df[t].max():13.0f}")
print(f"    {'max of sum':13s} {assumed:9.0f} {ssum.max():13.0f}   "
      f"<- simultaneous, at {clean_df.loc[at,'datetime']}")
IMPLIED_LAMBDA = ssum.max()/assumed
print(f"\n    Implied minimum is {IMPLIED_LAMBDA:.2f}x the assumed {assumed:,.0f} MW.")
print("    The assumption is therefore CONSERVATIVE: reported idle capacity is a floor.")

rows = []
for lam in [0.60,0.70,0.80,0.90,1.00,1.10,1.20,1.35]:
    idle = sum((CAPS[t]*lam-shed[t].fillna(0.0)).clip(lower=0) for t in THERMAL)
    rows.append(dict(lam=lam, thermal_mw=round(assumed*lam,0),
                     mean_idle_mw=round(float(idle.mean()),0),
                     idle_gt_shortfall_pct=round(100*float((idle>shed["Loadshed"]).mean()),2),
                     idle_gt_zero_pct=round(100*float((idle>0).mean()),2)))
cap_rob = pd.DataFrame(rows)
print("\n(b) Sensitivity to scaling thermal nameplate by lambda:")
print(cap_rob.to_string(index=False))
print(f"\n>> The claim holds for {cap_rob.loc[cap_rob.lam==0.90,'idle_gt_shortfall_pct'].iloc[0]:.1f}% "
      "of shedding hours even at lambda = 0.90, and the record implies")
print(f"   lambda >= {IMPLIED_LAMBDA:.2f}. The plausible range lies entirely where the result is stronger.")
save_table(cap_rob, "TS_capacity_robustness")
# Out:
# (a) The record bounds thermal capacity from BELOW.
#     carrier         assumed  max observed
#     Gas                6644          8114
#     Coal               4144          5657
#     Liquid Fuel        3995          6175
#     max of sum        14783         15697   <- simultaneous, at 2024-04-30 21:00:00
#
#     Implied minimum is 1.06x the assumed 14,783 MW.
#     The assumption is therefore CONSERVATIVE: reported idle capacity is a floor.
#
# (b) Sensitivity to scaling thermal nameplate by lambda:
#  lam  thermal_mw  mean_idle_mw  idle_gt_shortfall_pct  idle_gt_zero_pct
# 0.60      8870.0         970.0                  64.74             84.91
# 0.70     10348.0        1458.0                  77.75             92.09
# 0.80     11826.0        2152.0                  89.21             97.78
# 0.90     13304.0        3164.0                  97.16             99.88
# 1.00     14783.0        4417.0                  99.77             99.98
# 1.10     16261.0        5804.0                 100.00            100.00
# 1.20     17739.0        7248.0                 100.00            100.00
# 1.35     19957.0        9454.0                 100.00            100.00
#
# >> The claim holds for 97.2% of shedding hours even at lambda = 0.90, and the record implies
#    lambda >= 1.06. The plausible range lies entirely where the result is stronger.
#   table -> TS_capacity_robustness.csv
# '/content/outputs/tables/TS_capacity_robustness.csv'

# %% [markdown]
# ### 4.2 Anomaly sensitivity of every headline result

# %%
def headline(dd):
    cr = dd[dd["datetime"].dt.year.between(2022,2024)]
    sh = cr[cr["Loadshed"]>0].copy()
    sh["idle"] = sum((CAPS[t]-sh[t].fillna(0.0)).clip(lower=0) for t in THERMAL)
    pre = dd[dd["datetime"]<"2022-01-01"]
    r = dict(crisis_hours=len(cr), shedding_hours=len(sh),
             mean_idle=round(float(sh["idle"].mean()),1),
             mean_shortfall=round(float(sh["Loadshed"].mean()),1),
             idle_gt_shortfall=round(100*float((sh["idle"]>sh["Loadshed"]).mean()),2),
             idle_gt_zero=round(100*float((sh["idle"]>0).mean()),2),
             pre_LOLP=round(100*float((pre["Loadshed"]>0).mean()),3),
             crisis_LOLP=round(100*float((cr["Loadshed"]>0).mean()),1))
    for ym in PERIODS:
        r[ym] = round(float(shed_closed_form(slice_month(ym, dd)).mean()),2)
    return r

anom = pd.DataFrame([dict(variant="as published", **headline(df)),
                     dict(variant="flagged removed", **headline(clean_df))])
print(anom.to_string(index=False))
mo_c = clean_df.groupby(clean_df["datetime"].dt.to_period("M"))["Loadshed"].mean()
bkc = rpt.Binseg(model="l2").fit(mo_c.values.astype(float)).predict(n_bkps=1)
print(f"\nchangepoint: as published {CP['point_estimate']} | "
      f"flagged removed {mo_c.index[bkc[0]-1]}")
print("\n>> No crisis-period result changes at the reported precision. The flagged")
print("   hours are retained and disclosed rather than corrected.")
save_table(anom, "TS_anomaly_sensitivity")
# Out:
#         variant  crisis_hours  shedding_hours  mean_idle  mean_shortfall  idle_gt_shortfall  idle_gt_zero  pre_LOLP  crisis_LOLP  2016-12  2022-08  2023-06  2023-08
#    as published         25434           12290     4416.7           556.1              99.77         99.98     0.153         48.3     6.18   904.24  1038.81   367.38
# flagged removed         25425           12289     4416.8           556.1              99.77         99.98     0.153         48.3     5.12   904.24  1040.25   367.38
#
# changepoint: as published 2022-04 | flagged removed 2022-04
#
# >> No crisis-period result changes at the reported precision. The flagged
#    hours are retained and disclosed rather than corrected.
#   table -> TS_anomaly_sensitivity.csv
# '/content/outputs/tables/TS_anomaly_sensitivity.csv'

# %% [markdown]
# ## 5. Transmission
#
# **A limit of this test, stated explicitly.** Availability is calibrated from
# observed dispatch, so if real network constraints suppressed dispatch during
# the crisis their effect is already inside the availability envelope. Relaxing
# modelled inter-zonal limits cannot detect constraints already absorbed into the
# calibration. What follows establishes that *additional* modelled corridor
# capacity would not have reduced shedding — not that the physical network was
# unconstrained.

# %%
nJ = build_month_network(base, slice_month("2023-06")); model_shed_series(nJ)
util = nJ.lines_t.p0.abs().div(base.lines["s_nom"], axis=1)
print("June 2023, rated configuration:")
print(f"  {'corridor':12s} {'rated MW':>9s} {'peak MW':>9s} {'util %':>7s}")
for L in base.lines.index:
    print(f"  {L:12s} {base.lines.at[L,'s_nom']:9,.0f} "
          f"{nJ.lines_t.p0[L].abs().max():9,.0f} {100*util[L].max():7.1f}")
UTIL_JUN = 100*util.max().max()
print(f"  peak across all corridors: {UTIL_JUN:.1f}%")
# Out:
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 42.18it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 71.74it/s]
# June 2023, rated configuration:
#   corridor      rated MW   peak MW  util %
#   NW-Dhaka         6,500       690    10.6
#   NE-Dhaka         7,000     1,797    25.7
#   SW-Dhaka         6,000     1,070    17.8
#   CTG-Dhaka        5,000     1,299    26.0
#   NW-SW            3,000       380    12.7
#   NE-CTG           3,000       759    25.3
#   peak across all corridors: 26.0%

# %%
if RUN_TRANSMISSION:
    t0 = time.time(); nom = base.lines["s_nom"].copy(); rows = []
    for ym in crisis_months():
        mdf = slice_month(ym)
        if len(mdf) < 24: continue
        rec = dict(month=ym, observed=round(float(mdf["Loadshed"].mean()),1))
        for s in (1.0, 0.5, 0.3):
            n = build_month_network(base, mdf, size_shedding=True)
            n.lines["s_nom"] = nom*s
            rec[f"x{s}"] = round(float(model_shed_series(n).mean()),2)
            if s == 1.0:
                rec["max_util_pct"] = round(
                    100*float(n.lines_t.p0.abs().div(nom,axis=1).max().max()),1)
        rec["delta"] = round(rec["x0.3"]-rec["x1.0"],2); rows.append(rec)
    trans = pd.DataFrame(rows)
    print(trans.to_string(index=False))
    N_CHANGED = int((trans["delta"].abs()>1).sum())
    UTIL_ALL  = float(trans["max_util_pct"].max())
    print(f"\nmonths changed by >1 MW/h at 30% derating: {N_CHANGED} of {len(trans)}")
    print(f"peak corridor utilisation across all crisis months: {UTIL_ALL:.1f}%")
    print(f"({time.time()-t0:.0f}s)")
    print("\n>> NOTE: this sweep uses size_shedding=True, without which October 2022")
    print("   is infeasible. Peak utilisation is therefore 51.4% here against 26.0% for")
    print("   June 2023 in the as-shipped configuration above. Quote the right one.")
    save_table(trans, "T5_transmission_all_months")
else:
    trans = None; N_CHANGED = UTIL_ALL = np.nan
    print("skipped (RUN_TRANSMISSION = False)")
# Out:
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.58it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 125.34it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.30it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 122.18it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.31it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 117.42it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 65.79it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 129.54it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 66.29it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 117.50it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 42.65it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 96.42it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.51it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 118.28it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.65it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 114.77it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.32it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 121.13it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.28it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 113.04it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 64.12it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 128.81it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.92it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 70.29it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.26it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 115.29it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.60it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 114.45it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.35it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 120.51it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.45it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 114.84it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.32it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 122.07it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 41.27it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 66.03it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.53it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 117.95it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.54it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 115.59it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.67it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 99.50it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.16it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 106.56it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.98it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 112.17it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.16it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 85.10it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.89it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 127.05it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.21it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 119.49it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.36it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 119.34it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 51.13it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 116.35it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 50.56it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 103.87it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.87it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 63.78it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.01it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 106.64it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.07it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 123.75it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.23it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 94.61it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.98it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 113.44it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.95it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 108.87it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 39.12it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 74.04it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.49it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 108.97it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.59it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 100.43it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.68it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 121.84it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.79it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 136.76it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 65.60it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 92.66it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 42.32it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 93.69it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.53it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 109.73it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.31it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 127.47it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 52.13it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 110.91it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.67it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 105.82it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.29it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 130.75it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.73it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 77.19it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.99it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 104.65it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.55it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 118.65it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.10it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 107.38it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 54.67it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 88.64it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 64.41it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 85.92it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 39.00it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 80.97it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.81it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 120.08it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.33it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 110.38it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.86it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 107.73it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 54.72it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 95.79it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.79it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 110.29it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 37.63it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 71.67it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.12it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 96.54it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 55.58it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 84.08it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.67it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 103.19it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.29it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 117.01it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.18it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 105.66it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.17it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 85.78it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.30it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 119.50it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.38it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 104.06it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.89it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 105.16it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.10it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 101.54it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 39.34it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 59.26it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.02it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 101.87it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.26it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 110.20it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.12it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 101.24it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.81it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 115.20it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.12it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 107.94it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.37it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 116.61it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 37.48it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 81.88it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.33it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 113.60it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.91it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 103.45it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.21it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 101.05it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.59it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 121.82it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.23it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 107.15it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 41.04it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 77.15it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.75it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 119.33it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.85it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 118.20it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.73it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 100.02it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.58it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 117.14it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 54.87it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 103.39it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 35.81it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 102.57it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.29it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 107.43it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.45it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 89.07it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.15it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 101.26it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.36it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 97.43it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.64it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 107.05it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.36it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 56.79it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.67it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 73.77it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.17it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 100.75it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.66it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 104.59it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.78it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 97.83it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.15it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 111.18it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 34.33it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 68.42it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 70.31it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 126.26it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 69.25it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 98.76it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 68.28it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 105.05it/s]
#   month  observed    x1.0  max_util_pct    x0.5    x0.3  delta
# 2022-01       0.0   47.30          29.5   47.30   47.30    0.0
# 2022-02       0.0   15.28          25.8   15.28   15.28    0.0
# 2022-03       2.6  271.63          41.3  271.63  271.63    0.0
# 2022-04       0.0  688.62          50.5  688.62  688.62    0.0
# 2022-05       0.0  187.58          44.2  187.58  187.58    0.0
# 2022-06       0.0  331.63          42.8  331.63  331.63    0.0
# 2022-07     350.6  591.89          44.2  591.89  591.89    0.0
# 2022-08     769.5  904.24          44.9  904.24  904.24    0.0
# 2022-09     429.3  591.57          42.1  591.57  591.57    0.0
# 2022-10     876.3  944.97          42.9  944.97  944.97    0.0
# 2022-11     109.6  118.74          30.9  118.74  118.74    0.0
# 2022-12       8.4   13.95          21.3   13.95   13.95    0.0
# 2023-01     174.5  175.62          31.7  175.62  175.62    0.0
# 2023-02     193.3  184.44          27.9  184.44  184.44    0.0
# 2023-03      32.6   29.45          29.2   29.45   29.45    0.0
# 2023-04     300.3  399.87          43.9  399.87  399.87    0.0
# 2023-05     645.3  655.59          45.4  655.59  655.59    0.0
# 2023-06     981.8 1038.81          51.4 1038.81 1038.81    0.0
# 2023-07     624.3  709.97          48.0  709.97  709.97    0.0
# 2023-08     363.5  367.38          37.4  367.38  367.38    0.0
# 2023-09     355.6  378.04          34.3  378.04  378.04    0.0
# 2023-10      83.1   88.17          29.8   88.17   88.17    0.0
# 2023-11      10.0   15.86          22.0   15.86   15.86    0.0
# 2023-12       1.1    3.07          20.4    3.07    3.07    0.0
# 2024-01      34.4   35.50          19.8   35.50   35.50    0.0
# 2024-02      56.9   60.98          22.2   60.98   60.98    0.0
# 2024-03     103.9  130.99          28.0  130.99  130.99    0.0
# 2024-04     680.6 1092.42          50.1 1092.42 1092.42    0.0
# 2024-05     202.5  486.48          43.5  486.48  486.48    0.0
# 2024-06     371.7  666.82          39.5  666.82  666.82    0.0
# 2024-07     452.8  993.17          45.0  993.17  993.17    0.0
# 2024-08     265.8  515.27          37.1  515.27  515.27    0.0
# 2024-09     600.8 1482.44          46.4 1482.44 1482.44    0.0
# 2024-10     214.2 1081.21          39.1 1081.21 1081.21    0.0
# 2024-11      47.2  586.30          37.1  586.30  586.30    0.0
#
# months changed by >1 MW/h at 30% derating: 0 of 35
# peak corridor utilisation across all crisis months: 51.4%
# (230s)
#
# >> NOTE: this sweep uses size_shedding=True, without which October 2022
#    is infeasible. Peak utilisation is therefore 51.4% here against 26.0% for
#    June 2023 in the as-shipped configuration above. Quote the right one.
#   table -> T5_transmission_all_months.csv

# %% [markdown]
# ## 6. Seasonality of the crisis regime
#
# Independent support for the central claim. A binding deliverable-capacity
# envelope predicts that shedding appears only once demand crosses it, so a
# moderate seasonal rise in demand produces a disproportionate rise in unserved
# energy. A shortfall of *installed* capacity would scale roughly with demand.

# %%
names = ["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"]
cr = df[df["datetime"].dt.year.between(2022,2024)].copy(); cr["mon"] = cr["datetime"].dt.month
rows = []
for mo in range(1,13):
    s = cr[cr["mon"]==mo]; sh = s[s["Loadshed"]>0]
    idle = sum((CAPS[t]-sh[t].fillna(0.0)).clip(lower=0) for t in THERMAL)
    rows.append(dict(month=names[mo-1], hours=len(s),
                     lolp_pct=round(100*float((s["Loadshed"]>0).mean()),1),
                     mean_shed_mw=round(float(s["Loadshed"].mean()),1),
                     mean_idle_mw=round(float(idle.mean()),0),
                     idle_gt_shed_pct=round(100*float((idle>sh["Loadshed"]).mean()),2),
                     mean_demand_mw=round(float(s["Demand"].mean()),0)))
seas = pd.DataFrame(rows); print(seas.to_string(index=False))
warm = seas[seas.month.isin(["Apr","May","Jun","Jul","Aug","Sep","Oct"])]
cool = seas[seas.month.isin(["Nov","Dec","Jan","Feb","Mar"])]
DEM_RATIO  = warm.mean_demand_mw.mean()/cool.mean_demand_mw.mean()
SHED_RATIO = warm.mean_shed_mw.mean()/cool.mean_shed_mw.mean()
print(f"\nwarm (Apr-Oct): LOLP {warm.lolp_pct.mean():.1f}%  shed {warm.mean_shed_mw.mean():.0f} MW"
      f"  demand {warm.mean_demand_mw.mean():,.0f} MW")
print(f"cool (Nov-Mar): LOLP {cool.lolp_pct.mean():.1f}%  shed {cool.mean_shed_mw.mean():.0f} MW"
      f"  demand {cool.mean_demand_mw.mean():,.0f} MW")
print(f"\ndemand ratio {DEM_RATIO:.2f}x  |  shedding ratio {SHED_RATIO:.1f}x")
print(">> Shedding is far more seasonal than demand.")
save_table(seas, "TS_seasonality")
# Out:
# month  hours  lolp_pct  mean_shed_mw  mean_idle_mw  idle_gt_shed_pct  mean_demand_mw
#   Jan   2232      20.4          69.6        7038.0            100.00          8112.0
#   Feb   2040      36.5          83.1        6474.0            100.00          8639.0
#   Mar   2232      33.3          46.4        5096.0            100.00         10233.0
#   Apr   2160      48.8         327.0        3429.0             97.63         12266.0
#   May   2232      47.2         282.6        3697.0             99.81         11571.0
#   Jun   2160      52.1         451.2        3685.0             99.91         12293.0
#   Jul   2232      70.0         475.9        3747.0            100.00         12659.0
#   Aug   2232      86.3         466.2        4142.0            100.00         12399.0
#   Sep   2160      82.0         461.9        4036.0            100.00         12642.0
#   Oct   2232      65.2         391.2        5057.0            100.00         11351.0
#   Nov   2034      17.8          56.1        6131.0            100.00          9320.0
#   Dec   1488       2.2           4.8        7081.0            100.00          8035.0
#
# warm (Apr-Oct): LOLP 64.5%  shed 408 MW  demand 12,169 MW
# cool (Nov-Mar): LOLP 22.0%  shed 52 MW  demand 8,868 MW
#
# demand ratio 1.37x  |  shedding ratio 7.8x
# >> Shedding is far more seasonal than demand.
#   table -> TS_seasonality.csv
# '/content/outputs/tables/TS_seasonality.csv'

# %% [markdown]
# ## 7. Payra event study
#
# The complete shutdown of the 1,320 MW Payra plant, 5–24 June 2023, caused by an
# unsettled USD 390 million letter of credit for imported coal, is documented
# independently of the operational record and falls inside a modelled period.
#
# A before/after comparison confounds the shutdown with everything else changing
# that month, so gas and liquid fuel — unaffected by Payra's coal LC — serve as
# controls.

# %%
pm = df[(df["datetime"]>="2023-04-15")&(df["datetime"]<"2023-08-01")].copy()
pm["day"] = pm["datetime"].dt.date
daily = pm.groupby("day")[["Coal","Gas","Liquid Fuel"]].mean()
pcf = daily.copy()
for t in pcf.columns: pcf[t] = daily[t]/NETCAP[t]
idx = pd.to_datetime(pd.Series(pcf.index))
post = ((idx>="2023-06-05")&(idx<="2023-06-24")).values

print("Window means of daily coal dispatch:")
for lab,(a,b) in {"pre-shutdown (1-24 May)":("2023-05-01","2023-05-24"),
                  "unit 1 halted (25 May-4 Jun)":("2023-05-25","2023-06-04"),
                  "FULL SHUTDOWN (5-24 Jun)":("2023-06-05","2023-06-24"),
                  "resumed (25 Jun-15 Jul)":("2023-06-25","2023-07-15")}.items():
    m = (idx>=a)&(idx<=b)
    print(f"  {lab:30s} {daily['Coal'].values[m].mean():7.0f} MW  "
          f"CF {pcf['Coal'].values[m].mean():.3f}")

raw = daily["Coal"].values[post].mean() - daily["Coal"].values[~post].mean()
tt = stats.ttest_ind(daily["Coal"].values[post], daily["Coal"].values[~post], equal_var=False)
print(f"\nRaw before/after: {raw:+.0f} MW (Welch t={tt.statistic:.2f}, p={tt.pvalue:.4g})")
print(f"  = {100*abs(raw)/1320:.0f}% of Payra's 1,320 MW nameplate")

ch = {t: float(pcf[t].values[post].mean()-pcf[t].values[~post].mean()) for t in pcf.columns}
print("\nCapacity-factor change, inside minus outside the window:")
for t,v in ch.items():
    print(f"  {t:13s} {v:+.3f}   {'<- treated' if t=='Coal' else '<- control'}")
DID = ch["Coal"] - np.mean([ch["Gas"], ch["Liquid Fuel"]])
DID_MW = DID*NETCAP["Coal"]; DID_PCT = 100*abs(DID_MW)/1320
print(f"\ncontrol mean change {np.mean([ch['Gas'],ch['Liquid Fuel']]):+.3f}")
print(f"DiD estimate        {DID:+.4f} CF  =  {DID_MW:+,.0f} MW  =  {DID_PCT:.0f}% of nameplate")

import statsmodels.formula.api as smf
lg = pcf.reset_index().melt(id_vars="day", var_name="carrier", value_name="cf")
lg["post"]  = ((pd.to_datetime(lg["day"])>="2023-06-05")&
               (pd.to_datetime(lg["day"])<="2023-06-24")).astype(int)
lg["treat"] = (lg["carrier"]=="Coal").astype(int)
fit = smf.ols("cf ~ treat*post + C(carrier) + C(day)", data=lg).fit(
    cov_type="cluster", cov_kwds={"groups": lg["carrier"]})
OLS_B, OLS_SE, OLS_P = (float(fit.params["treat:post"]), float(fit.bse["treat:post"]),
                        float(fit.pvalues["treat:post"]))
print(f"\nOLS, carrier and day fixed effects, clustered by carrier:")
print(f"  treat x post = {OLS_B:+.4f}  (se {OLS_SE:.4f}, p {OLS_P:.4g})  = {OLS_B*NETCAP['Coal']:+,.0f} MW")
print("\n>> Gas and liquid fuel ROSE during the window - the system substituted, which")
print("   is why the raw comparison understates. Residual attenuation remains because")
print("   the record is aggregated by fuel, so other coal plants sit inside the treated")
print("   group. Report as corroborating evidence, NOT as independent validation.")
save_table(pd.DataFrame([dict(raw_mw=round(raw,0), did_cf=round(DID,4),
                              did_mw=round(DID_MW,0), pct_of_payra=round(DID_PCT,0),
                              ols_coef=round(OLS_B,4), ols_se=round(OLS_SE,4),
                              ols_p=OLS_P)]), "TS_payra_did")
# Out:
# Window means of daily coal dispatch:
#   pre-shutdown (1-24 May)           2124 MW  CF 0.513
#   unit 1 halted (25 May-4 Jun)      2093 MW  CF 0.505
#   FULL SHUTDOWN (5-24 Jun)          1739 MW  CF 0.420
#   resumed (25 Jun-15 Jul)           1658 MW  CF 0.400
#
# Raw before/after: -301 MW (Welch t=-4.77, p=9.323e-06)
#   = 23% of Payra's 1,320 MW nameplate
#
# Capacity-factor change, inside minus outside the window:
#   Coal          -0.073   <- treated
#   Gas           +0.068   <- control
#   Liquid Fuel   +0.042   <- control
#
# control mean change +0.055
# DiD estimate        -0.1278 CF  =  -530 MW  =  40% of nameplate
#
# OLS, carrier and day fixed effects, clustered by carrier:
#   treat x post = -0.1278  (se 0.0140, p 8.004e-20)  = -530 MW
#
# >> Gas and liquid fuel ROSE during the window - the system substituted, which
#    is why the raw comparison understates. Residual attenuation remains because
#    the record is aggregated by fuel, so other coal plants sit inside the treated
#    group. Report as corroborating evidence, NOT as independent validation.
#   table -> TS_payra_did.csv
# '/content/outputs/tables/TS_payra_did.csv'

# %% [markdown]
# ## 8. Reliability metrics

# %%
EPS_LOLE, HOURS_YR = 1.0, 8760.0
def reliability(sv, n=None):
    s = pd.Series(sv).astype(float); n = len(s) if n is None else n
    lole = int((s>EPS_LOLE).sum()); eens = float(s.clip(lower=0).sum()); sc = HOURS_YR/n
    return dict(hours=n, LOLE_h=lole, LOLP_pct=round(100*(s>EPS_LOLE).mean(),2),
                EENS_MWh=round(eens,0), LOLE_h_yr=round(lole*sc,0),
                EENS_GWh_yr=round(eens*sc/1000,1))

rel = []
for lab, mk in [("2015-2021 pre-crisis", df["datetime"].dt.year.between(2015,2021)),
                ("2022-2024 crisis",     df["datetime"].dt.year.between(2022,2024))]:
    r = reliability(df.loc[mk,"Loadshed"].values); r["period"] = lab; rel.append(r)
for y, g in df.groupby(df["datetime"].dt.year):
    r = reliability(g["Loadshed"].values); r["period"] = str(int(y)); rel.append(r)
rel = pd.DataFrame(rel)[["period","hours","LOLE_h","LOLP_pct","EENS_MWh","EENS_GWh_yr"]]
print(rel.to_string(index=False))
save_table(rel, "TS_reliability")
# Out:
#               period  hours  LOLE_h  LOLP_pct  EENS_MWh  EENS_GWh_yr
# 2015-2021 pre-crisis  58752      86      0.15   25757.0          3.8
#     2022-2024 crisis  25434   12289     48.32 6834851.0       2354.1
#                 2015   6144      21      0.34    7468.0         10.6
#                 2016   8784      34      0.39    7309.0          7.3
#                 2017   8760       4      0.05     202.0          0.2
#                 2018   8760      10      0.11    3307.0          3.3
#                 2019   8760      10      0.11    2548.0          2.5
#                 2020   8784       4      0.05    4320.0          4.3
#                 2021   8760       3      0.03     603.0          0.6
#                 2022   8760    2281     26.04 1881471.0       1881.5
#                 2023   8760    4988     56.94 2747996.0       2748.0
#                 2024   7914    5020     63.43 2205384.0       2441.1
#   table -> TS_reliability.csv
# '/content/outputs/tables/TS_reliability.csv'

# %% [markdown]
# ## 9. Reconstruction fidelity and the model boundary
#
# Given the closed-form reduction in §3.2, the correspondence between modelled and
# observed shedding is near-algebraic. It is reported here as a **diagnostic of
# the model boundary**, not as validation. The residual has a single identifiable
# source: hours in which observed dispatch exceeded the assumed nameplate, where
# the calibration clips.

# %%
val = []
for ym, label in [("2016-12","Adequate"),("2022-08","Crisis"),
                  ("2023-06","Crisis"),("2023-08","Crisis (recon.)")]:
    mdf = slice_month(ym)
    r = shed_stats(build_month_network(base, mdf), mdf); r.update(period=ym, state=label)
    clip = {t: float((mdf[t].fillna(0.0)-NETCAP[t]).clip(lower=0).sum()) for t in TECHS}
    r["clipped_MWh"] = round(sum(clip.values()),0)
    r["clipped_MW_per_h"] = round(sum(clip.values())/len(mdf),1)
    r["dominant_carrier"] = max(clip, key=clip.get)
    val.append(r)
val_df = pd.DataFrame(val)[["period","state","obs","model","bias","mae","rmse","corr",
                            "clipped_MWh","clipped_MW_per_h","dominant_carrier"]]
print(val_df.to_string(index=False))
print("\n>> Clipped energy accounts for the positive bias almost exactly. The weaker")
print("   August 2022 correspondence is a capacity-vintage artefact, not a failure of")
print("   the availability representation.")
print("\nObserved dispatch above assumed nameplate, full record:")
for t in TECHS:
    n_over = int((df[t].fillna(0.0)>NETCAP[t]).sum())
    print(f"  {t:13s} assumed {NETCAP[t]:7.0f} | max {df[t].max():7.0f} | "
          f"hours over {n_over:5,d} ({100*n_over/len(df):4.2f}%)")
save_table(val_df, "T2_reconstruction_fidelity")
# Out:
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.89it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 122.82it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.69it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 124.07it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 41.43it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 92.55it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.14it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 115.98it/s]
#  period           state    obs   model   bias    mae   rmse  corr  clipped_MWh  clipped_MW_per_h dominant_carrier
# 2016-12        Adequate   0.00    6.18   6.18   6.18  53.30   NaN        829.0               1.1              Gas
# 2022-08          Crisis 769.49  904.24 134.74 158.75 357.44 0.811     110976.0             149.2      Liquid Fuel
# 2023-06          Crisis 981.84 1038.81  56.97  79.24 169.63 0.984      56947.0              79.1              Gas
# 2023-08 Crisis (recon.) 363.45  367.38   3.93  13.18  65.63 0.987       3173.0               4.3      Liquid Fuel
#
# >> Clipped energy accounts for the positive bias almost exactly. The weaker
#    August 2022 correspondence is a capacity-vintage artefact, not a failure of
#    the availability representation.
#
# Observed dispatch above assumed nameplate, full record:
#   Gas           assumed    6644 | max    8114 | hours over 4,196 (4.98%)
#   Coal          assumed    4144 | max    5657 | hours over 1,653 (1.96%)
#   Liquid Fuel   assumed    3995 | max    6175 | hours over 3,937 (4.68%)
#   Import        assumed    1093 | max    2467 | hours over 4,076 (4.84%)
#   Hydro         assumed     211 | max     230 | hours over 4,023 (4.78%)
#   Solar         assumed     391 | max     998 | hours over 1,027 (1.22%)
#   Wind          assumed      29 | max      63 | hours over 1,051 (1.25%)
#   table -> T2_reconstruction_fidelity.csv
# '/content/outputs/tables/T2_reconstruction_fidelity.csv'

# %% [markdown]
# ## 10. Ablation

# %%
def build_ablation(mdf, config):
    n = build_month_network(base, mdf)
    if config == "IC":
        for g in n.generators.index:
            if n.generators.loc[g,"carrier"] in ["Gas","Coal","Liquid Fuel","Import"]:
                n.generators_t.p_max_pu[g] = 1.0
    elif config == "no_LF":
        for g in n.generators.index:
            if n.generators.loc[g,"carrier"] == "Liquid Fuel":
                n.generators_t.p_max_pu[g] = 1.0
    return n

abl = []
for ym in PERIODS:
    mdf = slice_month(ym)
    for cfg in ["IC","no_LF","full"]:
        r = shed_stats(build_ablation(mdf,cfg), mdf); r.update(period=ym, config=cfg)
        abl.append(r)
abl_df = pd.DataFrame(abl)[["period","config","obs","model","bias","mae","corr"]]
print(abl_df.to_string(index=False))
print("\n>> A capacity-based model is structurally blind to this crisis: with the")
print("   availability constraint removed it predicts essentially no shedding in")
print("   every period, including those in which thousands of MW were shed.")
save_table(abl_df, "T3_ablation")
# Out:
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.94it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 123.63it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.35it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 114.61it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.70it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 124.45it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.13it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 117.37it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 39.58it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 65.24it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.69it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 112.65it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.30it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 122.99it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 64.59it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 133.00it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.27it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 118.08it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.94it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 120.72it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 39.69it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 78.05it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.51it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 116.88it/s]
#  period config    obs   model    bias    mae   corr
# 2016-12     IC   0.00    0.00    0.00   0.00    NaN
# 2016-12  no_LF   0.00    0.00    0.00   0.00    NaN
# 2016-12   full   0.00    6.18    6.18   6.18    NaN
# 2022-08     IC 769.49    0.00 -769.49 769.49    NaN
# 2022-08  no_LF 769.49  478.46 -291.03 582.67  0.420
# 2022-08   full 769.49  904.24  134.74 158.75  0.811
# 2023-06     IC 981.84    0.91 -980.93 980.93 -0.000
# 2023-06  no_LF 981.84  282.12 -699.71 763.91  0.554
# 2023-06   full 981.84 1038.81   56.97  79.24  0.984
# 2023-08     IC 363.45    0.00 -363.45 363.45    NaN
# 2023-08  no_LF 363.45   14.81 -348.64 354.46  0.046
# 2023-08   full 363.45  367.38    3.93  13.18  0.987
#
# >> A capacity-based model is structurally blind to this crisis: with the
#    availability constraint removed it predicts essentially no shedding in
#    every period, including those in which thousands of MW were shed.
#   table -> T3_ablation.csv
# '/content/outputs/tables/T3_ablation.csv'

# %% [markdown]
# ## 11. Out-of-sample validation
#
# This is the paper's actual validation. Availability profiles are estimated by
# hour of day on training folds and applied to held-out hours, so the held-out
# hours' own dispatch is never used.
#
# Three null models bound the interpretation, and a strictly forward-only
# protocol addresses the fact that contiguous folds place both earlier and later
# periods in the training set.

# %%
def tech_avail_hod(w):
    out = {}
    for t in TECHS:
        cap = NETCAP.get(t, 0.0)
        cf = ((pd.to_numeric(w[t],errors="coerce").fillna(0.0)/cap).clip(0,1)
              if cap > 0 else pd.Series(0.0, index=w.index))
        out[t] = cf.groupby(w.index.hour).mean()
    return out

def build_avail(mdf, avail):
    n = fresh_network(base); n.set_snapshots(mdf.index)
    dem = pd.to_numeric(mdf["Demand"],errors="coerce").fillna(0.0)
    for L in n.loads.index: n.loads_t.p_set[L] = dem.values*base_load_shares.get(L,0.0)
    hod = pd.Series(mdf.index.hour)
    for t in TECHS:
        gens = [g for g in n.generators.index if n.generators.loc[g,"carrier"]==t]
        if not gens: continue
        prof = avail[t]; arr = np.clip(hod.map(prof).fillna(prof.mean()).values,0,1)
        for g in gens: n.generators_t.p_max_pu[g] = arr
    for g in _shed_gens(n): n.generators_t.p_max_pu[g] = np.full(len(mdf),1.0)
    return n

def score(n, mdf):
    model_shed_series(n)
    c = pd.DataFrame({"m": n.generators_t.p[_shed_gens(n)].sum(axis=1),
                      "o": mdf["Loadshed"].reindex(n.snapshots)}).dropna()
    dd = c["m"]-c["o"]
    return dict(obs=round(c["o"].mean(),1), model=round(c["m"].mean(),1),
                mae=round(dd.abs().mean(),1),
                corr=round(c["m"].corr(c["o"]),3) if c["o"].std()>0 else np.nan,
                eens_o=int(c["o"].clip(lower=0).sum()), eens_m=int(c["m"].clip(lower=0).sum()),
                pairs=c)

OOS_CAPTURE = {}
def rolling_origin(Mw, K=5, capture_key=None):
    n = len(Mw); b = [round(i*n/K) for i in range(K+1)]
    res, mm, oo, rs = [], [], [], []
    for k in range(K):
        te = Mw.iloc[b[k]:b[k+1]]; trw = pd.concat([Mw.iloc[:b[k]], Mw.iloc[b[k+1]:]])
        if len(te) < 24 or te["Loadshed"].std() == 0: continue
        s = score(build_avail(te, tech_avail_hod(trw)), te); c = s.pop("pairs")
        s["fold"] = k; s["ratio"] = round(s["model"]/s["obs"],2) if s["obs"]>0 else np.nan
        res.append(s)
        if not np.isnan(s["corr"]): rs.append(s["corr"])
        mm += list(c["m"]); oo += list(c["o"])
    if capture_key:
        OOS_CAPTURE[capture_key] = dict(model=np.array(mm), obs=np.array(oo), fold_r=rs,
                                        pooled_r=float(np.corrcoef(mm,oo)[0,1]))
    return pd.DataFrame(res)

oos_folds = {}
for nm, ym in [("Jun2023","2023-06"),("Aug2023","2023-08")]:
    r = rolling_origin(slice_month(ym), K=5, capture_key=nm); oos_folds[nm] = r
    cc = pd.Series(OOS_CAPTURE[nm]["fold_r"])
    print(f"\n{nm} rolling-origin, K=5 contiguous folds:")
    print(r[["fold","obs","model","ratio","mae","corr"]].to_string(index=False))
    print(f"  median r={cc.median():.3f} (min {cc.min():.3f}, max {cc.max():.3f}) | "
          f"pooled r={OOS_CAPTURE[nm]['pooled_r']:.3f}")
save_table(pd.concat([v.assign(month=k) for k,v in oos_folds.items()]), "TS_oos_folds")
# Out:
# Jun2023 rolling-origin, K=5 contiguous folds:
#  fold    obs  model  ratio   mae  corr
#     0 2133.6 2963.7   1.39 838.5 0.775
#     1  993.3 1636.4   1.65 661.1 0.913
#     2  793.9 1096.5   1.38 362.0 0.845
#     3  603.3 1025.0   1.70 449.2 0.634
#     4  385.0  375.5   0.98  64.4 0.976
#   median r=0.845 (min 0.634, max 0.976) | pooled r=0.919
#
# Aug2023 rolling-origin, K=5 contiguous folds:
#  fold   obs  model  ratio   mae  corr
#     0 329.0  540.3   1.64 301.0 0.852
#     1 168.4   61.9   0.37 127.7 0.622
#     2 412.1  530.2   1.29 176.9 0.896
#     3 552.3  954.2   1.73 418.4 0.854
#     4 355.7  894.5   2.51 564.6 0.694
#   median r=0.852 (min 0.622, max 0.896) | pooled r=0.783
#   table -> TS_oos_folds.csv
# '/content/outputs/tables/TS_oos_folds.csv'

# %% [markdown]
# ### 11.1 Null models and a forward-only protocol
#
# **Specification D matters.** An aggregate hour-of-day profile with no technology
# disaggregation reproduces A exactly. What the test validates is the availability
# *envelope*, not the technology attribution.

# %%
def _hod(tr, per_tech=True):
    if per_tech:
        tot = np.zeros(24)
        for t in TECHS:
            cf = (tr[t].fillna(0.0)/NETCAP[t]).clip(0,1)
            tot += cf.groupby(tr.index.hour).mean().reindex(range(24)).values*NETCAP[t]
        return tot
    g = available(tr)
    return g.groupby(tr.index.hour).mean().reindex(range(24)).values

NAMES = {"A":"per-technology hour-of-day [as specified]",
         "B":"constant capacity (null)", "C":"demand only (null)",
         "D":"aggregate hour-of-day (null)"}
rows = []
for ym in ["2023-06","2023-08"]:
    M = slice_month(ym); n = len(M); b = [round(i*n/5) for i in range(6)]
    acc = {k: [] for k in NAMES}; obs = []
    fwd = {"A":([],[]), "D":([],[])}
    for k in range(5):
        te = M.iloc[b[k]:b[k+1]]; tr = pd.concat([M.iloc[:b[k]], M.iloc[b[k+1]:]])
        if len(te) < 24 or te["Loadshed"].std() == 0: continue
        D_, O, h = te["Demand"].values, te["Loadshed"].values, te.index.hour.values
        acc["A"] += list(np.clip(D_-_hod(tr)[h],0,None))
        acc["B"] += list(np.clip(D_-available(tr).mean(),0,None))
        acc["C"] += list(D_)
        acc["D"] += list(np.clip(D_-_hod(tr,False)[h],0,None))
        obs += list(O)
        if k > 0:
            trf = M.iloc[:b[k]]
            fwd["A"][0].extend(np.clip(D_-_hod(trf)[h],0,None)); fwd["A"][1].extend(O)
            fwd["D"][0].extend(np.clip(D_-_hod(trf,False)[h],0,None)); fwd["D"][1].extend(O)
    o = np.array(obs)
    for k, v in acc.items():
        m = np.array(v)
        rows.append(dict(month=ym, protocol="rolling-origin", spec=NAMES[k],
                         r=round(float(np.corrcoef(m,o)[0,1]),3),
                         mae=round(float(np.abs(m-o).mean()),1),
                         bias=round(float((m-o).mean()),1),
                         rmse=round(float(np.sqrt(((m-o)**2).mean())),1)))
    for k, (mv, ov) in fwd.items():
        m, oo2 = np.array(mv), np.array(ov)
        rows.append(dict(month=ym, protocol="forward-only", spec=NAMES[k],
                         r=round(float(np.corrcoef(m,oo2)[0,1]),3),
                         mae=round(float(np.abs(m-oo2).mean()),1),
                         bias=round(float((m-oo2).mean()),1),
                         rmse=round(float(np.sqrt(((m-oo2)**2).mean())),1)))
oos_null = pd.DataFrame(rows)
print(oos_null.to_string(index=False))
print("\n>> A beats B and C clearly: there is real skill beyond 'shedding tracks demand'.")
print(">> A ties D exactly: the technology split adds nothing to timing skill.")
print(">> Forward-only skill is comparable, and in June 2023 more accurate in magnitude.")
save_table(oos_null, "T4_out_of_sample")
# Out:
#   month       protocol                                      spec     r     mae    bias    rmse
# 2023-06 rolling-origin per-technology hour-of-day [as specified] 0.919   475.0   437.6   648.2
# 2023-06 rolling-origin                  constant capacity (null) 0.749   617.2   452.6   956.0
# 2023-06 rolling-origin                        demand only (null) 0.703 11491.9 11491.9 11572.7
# 2023-06 rolling-origin              aggregate hour-of-day (null) 0.919   475.0   437.6   648.2
# 2023-06   forward-only per-technology hour-of-day [as specified] 0.906   214.8   -31.4   327.2
# 2023-06   forward-only              aggregate hour-of-day (null) 0.906   214.8   -31.4   327.2
# 2023-08 rolling-origin per-technology hour-of-day [as specified] 0.783   317.9   232.9   469.9
# 2023-08 rolling-origin                  constant capacity (null) 0.494   513.6   362.9   809.0
# 2023-08 rolling-origin                        demand only (null) 0.522 12206.0 12206.0 12255.2
# 2023-08 rolling-origin              aggregate hour-of-day (null) 0.783   317.9   232.9   469.9
# 2023-08   forward-only per-technology hour-of-day [as specified] 0.763   388.9   317.8   544.6
# 2023-08   forward-only              aggregate hour-of-day (null) 0.763   388.9   317.8   544.6
#
# >> A beats B and C clearly: there is real skill beyond 'shedding tracks demand'.
# >> A ties D exactly: the technology split adds nothing to timing skill.
# >> Forward-only skill is comparable, and in June 2023 more accurate in magnitude.
#   table -> T4_out_of_sample.csv
# '/content/outputs/tables/T4_out_of_sample.csv'

# %% [markdown]
# ### 11.2 Sensitivity to the fold count
#
# The K = 5 split is arbitrary. Pooled skill should not depend on it.

# %%
rows = []
for nm, ym in [("Jun2023","2023-06"), ("Aug2023","2023-08")]:
    Mw = slice_month(ym)
    print(f"{nm}:")
    for K in [4,5,6,8]:
        n = len(Mw); b = [round(i*n/K) for i in range(K+1)]
        mm, oo, rs = [], [], []
        for k in range(K):
            te = Mw.iloc[b[k]:b[k+1]]; trw = pd.concat([Mw.iloc[:b[k]], Mw.iloc[b[k+1]:]])
            if len(te) < 24 or te["Loadshed"].std() == 0: continue
            s = score(build_avail(te, tech_avail_hod(trw)), te); c = s.pop("pairs")
            if c["o"].std() > 0:
                rs.append(c["m"].corr(c["o"])); mm += list(c["m"]); oo += list(c["o"])
        med = float(np.median(rs)) if rs else np.nan
        pooled = float(np.corrcoef(mm, oo)[0,1])
        rows.append(dict(month=ym, K=K, folds=len(rs),
                         median_fold_r=round(med,3) if np.isfinite(med) else np.nan,
                         pooled_r=round(pooled,3)))
        print(f"  K={K}: median fold r={med:.3f} | pooled OOS r={pooled:.3f} | folds={len(rs)}")
fold_sens = pd.DataFrame(rows)
print("\n>> Pooled skill is stable across fold counts; the median fold correlation is")
print("   noisier because individual folds are short. Report the pooled figure.")
save_table(fold_sens, "TS_oos_fold_count")
# Out:
# Jun2023:
#   K=4: median fold r=0.762 | pooled OOS r=0.917 | folds=4
#   K=5: median fold r=0.845 | pooled OOS r=0.919 | folds=5
#   K=6: median fold r=0.729 | pooled OOS r=0.923 | folds=6
#   K=8: median fold r=nan | pooled OOS r=0.926 | folds=8
# Aug2023:
#   K=4: median fold r=0.756 | pooled OOS r=0.794 | folds=4
#   K=5: median fold r=0.852 | pooled OOS r=0.783 | folds=5
#   K=6: median fold r=0.714 | pooled OOS r=0.784 | folds=6
#   K=8: median fold r=0.705 | pooled OOS r=0.782 | folds=8
#
# >> Pooled skill is stable across fold counts; the median fold correlation is
#    noisier because individual folds are short. Report the pooled figure.
#   table -> TS_oos_fold_count.csv
# '/content/outputs/tables/TS_oos_fold_count.csv'

# %% [markdown]
# ### 11.3 Negative results — what does **not** predict the crisis
#
# Reported because they matter. No exogenous or autoregressive specification
# trained on the pre-crisis record achieves positive out-of-sample skill. The
# crisis is not forecastable from demand, seasonality or its own history; it
# required the availability information.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import r2_score, mean_absolute_error

g = df.copy(); g["ym"] = g["datetime"].dt.to_period("M"); g["month"] = g["datetime"].dt.month
Mp = g.groupby("ym").agg(shed=("Loadshed","mean"), demand=("Demand","mean"),
                         dpeak=("Demand","max"), month=("month","first")).reset_index()
Mp["is_summer"] = Mp["month"].isin([4,5,6,7,8,9]).astype(int)
Mp["year"] = Mp["ym"].dt.year
FEAT = ["demand","dpeak","is_summer"]

print("=== Hard test: train on pre-2022, forecast the crisis ===")
hard = []
tr = Mp["year"] <= 2021; te = Mp["year"] >= 2022
for name, mdl in [("Linear", LinearRegression()),
                  ("RandomForest", RandomForestRegressor(300, random_state=SEED))]:
    mdl.fit(Mp.loc[tr, FEAT], Mp.loc[tr,"shed"])
    r2 = r2_score(Mp.loc[te,"shed"], mdl.predict(Mp.loc[te, FEAT]))
    hard.append(dict(test="pre-2022 -> crisis", model=name, r2=round(r2,3)))
    print(f"  {name:14s}: out-of-sample R2 = {r2:.3f}")
try:
    from statsmodels.tsa.statespace.sarimax import SARIMAX
    ser = Mp.set_index(Mp["ym"].dt.to_timestamp())["shed"]
    trn = ser[ser.index < "2022-01-01"]; tst = ser[ser.index >= "2022-01-01"]
    fit = SARIMAX(trn, order=(1,0,1), seasonal_order=(1,0,1,12),
                  enforce_stationarity=False, enforce_invertibility=False).fit(disp=False)
    r2 = r2_score(tst, fit.forecast(len(tst)))
    hard.append(dict(test="pre-2022 -> crisis", model="SARIMAX", r2=round(r2,3)))
    print(f"  {'SARIMAX':14s}: out-of-sample R2 = {r2:.3f}")
except Exception as e:
    print("  SARIMAX skipped:", str(e)[:60])

print(f"\n=== Expanding-window (forward-chaining) CV, 5 splits, n = {len(Mp)} months ===")
Mp["shed_l1"] = Mp["shed"].shift(1); Mp["shed_l2"] = Mp["shed"].shift(2)
Mp["shed_m3"] = Mp["shed"].rolling(3).mean().shift(1)
Mq = Mp.dropna().reset_index(drop=True)
SPECS = [("Linear (exogenous)", LinearRegression(), FEAT),
         ("Gradient boosting (exogenous)", GradientBoostingRegressor(random_state=SEED), FEAT),
         ("Random forest (exogenous)", RandomForestRegressor(300, random_state=SEED), FEAT),
         ("AR(1)", LinearRegression(), ["shed_l1"]),
         ("AR(1,2) + 3-month mean", LinearRegression(), ["shed_l1","shed_l2","shed_m3"]),
         ("Exogenous + AR terms", LinearRegression(), FEAT+["shed_l1","shed_l2","shed_m3"])]
tss = TimeSeriesSplit(n_splits=5); fc_rows = []
for name, mdl, feats in SPECS:
    r2s, maes = [], []
    for itr, ite in tss.split(Mq):
        m = mdl.__class__(**mdl.get_params())
        m.fit(Mq.loc[itr, feats], Mq.loc[itr,"shed"])
        p = m.predict(Mq.loc[ite, feats])
        r2s.append(r2_score(Mq.loc[ite,"shed"], p))
        maes.append(mean_absolute_error(Mq.loc[ite,"shed"], p))
    fc_rows.append(dict(spec=name, r2_mean=round(float(np.mean(r2s)),3),
                        r2_sd=round(float(np.std(r2s)),3),
                        mae_mw=round(float(np.mean(maes)),1)))
    print(f"  {name:34s}: R2 = {np.mean(r2s):7.3f} +/- {np.std(r2s):6.3f}   "
          f"MAE = {np.mean(maes):6.1f} MW")
forward_cv = pd.DataFrame(fc_rows)
print("\n>> Every specification has NEGATIVE out-of-sample R2. Reported as a negative")
print("   result: the crisis is not predictable from demand, season or its own history.")
save_table(forward_cv, "TS_forward_chaining_cv")
save_table(pd.DataFrame(hard), "TS_hard_forecast_test")
# Out:
# === Hard test: train on pre-2022, forecast the crisis ===
#   Linear        : out-of-sample R2 = -0.916
#   RandomForest  : out-of-sample R2 = -0.915
#   SARIMAX       : out-of-sample R2 = -0.914
#
# === Expanding-window (forward-chaining) CV, 5 splits, n = 116 months ===
#   Linear (exogenous)                : R2 =  -0.560 +/-  0.641   MAE =   80.2 MW
#   Gradient boosting (exogenous)     : R2 =  -0.802 +/-  0.943   MAE =   79.8 MW
#   Random forest (exogenous)         : R2 =  -0.399 +/-  0.475   MAE =   75.5 MW
#   AR(1)                             : R2 =  -0.182 +/-  0.236   MAE =   77.0 MW
#   AR(1,2) + 3-month mean            : R2 =  -0.245 +/-  0.260   MAE =   76.7 MW
#   Exogenous + AR terms              : R2 =  -0.531 +/-  0.571   MAE =   75.0 MW
#
# >> Every specification has NEGATIVE out-of-sample R2. Reported as a negative
#    result: the crisis is not predictable from demand, season or its own history.
#   table -> TS_forward_chaining_cv.csv
#   table -> TS_hard_forecast_test.csv
# '/content/outputs/tables/TS_hard_forecast_test.csv'

# %% [markdown]
# ### 11.4 An excluded test, and why
#
# A pre-crisis-trained availability profile would be the cleanest exogeneity
# test. It is **excluded**, and both reasons are computed here rather than
# asserted.

# %%
_pre = df[df["datetime"].dt.year.between(2015,2021)].copy()
_pre["hod"] = _pre["datetime"].dt.hour
_prof_pre = {}
for t in TECHS:
    cap = NETCAP.get(t, 0.0)
    cf = ((pd.to_numeric(_pre[t],errors="coerce").fillna(0.0)/cap).clip(0,1)
          if cap > 0 else pd.Series(0.0, index=_pre.index))
    _prof_pre[t] = cf.groupby(_pre["hod"]).mean()

_avail_hod = sum(NETCAP[t]*_prof_pre[t] for t in TECHS)
_ceiling   = _avail_hod + LS_TOTAL
print("Test C - exogeneity via pre-crisis-trained availability: EXCLUDED.\n")
print("Reason 1: the linear program is infeasible.")
print(f"  Pre-crisis available capacity by hour of day: "
      f"{_avail_hod.min():,.0f} to {_avail_hod.max():,.0f} MW")
print(f"  Virtual shedding fleet: {LS_TOTAL:,.0f} MW")
print(f"  Feasibility ceiling:    {_ceiling.min():,.0f} to {_ceiling.max():,.0f} MW")
_tc = []
for ym in ["2023-06","2023-08"]:
    m = slice_month(ym).copy(); m["hod"] = m.index.hour
    n_inf = int((m["Demand"] > m["hod"].map(_ceiling)).sum())
    _tc.append(dict(period=ym, hours=len(m), infeasible_hours=n_inf,
                    share_pct=round(100*n_inf/len(m),1)))
    print(f"  {ym}: demand exceeds the ceiling in {n_inf} of {len(m)} hours")
testc_infeasible = pd.DataFrame(_tc)

print("\nReason 2: fleet-growth confound.")
print("  Pre-crisis mean capacity factor against present-day installed capacity:")
_cf_pre = {}
for t in TECHS:
    cap = NETCAP.get(t, 0.0)
    _cf_pre[t] = (float((pd.to_numeric(_pre[t],errors="coerce").fillna(0.0)/cap)
                        .clip(0,1).mean()) if cap > 0 else np.nan)
    print(f"    {t:12s}: {_cf_pre[t]:.3f}")
print("  Coal and imports expanded after 2021, so a low pre-crisis factor reflects fleet")
print("  size at the time rather than unavailability. The profile is not a valid")
print("  counterfactual, and this is the same finite-shedding-fleet limit noted in §3.1.")
save_table(testc_infeasible, "TS_excluded_test_diagnostics")
# Out:
# Test C - exogeneity via pre-crisis-trained availability: EXCLUDED.
#
# Reason 1: the linear program is infeasible.
#   Pre-crisis available capacity by hour of day: 6,589 to 9,014 MW
#   Virtual shedding fleet: 5,366 MW
#   Feasibility ceiling:    11,954 to 14,380 MW
#   2023-06: demand exceeds the ceiling in 287 of 720 hours
#   2023-08: demand exceeds the ceiling in 261 of 744 hours
#
# Reason 2: fleet-growth confound.
#   Pre-crisis mean capacity factor against present-day installed capacity:
#     Gas         : 0.758
#     Coal        : 0.067
#     Liquid Fuel : 0.383
#     Import      : 0.601
#     Hydro       : 0.472
#     Solar       : 0.016
#     Wind        : 0.000
#   Coal and imports expanded after 2021, so a low pre-crisis factor reflects fleet
#   size at the time rather than unavailability. The profile is not a valid
#   counterfactual, and this is the same finite-shedding-fleet limit noted in §3.1.
#   table -> TS_excluded_test_diagnostics.csv
# '/content/outputs/tables/TS_excluded_test_diagnostics.csv'

# %% [markdown]
# ## 12. Interventions
#
# **Three counterfactuals, not one.** Capacity that inherits the calibrated
# availability profile shares the fuel constraint binding the existing fleet — it
# is *not* fuel-secured. Reporting only that specification confuses two different
# counterfactuals.
#
# Computed for **all 35 crisis months**, not selected periods.

# %%
ADD = 500.0
rows = []
for ym in crisis_months():
    mdf = slice_month(ym)
    if len(mdf) < 24: continue
    av = available(mdf); b = (mdf["Demand"]-av).clip(lower=0).mean()
    r = dict(month=ym, base=round(float(b),2))
    for t in DISPATCHABLE:
        cf = (mdf[t].fillna(0.0)/NETCAP[t]).clip(0,1)
        r[f"{t}_inherits"] = round(float(
            (b-(mdf["Demand"]-(av+ADD*cf)).clip(lower=0).mean())/ADD),4)
        r[f"{t}_flat"] = round(float(
            (b-(mdf["Demand"]-(av+ADD*cf.mean())).clip(lower=0).mean())/ADD),4)
    r["secured"] = round(float((b-(mdf["Demand"]-(av+ADD)).clip(lower=0).mean())/ADD),4)
    rows.append(r)
interv = pd.DataFrame(rows)
show = ["month","base"]+[f"{t}_inherits" for t in DISPATCHABLE]+["secured"]
print(interv[show].to_string(index=False))
save_table(interv, "T6_interventions_all_months")
# Out:
#   month    base  Gas_inherits  Coal_inherits  Liquid Fuel_inherits  Import_inherits  Hydro_inherits  secured
# 2022-01   47.30        0.0527         0.0180                0.0743           0.0623          0.0401   0.0775
# 2022-02   15.28        0.0248         0.0093                0.0264           0.0260          0.0135   0.0292
# 2022-03  271.63        0.2409         0.0640                0.2930           0.2559          0.1064   0.2939
# 2022-04  688.62        0.4623         0.1196                0.5322           0.5310          0.1794   0.5344
# 2022-05  187.58        0.1823         0.0648                0.1953           0.1966          0.0504   0.2034
# 2022-06  331.63        0.2991         0.0992                0.3395           0.3299          0.1209   0.3406
# 2022-07  591.89        0.4762         0.1666                0.5165           0.5210          0.3484   0.5610
# 2022-08  904.24        0.7451         0.2660                0.7425           0.8319          0.5560   0.8557
# 2022-09  591.57        0.4672         0.2037                0.5198           0.5294          0.4108   0.5441
# 2022-10  944.97        0.5708         0.1780                0.5592           0.7147          0.5324   0.7281
# 2022-11  118.74        0.1524         0.0610                0.1491           0.1889          0.1131   0.1938
# 2022-12   13.95        0.0171         0.0131                0.0153           0.0178          0.0135   0.0180
# 2023-01  175.62        0.2259         0.1181                0.1568           0.2567          0.0623   0.2833
# 2023-02  184.44        0.2653         0.1702                0.1872           0.3030          0.0896   0.3207
# 2023-03   29.45        0.0565         0.0514                0.0528           0.0568          0.0312   0.0570
# 2023-04  399.87        0.3596         0.2535                0.3422           0.3629          0.0394   0.3862
# 2023-05  655.59        0.4847         0.3357                0.3747           0.5298          0.0468   0.5511
# 2023-06 1038.81        0.7301         0.3592                0.4667           0.7306          0.1358   0.7466
# 2023-07  709.97        0.7029         0.4296                0.5176           0.7038          0.2552   0.7229
# 2023-08  367.38        0.4657         0.4273                0.3161           0.4723          0.4487   0.4944
# 2023-09  378.04        0.5097         0.4982                0.3186           0.5233          0.5185   0.5412
# 2023-10   88.17        0.1656         0.1622                0.1187           0.1677          0.1619   0.1696
# 2023-11   15.86        0.0296         0.0296                0.0210           0.0302          0.0293   0.0303
# 2023-12    3.07        0.0048         0.0046                0.0026           0.0049          0.0045   0.0052
# 2024-01   35.50        0.0509         0.0611                0.0395           0.0608          0.0410   0.0658
# 2024-02   60.98        0.1100         0.1145                0.0830           0.1154          0.0764   0.1190
# 2024-03  130.99        0.2136         0.2276                0.1250           0.2273          0.0900   0.2309
# 2024-04 1092.42        0.7373         0.7177                0.3286           0.6852          0.1379   0.7767
# 2024-05  486.48        0.5975         0.5412                0.3712           0.5163          0.1192   0.6120
# 2024-06  666.82        0.5442         0.5957                0.4229           0.5717          0.3617   0.6377
# 2024-07  993.17        0.6297         0.7744                0.4216           0.7128          0.7061   0.7758
# 2024-08  515.27        0.4871         0.5492                0.3240           0.5369          0.5637   0.5741
# 2024-09 1482.44        0.7388         0.8523                0.4562           0.9786          0.9344   0.9786
# 2024-10 1081.21        0.7600         0.7131                0.3865           0.9997          0.9039   0.9997
# 2024-11  586.30        0.7379         0.4761                0.2786           0.9166          0.5834   0.9166
#   table -> T6_interventions_all_months.csv
# '/content/outputs/tables/T6_interventions_all_months.csv'

# %%
hi = interv[interv["base"]>100]
cols = [f"{t}_inherits" for t in DISPATCHABLE]
ranks = hi[cols].idxmax(axis=1).str.replace("_inherits","",regex=False).value_counts()
rows = []
for t in DISPATCHABLE:
    c = f"{t}_inherits"
    rows.append(dict(technology=t, mean=round(float(hi[c].mean()),3),
                     sd=round(float(hi[c].std()),3), min=round(float(hi[c].min()),3),
                     max=round(float(hi[c].max()),3), ranked_first=int(ranks.get(t,0))))
rows.append(dict(technology="Fuel-secured", mean=round(float(hi["secured"].mean()),3),
                 sd=round(float(hi["secured"].std()),3), min=round(float(hi["secured"].min()),3),
                 max=round(float(hi["secured"].max()),3), ranked_first=np.nan))
iv_summary = pd.DataFrame(rows)
N_HI = len(hi)
print(f"Across the {N_HI} months with baseline shedding above 100 MW/h:")
print(iv_summary.to_string(index=False))
print("\nIllustrative months, all three counterfactuals:")
for ym in ["2023-06","2023-08"]:
    r = interv[interv.month==ym].iloc[0]
    print(f"  {ym}  (baseline {r['base']:.1f} MW/h)")
    print(f"    {'technology':13s} {'inherits':>9s} {'secured':>9s} {'flat':>9s}")
    for t in DISPATCHABLE:
        print(f"    {t:13s} {r[f'{t}_inherits']:9.3f} {r['secured']:9.3f} {r[f'{t}_flat']:9.3f}")
print("\n>> Under the fuel-secured specification every technology converges on one value:")
print("   under a sustained energy deficit any reliably available MW is worth the same.")
print("   The ranking under 'inherits' is a ranking of INHERITED AVAILABILITY PROFILES.")
print(">> The two illustrative months flatter the estimates relative to the 26-month mean.")
save_table(iv_summary, "T6_intervention_summary")
# Out:
# Across the 26 months with baseline shedding above 100 MW/h:
#   technology  mean    sd   min   max  ranked_first
#          Gas 0.492 0.199 0.152 0.760           2.0
#         Coal 0.356 0.241 0.061 0.852           3.0
#  Liquid Fuel 0.371 0.146 0.125 0.743           3.0
#       Import 0.543 0.238 0.189 1.000          17.0
#        Hydro 0.324 0.270 0.039 0.934           1.0
# Fuel-secured 0.569 0.239 0.194 1.000           NaN
#
# Illustrative months, all three counterfactuals:
#   2023-06  (baseline 1038.8 MW/h)
#     technology     inherits   secured      flat
#     Gas               0.730     0.747     0.720
#     Coal              0.359     0.747     0.353
#     Liquid Fuel       0.467     0.747     0.436
#     Import            0.731     0.747     0.720
#     Hydro             0.136     0.747     0.149
#   2023-08  (baseline 367.4 MW/h)
#     technology     inherits   secured      flat
#     Gas               0.466     0.494     0.464
#     Coal              0.427     0.494     0.413
#     Liquid Fuel       0.316     0.494     0.313
#     Import            0.472     0.494     0.475
#     Hydro             0.449     0.494     0.446
#
# >> Under the fuel-secured specification every technology converges on one value:
#    under a sustained energy deficit any reliably available MW is worth the same.
#    The ranking under 'inherits' is a ranking of INHERITED AVAILABILITY PROFILES.
# >> The two illustrative months flatter the estimates relative to the 26-month mean.
#   table -> T6_intervention_summary.csv
# '/content/outputs/tables/T6_intervention_summary.csv'

# %% [markdown]
# ### 12.1 Monte Carlo under availability perturbation

# %%
def mc_intervene(mdf, tech=None, inc=500.0, factors=None):
    n = build_month_network(base, mdf)
    if factors:
        for g in n.generators.index:
            car = n.generators.loc[g,"carrier"]
            if car in factors:
                n.generators_t.p_max_pu[g] = np.clip(
                    n.generators_t.p_max_pu[g].values*factors[car], 0, 1)
    if tech:
        gens = [g for g in n.generators.index if n.generators.loc[g,"carrier"]==tech]
        caps = n.generators.loc[gens,"p_nom"]; shr = caps/caps.sum()
        for g in gens: n.generators.loc[g,"p_nom"] += inc*shr[g]
    return shed_stats(n, mdf)["model"]

rngm = np.random.default_rng(SEED); mdfJ = slice_month("2023-06")
draws = {t: [] for t in DISPATCHABLE}
for _ in range(50):
    fac = {c: float(np.clip(rngm.normal(1,0.05),0.85,1.15)) for c in DISPATCHABLE}
    b = mc_intervene(mdfJ, None, factors=fac)
    for t in DISPATCHABLE:
        draws[t].append((b - mc_intervene(mdfJ, t, 500.0, fac))/500.0)
mc = pd.DataFrame([dict(technology=t, mean=round(float(np.mean(v)),3),
                        sd=round(float(np.std(v)),3),
                        p05=round(float(np.mean(v)-1.645*np.std(v)),3),
                        p95=round(float(np.mean(v)+1.645*np.std(v)),3))
                   for t,v in draws.items()])
print("June 2023, 50 draws, +/-5% Gaussian availability perturbation:")
print(mc.to_string(index=False))
save_table(mc, "TS_monte_carlo")
# Out:
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 52.96it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 127.41it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.92it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 93.72it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.03it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 91.25it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.03it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 125.13it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.42it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 120.96it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.91it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 119.94it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.34it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 113.75it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 64.09it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 120.39it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 40.52it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 71.66it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 64.19it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 118.63it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 64.26it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 111.94it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 64.08it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 118.02it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.88it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 122.17it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 55.58it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 115.06it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 39.37it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 70.93it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.58it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 117.83it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 64.46it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 107.95it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.75it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 127.78it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.84it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 121.49it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.65it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 126.09it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.72it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 84.15it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.75it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 124.05it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 64.02it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 126.00it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 56.07it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 123.70it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 64.35it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 97.30it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 64.45it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 117.96it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 50.38it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 87.47it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 42.76it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 110.74it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 64.34it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 118.48it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.67it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 116.21it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 64.46it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 111.38it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 64.86it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 123.88it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.65it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 97.79it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 36.62it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 69.19it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 64.40it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 77.57it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.07it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 92.52it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.70it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 118.05it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.53it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 114.04it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.06it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 72.53it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.28it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 69.20it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.39it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 110.64it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.58it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 114.24it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.62it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 127.46it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.42it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 114.33it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.83it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 87.04it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.38it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 108.06it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.46it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 116.19it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.68it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 96.61it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.01it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 120.89it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.39it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 101.02it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 39.81it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 74.74it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.42it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 111.24it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.48it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 104.05it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.16it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 93.89it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 64.40it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 122.89it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 64.57it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 113.67it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 39.04it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 65.33it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.30it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 108.15it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.91it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 85.78it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 64.29it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 120.14it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.97it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 119.34it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 64.30it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 125.49it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 39.88it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 63.03it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.73it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 120.07it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 54.53it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 110.00it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 64.29it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 86.62it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 64.58it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 116.63it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.85it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 119.35it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 37.74it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 61.49it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 56.09it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 98.82it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.02it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 102.51it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.10it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 123.37it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.34it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 109.45it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.42it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 104.16it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 41.34it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 85.59it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.66it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 102.74it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.95it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 120.54it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.21it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 89.49it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.76it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 100.80it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.51it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 112.78it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 41.28it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 88.16it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.46it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 99.94it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.83it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 102.56it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.91it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 101.43it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.59it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 105.17it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.00it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 98.45it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 40.03it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 72.00it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.07it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 98.04it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.14it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 103.21it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.86it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 101.70it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 52.99it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 91.73it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.01it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 92.13it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.43it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 81.34it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 56.98it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 96.84it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 50.43it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 97.86it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.08it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 105.54it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.79it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 103.71it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.33it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 66.08it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.91it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 102.10it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.50it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 97.17it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.66it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 90.18it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.00it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 98.62it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.42it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 88.10it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 36.02it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 58.39it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.91it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 111.79it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.33it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 98.00it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.50it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 93.73it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.50it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 108.57it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 40.79it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 56.06it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.43it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 99.43it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.59it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 95.69it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.03it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 91.55it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.24it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 82.66it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.60it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 116.39it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.23it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 87.96it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.27it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 101.14it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.75it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 83.76it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.71it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 110.03it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.47it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 107.36it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.26it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 105.45it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 39.29it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 79.79it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.78it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 99.41it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 54.64it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 87.55it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.01it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 106.84it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.46it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 108.08it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.02it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 104.34it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.33it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 56.52it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 52.01it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 93.64it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 51.91it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 120.31it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 51.64it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 81.33it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 55.25it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 76.49it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.92it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 68.40it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 39.89it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 58.99it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.43it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 98.90it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.59it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 96.03it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.83it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 98.53it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 55.53it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 102.69it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.29it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 68.53it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.71it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 94.85it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.00it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 91.28it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.03it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 89.92it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.45it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 99.80it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.15it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 105.60it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 39.01it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 76.47it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.90it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 104.76it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.50it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 85.68it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.79it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 93.98it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.70it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 91.60it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.87it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 107.84it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.11it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 88.31it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 52.24it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 87.03it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.83it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 71.83it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.19it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 82.44it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.68it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 77.79it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.96it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 108.73it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.41it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 51.83it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.44it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 83.95it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.86it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 96.39it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.91it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 97.43it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.40it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 90.98it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.40it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 91.58it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 37.82it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 70.78it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.02it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 97.37it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.95it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 89.94it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 55.80it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 93.63it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.46it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 89.23it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 40.32it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 84.14it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.43it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 99.54it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.58it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 90.72it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.99it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 85.92it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.97it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 95.51it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.99it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 100.39it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 36.69it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 62.79it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.39it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 94.42it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 55.63it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 94.12it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.08it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 85.68it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.60it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 87.70it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.84it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 91.99it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 36.67it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 54.24it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.94it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 81.70it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.92it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 99.36it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.85it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 93.74it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.01it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 89.25it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.22it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 85.22it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 37.50it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 62.59it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.01it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 89.65it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.96it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 96.15it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.11it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 82.02it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.63it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 85.12it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.86it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 83.98it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.79it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 86.63it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 50.33it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 92.67it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 51.36it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 74.04it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.64it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 72.50it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 51.08it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 94.84it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 37.01it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 69.32it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.03it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 92.69it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.22it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 93.08it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.58it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 98.59it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.92it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 73.06it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.64it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 100.41it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.65it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 54.10it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.92it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 86.21it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.76it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 80.26it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.20it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 97.07it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.18it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 90.84it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.38it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 91.04it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 32.89it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 54.44it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.68it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 88.76it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.07it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 86.06it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.77it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 81.17it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.67it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 100.48it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.09it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 79.02it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 37.75it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 73.83it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 51.07it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 102.28it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 50.33it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 89.96it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.89it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 60.72it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.65it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 74.54it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.17it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 88.53it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 36.95it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 75.03it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.49it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 88.74it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.86it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 98.75it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.34it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 80.60it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.44it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 93.99it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.72it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 68.22it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.51it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 77.60it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.10it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 73.97it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.34it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 78.66it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.33it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 90.75it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.47it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 98.33it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.19it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 54.22it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 39.20it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 68.60it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.18it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 94.00it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 52.91it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 77.76it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 52.91it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 83.83it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 49.88it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 95.88it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 34.49it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 66.42it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.54it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 88.79it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.57it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 68.64it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.17it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 95.38it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.74it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 91.33it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.23it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 78.70it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 39.00it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 57.26it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 56.24it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 82.41it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.63it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 81.09it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.28it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 86.87it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.45it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 78.71it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.79it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 89.91it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 34.47it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 57.85it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.45it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 83.23it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 55.35it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 85.41it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 56.83it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 78.16it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.17it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 70.02it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.69it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 89.59it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 35.72it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 71.54it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.38it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 57.09it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.52it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 75.37it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.06it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 83.37it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.00it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 91.08it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.03it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 77.81it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.12it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 77.61it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 56.87it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 90.56it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.77it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 84.90it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.95it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 88.60it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.48it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 71.93it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.02it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 87.43it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 36.54it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 82.77it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.29it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 49.99it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.59it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 101.12it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.43it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 86.17it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.28it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 90.50it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.44it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 79.11it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 35.19it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 59.99it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.30it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 80.86it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.75it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 63.56it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.12it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 77.26it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.25it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 82.44it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 55.26it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 58.25it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 43.13it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 79.05it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.69it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 69.39it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.70it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 71.17it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.19it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 80.51it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.66it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 66.46it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 40.89it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 89.97it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 56.99it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 86.92it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.93it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 76.25it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.98it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 77.84it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 55.27it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 97.18it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.89it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 73.62it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 37.86it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 55.27it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 55.74it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 92.67it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.83it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 83.38it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.48it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 89.50it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.03it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 71.36it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.33it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 67.56it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 37.16it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 86.97it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 55.04it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 77.45it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.71it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 72.53it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.27it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 80.07it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.18it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 93.91it/s]
# June 2023, 50 draws, +/-5% Gaussian availability perturbation:
#  technology  mean    sd   p05   p95
#         Gas 0.774 0.088 0.629 0.919
#        Coal 0.374 0.038 0.311 0.437
# Liquid Fuel 0.480 0.045 0.407 0.553
#      Import 0.778 0.107 0.602 0.954
#       Hydro 0.147 0.024 0.107 0.186
#   table -> TS_monte_carlo.csv
# '/content/outputs/tables/TS_monte_carlo.csv'

# %% [markdown]
# ### 12.2 Capacity-level sweep

# %%
if RUN_SWEEP:
    def sweep_point(mdf, tech, inc):
        n = build_month_network(base, mdf)
        gens = [g for g in n.generators.index if n.generators.loc[g,"carrier"]==tech]
        caps = n.generators.loc[gens,"p_nom"]; shr = caps/caps.sum()
        for g in gens: n.generators.loc[g,"p_nom"] += inc*shr[g]
        return shed_stats(n, mdf)["model"]
    rows = []
    for ym in ["2023-06","2023-08"]:
        mdf = slice_month(ym); b = shed_stats(build_month_network(base,mdf),mdf)["model"]
        for tech in ["Gas","Import"]:
            prev_shed, prev_add = b, 0
            for inc in [100,250,500,1000,1500,2000]:
                s = sweep_point(mdf, tech, float(inc))
                rows.append(dict(month=ym, tech=tech, added_MW=inc, baseline=round(b,1),
                                 shed=round(s,1), avg_eff=round((b-s)/inc,3),
                                 marg_eff=round((prev_shed-s)/(inc-prev_add),3)))
                prev_shed, prev_add = s, inc
    sweep_df = pd.DataFrame(rows)
    print(sweep_df.to_string(index=False))
    print("\n>> Returns diminish smoothly with no threshold; gas and import are")
    print("   near-identical at every level. The depth of the sustained deficit sets")
    print("   the saturation point (June ~2 GW, August ~1.5 GW).")
    save_table(sweep_df, "TS_capacity_sweep")
else:
    sweep_df = None; print("skipped (RUN_SWEEP = False)")
# Out:
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.22it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 121.57it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 39.58it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 84.11it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.52it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 121.37it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 53.51it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 120.98it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 51.23it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 109.09it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 34.45it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 85.76it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 53.06it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 126.81it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.65it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 89.47it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.24it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 124.64it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.82it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 122.50it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.61it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 92.72it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.58it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 115.58it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.10it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 70.24it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 51.92it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 126.82it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.37it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 112.91it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.27it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 108.49it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.89it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 112.95it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.41it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 105.18it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 37.63it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 82.93it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 55.03it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 69.46it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 56.49it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 61.75it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.56it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 104.93it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.79it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 111.00it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.21it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 114.20it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 39.78it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 87.65it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.73it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 111.32it/s]
#   month   tech  added_MW  baseline  shed  avg_eff  marg_eff
# 2023-06    Gas       100    1038.8 955.4    0.834     0.834
# 2023-06    Gas       250    1038.8 838.7    0.800     0.778
# 2023-06    Gas       500    1038.8 673.8    0.730     0.660
# 2023-06    Gas      1000    1038.8 422.9    0.616     0.502
# 2023-06    Gas      1500    1038.8 231.5    0.538     0.383
# 2023-06    Gas      2000    1038.8 106.1    0.466     0.251
# 2023-06 Import       100    1038.8 955.7    0.831     0.831
# 2023-06 Import       250    1038.8 839.3    0.798     0.776
# 2023-06 Import       500    1038.8 673.5    0.731     0.663
# 2023-06 Import      1000    1038.8 420.7    0.618     0.506
# 2023-06 Import      1500    1038.8 229.1    0.540     0.383
# 2023-06 Import      2000    1038.8 103.4    0.468     0.251
# 2023-08    Gas       100     367.4 298.1    0.693     0.693
# 2023-08    Gas       250     367.4 219.3    0.592     0.525
# 2023-08    Gas       500     367.4 134.5    0.466     0.339
# 2023-08    Gas      1000     367.4  39.5    0.328     0.190
# 2023-08    Gas      1500     367.4   5.8    0.241     0.067
# 2023-08    Gas      2000     367.4   0.7    0.183     0.010
# 2023-08 Import       100     367.4 295.9    0.715     0.715
# 2023-08 Import       250     367.4 216.1    0.605     0.532
# 2023-08 Import       500     367.4 131.2    0.472     0.339
# 2023-08 Import      1000     367.4  38.3    0.329     0.186
# 2023-08 Import      1500     367.4   5.9    0.241     0.065
# 2023-08 Import      2000     367.4   0.3    0.184     0.011
#
# >> Returns diminish smoothly with no threshold; gas and import are
#    near-identical at every level. The depth of the sustained deficit sets
#    the saturation point (June ~2 GW, August ~1.5 GW).
#   table -> TS_capacity_sweep.csv

# %% [markdown]
# ### 12.3 Reserve-margin constraint

# %%
RES_C = ["Gas","Coal","Liquid Fuel","Import"]
def reserve_run(mdf, R):
    n = build_month_network(base, mdf)
    rg = [g for g in n.generators.index if n.generators.loc[g,"carrier"] in RES_C]
    pn = n.generators.loc[rg,"p_nom"]; tot = pn.sum()
    for g in rg:
        share = R*pn[g]/tot
        avail_mw = n.generators.loc[g,"p_nom"]*pd.Series(n.generators_t.p_max_pu[g],
                                                        index=n.snapshots)
        n.generators_t.p_max_pu[g] = ((avail_mw-share).clip(lower=0)
                                      / n.generators.loc[g,"p_nom"]).values
    return shed_stats(n, mdf)["model"]

rows = []
for ym, label in [("2016-12","Adequate"),("2023-06","Crisis")]:
    mdf = slice_month(ym); b = shed_stats(build_month_network(base,mdf),mdf)["model"]
    row = {"month":ym,"state":label,"R=0":round(b,1)}
    for R in [100,250,500]: row[f"R={R}"] = round(reserve_run(mdf,R),1)
    row["pass_through@500"] = round((row["R=500"]-row["R=0"])/500,2)
    rows.append(row)
reserve_df = pd.DataFrame(rows)
print(reserve_df.to_string(index=False))
save_table(reserve_df, "TS_reserve_margin")
# Out:
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.32it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 126.94it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.52it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 112.50it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.00it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 121.08it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.98it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 119.94it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 40.50it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 71.99it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.00it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 121.29it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.47it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 122.03it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.03it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 118.30it/s]
#   month    state    R=0  R=100  R=250  R=500  pass_through@500
# 2016-12 Adequate    6.2   98.0  246.1  477.4              0.94
# 2023-06   Crisis 1038.8 1136.7 1286.5 1536.0              0.99
#   table -> TS_reserve_margin.csv
# '/content/outputs/tables/TS_reserve_margin.csv'

# %% [markdown]
# ## 13. Storage
#
# `hourly` is the specification used throughout. `daily` replaces the hourly
# availability ceiling with a per-carrier daily energy budget the model may
# reschedule freely — the formulation that permits off-peak charging.
#
# Effectiveness **falls** under it, because the crisis months are energy-short and
# the rescheduling itself performs the arbitrage storage would otherwise provide.

# %%
rows = []
for ym in ["2016-12","2023-06","2023-08"]:
    mdf = slice_month(ym)
    for mode in ("hourly","daily"):
        n0 = build_month_network(base, mdf, mode)
        m0 = add_daily_budgets(n0, mdf, base) if mode=="daily" else None
        b0 = model_shed_series(n0, m0).mean()
        nb = build_month_network(base, mdf, mode)
        nb.add("StorageUnit","Batt", bus="Dhaka", p_nom=500.0, max_hours=4,
               efficiency_store=0.95, efficiency_dispatch=0.95,
               cyclic_state_of_charge=True, marginal_cost=0.0)
        m1 = add_daily_budgets(nb, mdf, base) if mode=="daily" else None
        b1 = model_shed_series(nb, m1).mean()
        p = nb.storage_units_t.p["Batt"]
        rows.append(dict(period=ym, mode=mode, base=round(float(b0),2),
                         with_battery=round(float(b1),2), relief_mw=round(float(b0-b1),2),
                         effectiveness=round(float((b0-b1)/500.0),4),
                         charged_mwh=round(float((-p).clip(lower=0).sum()),0),
                         discharged_mwh=round(float(p.clip(lower=0).sum()),0)))
bat = pd.DataFrame(rows); print(bat.to_string(index=False))
print("\nBattery: 500 MW / 4 h at Dhaka, efficiencies 0.95/0.95 (90.25% round trip),")
print("cyclic state of charge, zero marginal cost, no self-discharge.")
save_table(bat, "T7_battery")
# Out:
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.67it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 115.71it/s]
# Writing constraints.: 100%|██████████| 13/13 [00:00<00:00, 88.52it/s]
# Writing continuous variables.: 100%|██████████| 5/5 [00:00<00:00, 170.35it/s]
# Writing constraints.: 100%|██████████| 223/223 [00:01<00:00, 198.75it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 125.26it/s]
# Writing constraints.: 100%|██████████| 230/230 [00:01<00:00, 195.34it/s]
# Writing continuous variables.: 100%|██████████| 5/5 [00:00<00:00, 166.33it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.58it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 126.07it/s]
# Writing constraints.: 100%|██████████| 13/13 [00:00<00:00, 94.58it/s]
# Writing continuous variables.: 100%|██████████| 5/5 [00:00<00:00, 175.29it/s]
# Writing constraints.: 100%|██████████| 216/216 [00:01<00:00, 203.49it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 112.85it/s]
# Writing constraints.: 100%|██████████| 223/223 [00:01<00:00, 197.18it/s]
# Writing continuous variables.: 100%|██████████| 5/5 [00:00<00:00, 186.17it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.07it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 115.19it/s]
# Writing constraints.: 100%|██████████| 13/13 [00:00<00:00, 93.57it/s]
# Writing continuous variables.: 100%|██████████| 5/5 [00:00<00:00, 188.77it/s]
# Writing constraints.: 100%|██████████| 223/223 [00:01<00:00, 181.55it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 79.31it/s]
# Writing constraints.: 100%|██████████| 230/230 [00:01<00:00, 189.70it/s]
# Writing continuous variables.: 100%|██████████| 5/5 [00:00<00:00, 175.72it/s]
#  period   mode    base  with_battery  relief_mw  effectiveness  charged_mwh  discharged_mwh
# 2016-12 hourly    6.18          0.95       5.23         0.0105       4315.0          3894.0
# 2016-12  daily    2.78          0.00       2.78         0.0056       2289.0          2066.0
# 2023-06 hourly 1038.81       1036.89       1.91         0.0038       1526.0          1377.0
# 2023-06  daily 1037.65       1036.78       0.87         0.0017        694.0           626.0
# 2023-08 hourly  367.38        365.97       1.41         0.0028       1162.0          1049.0
# 2023-08  daily  366.22        365.86       0.36         0.0007        300.0           271.0
#
# Battery: 500 MW / 4 h at Dhaka, efficiencies 0.95/0.95 (90.25% round trip),
# cyclic state of charge, zero marginal cost, no self-discharge.
#   table -> T7_battery.csv
# '/content/outputs/tables/T7_battery.csv'

# %%
rows = []
for ym in PERIODS:
    m = slice_month(ym)
    D = m["Demand"].sum()/1000; A = available(m).sum()/1000
    N = sum(NETCAP.values())*len(m)/1000
    head = available(m)-m["Demand"]
    rows.append(dict(period=ym, demand_gwh=round(D,0), delivered_gwh=round(A,0),
                     balance_gwh=round(A-D,0), nameplate_headroom_gwh=round(N-D,0),
                     chargeable_mwh=round(float(head.clip(lower=0).sum()),0),
                     hours_with_headroom=int((head>1).sum())))
ebal = pd.DataFrame(rows); print(ebal.to_string(index=False))
print("\n>> The crisis months are energy-short by 272 to 746 GWh. No rescheduling rule")
print("   can create surplus, which is why the daily-budget reformulation does not")
print("   rescue storage. December 2016 is the state in which the hourly ceiling was")
print("   doing the work: the balance is ~0 against 8,290 GWh of nameplate headroom.")
print("\n>> Table 7's 'surplus hours' in earlier versions computed hours WITHOUT")
print("   shedding, not hours with generation headroom. Relabel accordingly.")
save_table(ebal, "T7_energy_balance")
# Out:
#  period  demand_gwh  delivered_gwh  balance_gwh  nameplate_headroom_gwh  chargeable_mwh  hours_with_headroom
# 2016-12      3990.0         3994.0          4.0                  8290.0          8162.0                  561
# 2022-08      9103.0         8431.0       -672.0                  3178.0           299.0                   20
# 2023-06      8981.0         8235.0       -746.0                  2904.0          1526.0                   89
# 2023-08      9352.0         9080.0       -272.0                  2929.0          1162.0                   51
#
# >> The crisis months are energy-short by 272 to 746 GWh. No rescheduling rule
#    can create surplus, which is why the daily-budget reformulation does not
#    rescue storage. December 2016 is the state in which the hourly ceiling was
#    doing the work: the balance is ~0 against 8,290 GWh of nameplate headroom.
#
# >> Table 7's 'surplus hours' in earlier versions computed hours WITHOUT
#    shedding, not hours with generation headroom. Relabel accordingly.
#   table -> T7_energy_balance.csv
# '/content/outputs/tables/T7_energy_balance.csv'

# %% [markdown]
# ## 14. Sensitivity analysis
#
# **How to read this.** Once the availability envelope sits below demand it binds,
# and network and economic parameters cannot influence total shedding. Near-zero
# indices for those parameters characterise the *reduced formulation*, not the
# physical system.

# %%
if RUN_GSA:
    from SALib.sample.morris import sample as morris_sample
    from SALib.analyze.morris import analyze as morris_analyze
    t0 = time.time()
    mgsa = slice_month("2023-06")
    DEM = pd.to_numeric(mgsa["Demand"],errors="coerce").fillna(0.0).values
    BASE_CF = {t: ((pd.to_numeric(mgsa[t],errors="coerce").fillna(0.0)/NETCAP[t])
                   .clip(0,1).values if NETCAP.get(t,0)>0 else np.zeros(len(mgsa)))
               for t in TECHS}
    BASE_SHARE = np.array([base_load_shares[L] for L in base.loads.index])
    BASE_SNOM  = base.lines["s_nom"].copy()

    def gsa_model(x):
        ls, corr, mc_, pen, av = x[0:5], x[5], x[6:10], x[10], x[11:16]
        n = fresh_network(base); n.set_snapshots(mgsa.index)
        share = BASE_SHARE*ls; share = share/share.sum()
        for L, s in zip(n.loads.index, share): n.loads_t.p_set[L] = DEM*s
        n.lines["s_nom"] = BASE_SNOM*corr
        avmap = dict(zip(DISPATCHABLE, av))
        for t in TECHS:
            gens = [g for g in n.generators.index if n.generators.loc[g,"carrier"]==t]
            if not gens: continue
            c = np.clip(BASE_CF[t]*avmap.get(t,1.0),0,1)
            for g in gens: n.generators_t.p_max_pu[g] = c
        mcmap = dict(zip(["Gas","Coal","Import","Liquid Fuel"], mc_))
        for g in n.generators.index:
            car = n.generators.loc[g,"carrier"]
            if car in mcmap: n.generators.loc[g,"marginal_cost"] = mcmap[car]
            if "load shedding" in g.lower():
                n.generators.loc[g,"marginal_cost"] = pen
                n.generators.loc[g,"p_nom"] = 20000.0
                n.generators_t.p_max_pu[g] = 1.0
        try:
            n.optimize(**SOLVE_KW)
            return float(n.generators_t.p[_shed_gens(n)].sum(axis=1).mean())
        except Exception:
            return np.nan

    problem = {'num_vars':16,
        'names':['ls_NW','ls_NE','ls_Dhaka','ls_SW','ls_CTG','corridor_cap',
                 'mc_gas','mc_coal','mc_import','mc_LF','shed_penalty',
                 'av_gas','av_coal','av_LF','av_import','av_hydro'],
        'bounds':[[0.8,1.2]]*5 + [[0.5,1.5]] +
                 [[10,30],[15,45],[20,60],[30,90]] + [[2000,20000]] + [[0.85,1.15]]*5}
    globals().update(DEM=DEM, BASE_CF=BASE_CF, gsa_model=gsa_model)
    X = morris_sample(problem, N=MORRIS_N, num_levels=4, seed=SEED)
    Y = np.array([gsa_model(x) for x in X])
    Si = morris_analyze(problem, X, Y, num_levels=4, print_to_console=False)
    gsa = (pd.DataFrame({'param':problem['names'],'mu_star':Si['mu_star'],'sigma':Si['sigma']})
           .sort_values('mu_star',ascending=False).reset_index(drop=True))
    print(f"Morris: {int(np.isfinite(Y).sum())}/{len(Y)} valid evaluations in {time.time()-t0:.0f}s")
    print(gsa.round(1).to_string(index=False))
    print(f"\nmax mu* among non-availability parameters: "
          f"{gsa[~gsa.param.str.startswith('av_')]['mu_star'].max():.4f}")
    save_table(gsa, "TS_morris")
else:
    gsa = None; print("skipped (RUN_GSA = False)")
# Out:
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.53it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 91.82it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.17it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 105.76it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 56.02it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 118.03it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.43it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 124.18it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.56it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 123.89it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.36it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 124.34it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.49it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 90.77it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 36.55it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 86.61it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.48it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 116.42it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.83it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 115.05it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.53it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 112.05it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.96it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 117.06it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.51it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 121.05it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 39.57it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 73.30it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 52.91it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 115.00it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.95it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 108.09it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.27it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 110.47it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.36it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 118.74it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.93it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 120.31it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 40.30it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 65.55it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.78it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 112.16it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.58it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 101.95it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.12it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 113.17it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.53it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 113.65it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.20it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 113.29it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 40.81it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 89.79it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.16it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 126.57it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.68it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 81.49it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.13it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 102.21it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.44it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 107.44it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.39it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 121.30it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.84it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 79.57it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.09it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 79.28it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.69it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 112.01it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.13it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 115.64it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.65it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 114.80it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.27it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 114.85it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.22it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 109.11it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.69it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 77.16it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.30it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 119.95it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.86it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 116.50it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 50.65it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 116.82it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.15it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 84.89it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.68it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 117.19it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 39.92it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 88.06it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.44it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 124.73it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.52it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 124.37it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.39it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 88.17it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.38it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 122.52it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.88it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 105.62it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.00it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 65.94it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.95it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 123.61it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.48it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 105.70it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.39it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 119.44it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.09it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 116.75it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.26it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 113.55it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 40.66it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 79.61it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.39it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 116.31it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 56.09it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 107.01it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.06it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 98.59it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.27it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 110.85it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.13it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 105.35it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 41.49it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 88.61it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.35it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 107.72it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.94it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 112.97it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.85it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 106.09it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.29it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 104.89it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.01it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 110.64it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.87it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 103.06it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.10it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 53.34it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.99it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 110.88it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.92it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 90.80it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.12it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 102.01it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.78it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 104.22it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.04it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 113.21it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 40.54it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 89.24it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.91it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 115.20it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.59it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 106.79it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.64it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 109.73it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.92it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 104.93it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.25it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 114.67it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 39.29it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 76.80it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.99it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 109.97it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.85it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 119.57it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.18it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 105.94it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.82it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 92.47it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.08it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 104.38it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 44.69it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 47.88it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.44it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 75.72it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.69it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 99.40it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.58it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 109.12it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.78it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 98.30it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.38it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 114.22it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 41.73it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 90.44it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 36.29it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 85.73it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.22it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 106.71it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.43it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 78.36it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.63it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 102.19it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.78it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 99.09it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.11it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 121.52it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 36.18it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 63.94it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.08it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 112.64it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.85it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 104.92it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.21it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 64.30it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.36it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 98.49it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.73it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 112.31it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 33.40it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 90.72it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.89it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 103.36it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.77it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 120.59it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 51.94it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 81.25it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.41it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 99.11it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.73it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 103.43it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 42.05it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 74.64it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.62it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 86.86it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.34it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 98.17it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.93it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 105.37it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.44it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 121.09it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.38it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 84.58it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 35.84it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 59.75it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.91it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 94.97it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.45it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 94.19it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.83it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 106.72it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.30it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 100.68it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 52.35it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 104.35it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 44.22it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 75.90it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 37.98it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 70.49it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.79it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 95.38it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.98it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 99.14it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.35it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 99.06it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.32it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 99.72it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 53.36it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 104.46it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 39.20it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 79.96it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.34it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 93.88it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.70it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 92.39it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.42it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 91.33it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.18it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 100.59it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.89it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 100.47it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 35.78it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 73.55it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.49it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 106.16it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 50.21it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 86.46it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.46it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 107.18it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.27it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 100.64it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.70it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 78.82it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 36.83it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 66.56it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.10it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 97.79it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.44it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 97.12it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 55.06it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 71.42it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.04it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 76.02it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.58it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 98.16it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.88it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 89.96it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.14it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 81.05it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.05it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 108.19it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.25it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 104.70it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 56.83it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 67.50it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.84it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 98.84it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 43.96it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 83.54it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.69it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 100.40it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.63it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 103.62it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.79it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 101.72it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 53.19it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 95.53it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.98it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 97.38it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 49.07it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 69.69it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 35.75it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 81.95it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.44it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 100.62it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.13it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 93.16it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.15it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 91.96it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 54.71it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 78.21it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.25it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 92.03it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.88it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 59.64it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.99it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 98.12it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.76it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 94.01it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 56.12it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 89.15it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.27it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 83.24it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 56.13it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 83.87it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 39.97it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 77.69it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.31it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 97.21it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.85it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 97.13it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.50it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 98.65it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.54it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 90.69it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.02it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 59.77it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.92it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 59.20it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.05it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 82.07it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.97it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 94.64it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.22it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 81.06it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 56.56it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 85.16it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.83it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 92.02it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 39.48it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 53.80it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.92it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 91.64it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 54.85it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 67.76it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.71it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 90.38it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 56.37it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 87.96it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.97it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 87.46it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.43it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 66.93it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 40.34it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 105.31it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.19it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 77.60it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.58it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 61.84it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.83it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 89.48it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.21it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 89.53it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.05it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 100.19it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 39.49it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 80.98it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.84it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 92.80it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.55it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 87.62it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.08it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 84.00it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.85it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 76.85it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.73it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 88.91it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 36.69it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 49.23it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.89it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 90.33it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.03it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 90.43it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 50.26it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 88.51it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.55it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 96.53it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.19it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 85.40it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.31it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 80.61it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.67it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 97.29it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 55.95it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 86.72it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 49.02it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 78.15it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.72it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 78.98it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.12it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 104.55it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 39.15it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 61.91it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.04it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 91.14it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.24it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 86.44it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.91it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 93.86it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.54it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 63.54it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.41it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 97.91it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.97it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 100.32it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 34.72it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 53.37it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.69it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 74.65it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.24it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 92.43it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.19it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 75.59it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.74it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 75.97it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.23it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 81.31it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 35.90it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 72.32it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 55.81it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 84.72it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.09it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 86.64it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.80it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 87.66it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.62it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 80.98it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.26it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 85.15it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.58it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 83.22it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.09it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 77.94it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.37it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 80.96it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.97it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 84.82it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.60it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 77.33it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.53it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 95.12it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 40.40it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 82.07it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.37it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 84.37it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 49.44it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 71.49it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.95it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 87.16it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.64it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 90.04it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.01it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 74.74it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 41.38it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 78.96it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.35it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 90.32it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.59it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 74.36it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 51.15it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 96.84it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.17it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 82.52it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.02it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 90.24it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 36.98it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 78.05it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 36.55it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 87.15it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.31it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 86.44it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.58it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 78.23it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 51.49it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 70.70it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.07it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 86.08it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 63.75it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 82.96it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 40.86it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 55.42it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.04it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 82.14it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.10it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 70.17it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.30it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 91.53it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.26it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 54.81it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 56.10it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 83.09it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 34.33it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 71.09it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.37it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 68.29it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.86it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 83.49it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.08it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 86.37it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 49.51it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 89.68it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.46it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 86.95it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 37.96it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 88.39it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.76it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 81.32it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.89it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 91.70it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.60it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 93.68it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.29it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 88.80it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.71it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 88.01it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 39.90it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 89.99it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 55.33it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 83.14it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 56.31it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 76.73it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.50it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 79.79it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.20it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 98.87it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.87it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 88.32it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 40.21it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 88.09it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 55.93it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 88.00it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 51.07it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 90.37it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.01it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 74.79it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.73it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 76.29it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.03it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 80.88it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 64.23it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 80.50it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 36.13it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 59.46it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 51.58it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 85.31it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.21it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 61.53it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.85it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 89.80it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 56.70it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 67.92it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.82it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 75.73it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 36.80it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 47.58it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.19it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 90.32it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 50.85it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 90.03it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.77it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 87.35it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.00it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 71.10it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.55it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 101.05it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.16it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 83.01it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.23it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 94.98it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 51.08it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 69.97it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.77it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 82.08it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.38it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 83.93it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 56.20it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 79.52it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 36.94it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 65.74it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.66it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 95.35it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.11it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 85.03it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 48.07it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 84.51it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 49.10it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 69.89it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.92it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 79.71it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 39.71it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 66.49it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 34.69it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 92.34it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.16it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 89.84it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.48it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 85.87it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.95it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 95.27it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.21it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 80.96it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.19it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 94.71it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.88it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 65.47it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.18it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 84.08it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 55.66it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 74.53it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 55.45it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 92.86it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 56.35it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 82.11it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 50.44it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 89.00it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 40.53it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 61.08it/s]
# ...
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.69it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 65.48it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.62it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 71.64it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.02it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 79.44it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.70it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 88.65it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 37.95it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 73.51it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.33it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 89.37it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.25it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 85.19it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.76it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 77.50it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.71it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 70.53it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 55.49it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 82.07it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.31it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 74.51it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.25it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 87.32it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.01it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 78.91it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.53it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 73.94it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.29it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 97.75it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 52.19it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 84.74it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.72it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 81.59it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.41it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 92.11it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.17it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 85.45it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 55.67it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 78.07it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.69it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 72.84it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.29it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 68.46it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 35.21it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 68.97it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.23it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 80.86it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.18it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 71.22it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.04it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 83.99it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 56.70it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 86.28it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.13it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 83.89it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 37.77it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 55.55it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 48.43it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 83.09it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.12it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 83.82it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.15it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 79.94it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 56.53it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 70.14it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 35.99it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 83.34it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 35.61it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 74.65it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 50.09it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 82.94it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.94it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 82.42it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.75it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 63.96it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.88it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 87.30it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 56.18it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 94.85it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 37.87it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 62.25it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.48it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 94.41it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.66it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 73.24it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.50it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 100.02it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.91it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 69.19it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.97it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 82.33it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 33.24it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 60.00it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.25it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 67.13it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 55.95it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 61.22it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 37.83it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 67.68it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 55.69it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 84.84it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 33.51it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 78.45it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.30it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 81.82it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.66it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 66.06it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.25it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 89.41it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.52it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 70.25it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.31it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 73.46it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 39.68it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 85.53it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 48.26it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 79.20it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 53.10it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 92.22it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.58it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 74.80it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.22it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 75.47it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.85it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 79.19it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 40.78it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 62.87it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.47it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 85.13it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.34it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 76.38it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.27it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 98.05it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 56.66it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 90.11it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.91it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 63.78it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 34.40it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 77.23it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 51.31it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 82.28it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.48it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 75.94it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 55.67it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 82.46it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 56.81it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 83.50it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 52.46it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 89.34it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 34.57it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 67.20it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 56.07it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 88.44it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 50.22it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 71.52it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.88it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 94.23it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 53.97it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 91.07it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 56.25it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 84.81it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 37.12it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 47.96it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.34it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 79.52it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.16it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 93.69it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 56.00it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 78.94it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.60it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 75.56it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.94it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 95.95it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 33.24it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 52.58it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 57.15it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 61.36it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 49.87it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 70.31it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 56.18it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 76.50it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 55.92it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 78.35it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 56.63it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 65.26it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 37.53it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 49.75it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.98it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 84.66it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.34it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 70.92it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 56.82it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 79.51it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.40it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 81.01it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 49.26it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 89.60it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 37.03it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 76.91it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.52it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 76.04it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.90it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 85.76it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.58it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 87.72it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.61it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 76.84it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.06it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 90.07it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 34.67it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 72.48it/s]
# Morris: 510/510 valid evaluations in 1094s
#        param  mu_star  sigma
#       av_gas   1120.9  477.1
#        av_LF    529.8   61.1
#      av_coal    491.2   45.6
#    av_import    176.7   68.7
#     av_hydro      9.7    1.3
#        ls_NW      0.0    0.0
#        ls_SW      0.0    0.0
#        ls_NE      0.0    0.0
#     ls_Dhaka      0.0    0.0
#       ls_CTG      0.0    0.0
#        mc_LF      0.0    0.0
# corridor_cap      0.0    0.0
#      mc_coal      0.0    0.0
#       mc_gas      0.0    0.0
# shed_penalty      0.0    0.0
#    mc_import      0.0    0.0
#
# max mu* among non-availability parameters: 0.0000
#   table -> TS_morris.csv

# %% [markdown]
# ### 14.2 Variance-based sensitivity (Sobol)
#
# Run on the **verified closed form** rather than the linear program, which makes
# a large sample tractable. The reduction is re-verified against the LP on 32
# random draws before use.

# %%
if RUN_GSA:
    from SALib.sample import saltelli
    from SALib.analyze import sobol
    SOBOL_N = 16384                       # closed-form evaluations = SOBOL_N * 7

    prob2 = {'num_vars':5,
             'names':['av_gas','av_coal','av_LF','av_import','av_hydro'],
             'bounds':[[0.85,1.15]]*5}

    def gsa_closed_form(x):
        """Equivalent to gsa_model at base load shares and corridor ratings:
        corridors never bind and shedding capacity is unconstrained, so hourly
        shedding is the positive part of demand minus total available generation."""
        avmap = dict(zip(DISPATCHABLE, x[11:16]))
        avail = np.zeros(len(DEM))
        for t in TECHS:
            avail += NETCAP[t]*np.clip(BASE_CF[t]*avmap.get(t,1.0), 0.0, 1.0)
        return float(np.maximum(DEM-avail, 0.0).mean())

    print("Verifying the closed form against the linear program on 32 random draws...")
    _rngv = np.random.default_rng(7); _rows = []
    for k in range(32):
        _av = _rngv.uniform(0.85, 1.15, 5)
        _x = np.array([1,1,1,1,1, 1.0, 20,30,40,60, 10000, *_av], dtype=float)
        _rows.append(dict(draw=k+1, lp=gsa_model(_x), closed_form=gsa_closed_form(_x)))
    sobol_validation = pd.DataFrame(_rows)
    sobol_validation["abs_diff"] = (sobol_validation["lp"]-sobol_validation["closed_form"]).abs()
    _maxd = float(sobol_validation["abs_diff"].max())
    print(f"Maximum absolute difference over 32 draws: {_maxd:.10f} MW/h")
    assert _maxd < 1e-6, "The closed form does not reproduce the LP. Do not use it."
    print("Reduction verified. The Sobol indices below are exact for this model.\n")
    save_table(sobol_validation, "TS_sobol_lp_verification")

    def y5(x5):
        return gsa_closed_form(np.array([1,1,1,1,1, 1.0, 20,30,40,60, 10000, *x5], dtype=float))

    X2 = saltelli.sample(prob2, SOBOL_N, calc_second_order=False)
    print(f"running {len(X2):,} closed-form Sobol evaluations (N={SOBOL_N:,})...")
    Y2 = np.array([y5(x) for x in X2])

    def _analyze(Yv):
        try:
            return sobol.analyze(prob2, Yv, calc_second_order=False,
                                 print_to_console=False, seed=SEED)
        except TypeError:
            np.random.seed(SEED)
            return sobol.analyze(prob2, Yv, calc_second_order=False, print_to_console=False)

    S2 = _analyze(Y2)
    sob = pd.DataFrame({'param':prob2['names'],'S1':S2['S1'],'S1_conf':S2['S1_conf'],
                        'ST':S2['ST'],'ST_conf':S2['ST_conf']}).sort_values('ST',ascending=False)
    print(f"\nSobol indices (June 2023, N={SOBOL_N:,}):")
    print(sob.round(4).to_string(index=False))
    save_table(sob, "TS_sobol_indices")

    _D = prob2['num_vars']; _half = (SOBOL_N//2)*(_D+2)
    S2h = _analyze(Y2[:_half])
    conv = pd.DataFrame({'param':prob2['names'],
                         f'ST_N{SOBOL_N//2}':S2h['ST'], f'ST_N{SOBOL_N}':S2['ST']})
    conv['abs_change'] = (conv[f'ST_N{SOBOL_N}']-conv[f'ST_N{SOBOL_N//2}']).abs()
    print("\nConvergence, half sample against full sample:")
    print(conv.round(4).to_string(index=False))
    _sum1 = float(np.nansum(S2['S1'])); _interact = float(np.nanmax(np.abs(S2['ST']-S2['S1'])))
    print(f"\nSum of first-order indices: {_sum1:.3f}")
    print(f"Largest total-order confidence half-width: {np.nanmax(S2['ST_conf']):.4f}")
    print(f"Largest ST - S1 difference: {_interact:.4f}")
    print("=> Converged." if (0.95 <= _sum1 <= 1.05 and float(conv['abs_change'].max()) < 0.005)
          else "=> NOT converged. Raise SOBOL_N.")
    if _interact < 0.01:
        print("=> Interactions are negligible: the response is essentially additive in the")
        print("   availability multipliers, so each acts independently on shedding.")
    save_table(conv, "TS_sobol_convergence")

    _mo = gsa.set_index("param")["mu_star"].rank(ascending=False).astype(int)
    _so = sob.set_index("param")["ST"].rank(ascending=False).astype(int)
    ranks = pd.DataFrame({"Morris_rank":_mo.reindex(prob2["names"]),
                          "Sobol_rank":_so.reindex(prob2["names"]),
                          "Morris_mu_star":gsa.set_index("param")["mu_star"]
                                              .reindex(prob2["names"]).round(1),
                          "Sobol_ST":sob.set_index("param")["ST"]
                                        .reindex(prob2["names"]).round(4)})
    print("\nRank comparison (1 = most influential):")
    print(ranks.to_string())
    RANKS_IDENTICAL = bool((ranks["Morris_rank"]==ranks["Sobol_rank"]).all())
    print(f"\nRankings identical: {RANKS_IDENTICAL}")
    print("The variance-based analysis reproduces the Morris ordering exactly."
          if RANKS_IDENTICAL else
          "The two methods disagree. Report the disagreement explicitly.")
    save_table(ranks.reset_index().rename(columns={"index":"param"}), "TS_morris_sobol_ranks")
else:
    sob = None; RANKS_IDENTICAL = None
    print("skipped (RUN_GSA = False)")
# Out:
# Verifying the closed form against the linear program on 32 random draws...
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.39it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 112.01it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.58it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 106.36it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.84it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 110.77it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 58.15it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 117.59it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.44it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 108.75it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.78it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 83.30it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.21it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 124.17it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.09it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 119.36it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.04it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 117.80it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.15it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 116.34it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.08it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 116.81it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 40.38it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 58.55it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 59.03it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 104.64it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.77it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 115.80it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.87it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 121.98it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.55it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 120.17it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.87it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 107.06it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 39.09it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 75.17it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.36it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 122.51it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.12it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 111.02it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.38it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 118.94it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.46it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 101.21it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.60it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 110.66it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 38.03it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 70.06it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.46it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 116.42it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.40it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 130.28it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 62.23it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 109.64it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 53.12it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 92.00it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 60.66it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 112.30it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 39.52it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 88.65it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.29it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 107.29it/s]
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00, 61.70it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 106.73it/s]
# Maximum absolute difference over 32 draws: 0.0000000000 MW/h
# Reduction verified. The Sobol indices below are exact for this model.
#
#   table -> TS_sobol_lp_verification.csv
# running 114,688 closed-form Sobol evaluations (N=16,384)...
#
# Sobol indices (June 2023, N=16,384):
#     param     S1  S1_conf     ST  ST_conf
#    av_gas 0.7190   0.0172 0.7211   0.0132
#     av_LF 0.1469   0.0085 0.1478   0.0033
#   av_coal 0.1138   0.0070 0.1152   0.0025
# av_import 0.0180   0.0031 0.0183   0.0004
#  av_hydro 0.0000   0.0001 0.0000   0.0000
#   table -> TS_sobol_indices.csv
#
# Convergence, half sample against full sample:
#     param  ST_N8192  ST_N16384  abs_change
#    av_gas    0.7211     0.7211         0.0
#   av_coal    0.1152     0.1152         0.0
#     av_LF    0.1478     0.1478         0.0
# av_import    0.0183     0.0183         0.0
#  av_hydro    0.0000     0.0000         0.0
#
# Sum of first-order indices: 0.998
# Largest total-order confidence half-width: 0.0132
# Largest ST - S1 difference: 0.0021
# => Converged.
# => Interactions are negligible: the response is essentially additive in the
#    availability multipliers, so each acts independently on shedding.
#   table -> TS_sobol_convergence.csv
#
# Rank comparison (1 = most influential):
#            Morris_rank  Sobol_rank  Morris_mu_star  Sobol_ST
# param
# av_gas               1           1          1120.9    0.7211
# av_coal              3           3           491.2    0.1152
# av_LF                2           2           529.8    0.1478
# av_import            4           4           176.7    0.0183
# av_hydro             5           5             9.7    0.0000
#
# Rankings identical: True
# The variance-based analysis reproduces the Morris ordering exactly.
#   table -> TS_morris_sobol_ranks.csv

# %% [markdown]
# ### 14.1 Correlated fuel shocks

# %%
mdfJ = slice_month("2023-06")
avJ = {t: np.minimum(mdfJ[t].fillna(0.0).values, NETCAP[t]) for t in TECHS}
DJ = mdfJ["Demand"].values
fuels = ["Gas","Coal","Liquid Fuel","Import"]
Cm = np.full((4,4), 0.7); np.fill_diagonal(Cm, 1.0); L = np.linalg.cholesky(Cm)
rngs = np.random.default_rng(SEED); out = {}
for label, corr in (("independent",False),("correlated",True)):
    r = []
    for _ in range(200):
        z = rngs.standard_normal(4)
        mult = np.clip(1+0.10*(L@z if corr else z), 0.5, 1.5)
        a = sum(avJ[t]*(mult[fuels.index(t)] if t in fuels else 1.0) for t in TECHS)
        r.append(np.clip(DJ-a,0,None).mean())
    out[label] = np.array(r)
corr_shock = pd.DataFrame([dict(sampling=k, mean=round(float(v.mean()),1),
                                sd=round(float(v.std()),1),
                                p05=round(float(np.percentile(v,5)),1),
                                p95=round(float(np.percentile(v,95)),1))
                           for k,v in out.items()])
SD_RATIO = out["correlated"].std()/out["independent"].std()
print("June 2023, 200 draws, sd=10%, rho=0.7 across fuel availabilities:")
print(corr_shock.to_string(index=False))
print(f"\nCorrelated shocks widen the distribution by {SD_RATIO:.2f}x and lower the")
print(f"5th percentile from {corr_shock.p05.iloc[0]:.0f} to {corr_shock.p05.iloc[1]:.0f} MW/h,")
print("while the mean is nearly unchanged. They alter TAIL RISK, not central tendency.")
save_table(corr_shock, "TS_correlated_shock")
# Out:
# June 2023, 200 draws, sd=10%, rho=0.7 across fuel availabilities:
#    sampling   mean    sd   p05    p95
# independent 1169.8 605.5 379.6 2226.5
#  correlated 1203.2 780.3 141.9 2430.7
#
# Correlated shocks widen the distribution by 1.29x and lower the
# 5th percentile from 380 to 142 MW/h,
# while the mean is nearly unchanged. They alter TAIL RISK, not central tendency.
#   table -> TS_correlated_shock.csv
# '/content/outputs/tables/TS_correlated_shock.csv'

# %% [markdown]
# ## 15. Figures
#
# `savefig` enforces the submission requirements: final print width (3.54 in
# single column, 7.48 in double), 600 dpi, LZW-compressed TIFF, and **RGB with no
# alpha channel** — Elsevier rejects transparency in TIFF. Building at final size
# keeps label sizes correct rather than letting the typesetter shrink them.

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.patches as mpatches
import matplotlib.font_manager as fm
from PIL import Image
Image.MAX_IMAGE_PIXELS = None

W_SINGLE, W_DOUBLE = 3.54, 7.48
avail_fonts = {f.name for f in fm.fontManager.ttflist}
FONT = ("Times New Roman" if "Times New Roman" in avail_fonts else
        "Liberation Serif" if "Liberation Serif" in avail_fonts else "DejaVu Serif")
plt.rcParams.update({
    "font.family":FONT, "font.size":8, "axes.titlesize":9, "axes.labelsize":8,
    "xtick.labelsize":7, "ytick.labelsize":7, "legend.fontsize":7,
    "axes.spines.top":False, "axes.spines.right":False,
    "figure.dpi":150, "savefig.dpi":600,
    "savefig.facecolor":"white", "savefig.edgecolor":"white"})

Cpal = {"normal":"#2166AC","crisis":"#B2182B","accent":"#F4A261","grey":"#ADB5BD",
        "gas":"#4C72B0","coal":"#55524E","liquid":"#C44E52","imp":"#8172B3","ren":"#55A868"}

def savefig(fig, name, width=W_DOUBLE):
    w0, h0 = fig.get_size_inches()
    if w0 > 0:
        fig.set_size_inches(width, h0*width/w0)
    tif = f"{OUT_FIG}/{name}.tiff"

    def _write():
        fig.savefig(tif, format="tiff", dpi=600, facecolor="white",
                    pil_kwargs={"compression":"tiff_lzw"})
        fig.savefig(f"{OUT_FIG}/{name}.pdf", facecolor="white")

    # constrained layout occasionally fails to solve when a colorbar was added
    # before the engine was set; fall back rather than lose the figure
    try:
        fig.set_layout_engine("constrained"); _write()
    except Exception:
        try:
            fig.set_layout_engine("none"); fig.tight_layout(); _write()
        except Exception:
            fig.set_layout_engine("none"); _write()
    im = Image.open(tif); mode = im.mode
    if mode != "RGB":
        rgb = Image.new("RGB", im.size, (255,255,255))
        rgb.paste(im, mask=im.split()[-1] if mode in ("RGBA","LA") else None)
        rgb.save(tif, format="TIFF", compression="tiff_lzw", dpi=(600,600))
        im = Image.open(tif)
    w, h = im.size
    print(f"  {name}: {w}x{h}px = {w/600:.2f}x{h/600:.2f}in | {mode} -> {im.mode}")
    return tif

print(f"figure style ready | font {FONT} | 8pt base")
# Out:
# figure style ready | font Liberation Serif | 8pt base

# %% [markdown]
# ### Figure 3 — system evolution

# %%
years = annual2["Year"].values
partial = (annual2["hours"] < 8000).values          # 2015 and 2024
CRISIS_X = 2022 + 3/12                              # Q2 2022 changepoint

fig, axes = plt.subplots(3,1, figsize=(7.48,8.0))
ax = axes[0]
ax.plot(years, annual2["Demand_mean"], "-o", color=Cpal["normal"], lw=1.6, ms=3)
ax.axvspan(CRISIS_X, years.max()+0.5, color=Cpal["crisis"], alpha=0.10)
ax.annotate("crisis onset\nQ2 2022", xy=(CRISIS_X, annual2["Demand_mean"].min()),
            xytext=(4,4), textcoords="offset points", fontsize=6.5)
ax.set_ylabel("Mean hourly demand (MW)")
ax.set_title("(a) Demand growth", loc="left", fontweight="bold")

ax = axes[1]
stack = ["Gas_mean","Coal_mean","Liquid_mean","Import_mean","Renewable_mean"]
ax.stackplot(years, [annual2[s] for s in stack],
             labels=["Gas","Coal","Liquid fuel","Import","Renewables"],
             colors=[Cpal["gas"],Cpal["coal"],Cpal["liquid"],Cpal["imp"],Cpal["ren"]],
             alpha=0.85)
ax.plot(years, annual2["Demand_mean"], "k--", lw=1.3, label="Mean demand")
ax.axvspan(CRISIS_X, years.max()+0.5, color=Cpal["crisis"], alpha=0.10)
ax.legend(loc="upper left", ncol=2, frameon=False)
ax.set_ylabel("Mean dispatch (MW)")
ax.set_title("(b) Generation mix", loc="left", fontweight="bold")

ax = axes[2]
b1 = ax.bar(years-0.2, annual2["Loadshed_GWh"], 0.4, color=Cpal["crisis"],
            hatch=["//" if p else "" for p in partial], edgecolor="white",
            linewidth=0.4, label="Unserved energy (GWh)")
ax2 = ax.twinx(); ax2.spines["top"].set_visible(False)
b2 = ax2.bar(years+0.2, annual2["Loadshed_hrs"], 0.4, color=Cpal["accent"],
             hatch=["//" if p else "" for p in partial], edgecolor="white",
             linewidth=0.4, label="Shedding hours")
ax.set_ylabel("Unserved energy (GWh)"); ax2.set_ylabel("Hours with shedding")
ax.set_xlabel("Year"); ax.set_title("(c) Load shedding", loc="left", fontweight="bold")
ax.legend(handles=[b1,b2,mpatches.Patch(facecolor="white", edgecolor=Cpal["grey"],
          hatch="//", label="Partial year")], loc="upper left", frameon=False)
savefig(fig, "Figure3_system_evolution"); plt.show()
# Out:
#   Figure3_system_evolution: 4488x4800px = 7.48x8.00in | RGBA -> RGB

# %% [markdown]
# ### Figure 4 — monthly shedding and changepoint

# %%
mon3 = df.copy(); mon3["ym"] = mon3["datetime"].dt.to_period("M")
mon3 = mon3.groupby("ym").agg(shed=("Loadshed","mean")).reset_index()
mon3["t"] = mon3["ym"].dt.to_timestamp()
cpx = pd.Timestamp(CP["point_estimate"]+"-01")
fig, ax = plt.subplots(figsize=(7.48,3.0))
ax.axvspan(cpx, mon3["t"].max(), color=Cpal["crisis"], alpha=0.12, zorder=0,
           label="Crisis regime")
ax.plot(mon3["t"], mon3["shed"], color=Cpal["crisis"], lw=1.6, zorder=3)
ax.axvline(cpx, color=Cpal["normal"], ls="--", lw=1.3, zorder=2)
ax.annotate(f"Changepoint\n({CP['point_estimate']})\n95% CI to {CP['ci95_high']}",
            xy=(cpx, mon3["shed"].max()*0.82),
            xytext=(pd.Timestamp("2018-06-01"), mon3["shed"].max()*0.78),
            arrowprops=dict(arrowstyle="->", color=Cpal["normal"]),
            color=Cpal["normal"], fontsize=7)
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y"))
ax.set_ylabel("Mean load shed (MW/h)")
ax.legend(loc="upper left", frameon=False)
savefig(fig, "Figure4_monthly_shedding_changepoint"); plt.show()
# Out:
#   Figure4_monthly_shedding_changepoint: 4488x1800px = 7.48x3.00in | RGBA -> RGB

# %% [markdown]
# ### Figure 5 — the adequacy paradox

# %%
fig, axes = plt.subplots(1,2, figsize=(7.48,3.1), layout="constrained")
ax = axes[0]
disp = [worst[t].mean() for t in THERMAL]
idle = [(CAPS[t]-worst[t]).clip(lower=0).mean() for t in THERMAL]
x = np.arange(3)
ax.bar(x, disp, 0.6, color=[Cpal["gas"],Cpal["coal"],Cpal["liquid"]], label="Dispatched")
ax.bar(x, idle, 0.6, bottom=disp, color=Cpal["grey"], alpha=0.7, label="Idle (undispatched)")
for i,t in enumerate(THERMAL):
    ax.text(i, CAPS[t]+90, f"{disp[i]/CAPS[t]*100:.0f}% used", ha="center", fontsize=6.5)
ax.set_xticks(x); ax.set_xticklabels(["Gas","Coal","Liquid fuel"])
ax.set_ylabel("Capacity (MW)")
ax.set_title("(a) Worst-decile shedding hours", loc="left", fontweight="bold")
ax.legend(frameon=False)

ax = axes[1]
xs, ys = shed["Loadshed"].values, shed["idle_thermal"].values
lim = max(np.percentile(xs,99.9), np.percentile(ys,99.9))*1.05
hb = ax.hexbin(xs, ys, gridsize=45, cmap="Reds", bins="log",
               extent=(0,lim,0,lim), mincnt=1, linewidths=0)
ax.plot([0,lim],[0,lim],"k--",lw=1.0,label="Idle = shed")
ax.set_xlim(0,lim); ax.set_ylim(0,lim)
cb = fig.colorbar(hb, ax=ax, pad=0.02); cb.set_label("Hours (log scale)", fontsize=7)
cb.ax.tick_params(labelsize=6)
ax.set_xlabel("Load shed (MW)"); ax.set_ylabel("Idle thermal capacity (MW)")
ax.set_title("(b) All 2022–2024 shedding hours", loc="left", fontweight="bold")
ax.legend(frameon=False, loc="lower right")
savefig(fig, "Figure5_adequacy_paradox"); plt.show()
# Out:
#   Figure5_adequacy_paradox: 4488x1860px = 7.48x3.10in | RGBA -> RGB

# %% [markdown]
# ### Figure 6 — effect sizes

# %%
_VARS = [("Demand","Demand"),("Gas","Gas"),("Coal","Coal"),("Liquid fuel","Liquid Fuel"),
         ("Import","Import"),("Hydro","Hydro"),("Load shedding","Loadshed")]
rng6 = np.random.default_rng(SEED); res6 = []
for name, col in _VARS:
    x = normal[col].dropna().values; y = crisis[col].dropna().values
    d = cohens_d(x, y); bs = []
    for _ in range(BOOTSTRAP_B):
        xb = rng6.choice(x,len(x)); yb = rng6.choice(y,len(y))
        sp = np.sqrt(((len(xb)-1)*xb.var(ddof=1)+(len(yb)-1)*yb.var(ddof=1))/(len(xb)+len(yb)-2))
        bs.append((yb.mean()-xb.mean())/sp)
    lo, hi2 = np.percentile(bs,[2.5,97.5]); res6.append((name,d,lo,hi2))
res6 = sorted(res6, key=lambda r: r[1])
fig, ax = plt.subplots(figsize=(7.48,3.4))
for i,(name,d,lo,hi2) in enumerate(res6):
    ax.errorbar(d, i, xerr=[[d-lo],[hi2-d]], fmt="o",
                color=Cpal["crisis"] if d>0 else Cpal["normal"], capsize=3, ms=5)
ax.axvline(0, color="k", lw=0.8)
ax.set_yticks(np.arange(len(res6))); ax.set_yticklabels([r[0] for r in res6])
ax.set_xlabel("Cohen's d  (crisis − normal, pooled SD)")
ax.text(0.98, 0.04, f"Bootstrap 95% intervals ({BOOTSTRAP_B} resamples) are\nnarrower than the markers",
        transform=ax.transAxes, ha="right", fontsize=6.5, color="#555")
savefig(fig, "Figure6_effect_sizes"); plt.show()
# Out:
#   Figure6_effect_sizes: 4488x2040px = 7.48x3.40in | RGBA -> RGB

# %% [markdown]
# ### Figure 7 — reconstruction fidelity

# %%
vd = val_df
fig, axes = plt.subplots(1,2, figsize=(7.48,3.0))
ax = axes[0]; x = np.arange(len(vd))
ax.bar(x-0.18, vd["obs"], 0.36, color=Cpal["grey"], label="Observed")
ax.bar(x+0.18, vd["model"], 0.36, color=Cpal["crisis"], label="Model")
ax.set_xticks(x)
ax.set_xticklabels([f"{p}\n({s})" for p,s in zip(vd['period'],vd['state'])], fontsize=6.5)
ax.set_ylabel("Mean load shed (MW/h)")
ax.set_title("(a) Observed vs reconstructed", loc="left", fontweight="bold")
ax.legend(frameon=False)
ax = axes[1]
cri = vd[vd["state"]!="Adequate"]; x2 = np.arange(len(cri))
ax.bar(x2, cri["clipped_MW_per_h"], 0.5, color=Cpal["accent"], label="Clipped energy")
ax.plot(x2, cri["bias"], "o-", color=Cpal["crisis"], label="Bias")
ax.set_xticks(x2); ax.set_xticklabels(cri["period"], fontsize=6.5)
ax.set_ylabel("MW/h")
ax.set_title("(b) The bias is clipped energy", loc="left", fontweight="bold")
ax.legend(frameon=False)
savefig(fig, "Figure7_reconstruction_fidelity"); plt.show()
# Out:
#   Figure7_reconstruction_fidelity: 4488x1800px = 7.48x3.00in | RGBA -> RGB

# %% [markdown]
# ### Figure 8 — ablation

# %%
cfg_order = ["IC","no_LF","full"]
cfg_lab = {"IC":"Installed capacity","no_LF":"No liquid-fuel calibration","full":"Full calibration"}
cfg_col = {"IC":Cpal["grey"],"no_LF":Cpal["accent"],"full":Cpal["crisis"]}
per_lab = {"2016-12":"Dec 2016\n(Adequate)","2022-08":"Aug 2022\n(Onset)",
           "2023-06":"Jun 2023\n(Crisis)","2023-08":"Aug 2023\n(Crisis)"}
def _v(p,c,f):
    r = abl_df[(abl_df["period"]==p)&(abl_df["config"]==c)]
    return float(r[f].iloc[0]) if len(r) else np.nan
fig, axes = plt.subplots(1,2, figsize=(7.48,3.2))
x = np.arange(len(PERIODS)); w = 0.24
ax = axes[0]
for j,cfg in enumerate(cfg_order):
    ax.bar(x+(j-1)*w, [_v(p,cfg,"model") for p in PERIODS], w,
           color=cfg_col[cfg], label=cfg_lab[cfg])
ax.plot(x, [_v(p,"full","obs") for p in PERIODS], "k_", ms=16, mew=2, label="Observed")
ax.set_xticks(x); ax.set_xticklabels([per_lab[p] for p in PERIODS], fontsize=6.5)
ax.set_ylabel("Mean load shed (MW/h)")
ax.set_title("(a) Modelled vs observed", loc="left", fontweight="bold")
ax.legend(frameon=False, fontsize=6.5)
ax = axes[1]
for j,cfg in enumerate(cfg_order):
    ax.bar(x+(j-1)*w, [_v(p,cfg,"mae") for p in PERIODS], w, color=cfg_col[cfg])
ax.set_xticks(x); ax.set_xticklabels([per_lab[p] for p in PERIODS], fontsize=6.5)
ax.set_ylabel("MAE (MW/h)")
ax.set_title("(b) Mean absolute error", loc="left", fontweight="bold")
savefig(fig, "Figure8_ablation"); plt.show()
# Out:
#   Figure8_ablation: 4488x1920px = 7.48x3.20in | RGBA -> RGB

# %% [markdown]
# ### Figure 9 — out-of-sample timing skill

# %%
fig, axes = plt.subplots(1,2, figsize=(7.48,3.2))
cols = {"Jun2023":Cpal["crisis"],"Aug2023":Cpal["normal"]}
ax = axes[0]
for nm, dd in OOS_CAPTURE.items():
    ax.scatter(dd["obs"], dd["model"], s=5, alpha=0.35, color=cols[nm],
               label=f"{nm} (pooled r={dd['pooled_r']:.2f})", rasterized=True)
lim = max(max(dd["obs"].max(), dd["model"].max()) for dd in OOS_CAPTURE.values())*1.03
ax.plot([0,lim],[0,lim],"k--",lw=1)
ax.set_xlabel("Observed held-out shed (MW)"); ax.set_ylabel("Predicted shed (MW)")
ax.set_title("(a) Pooled held-out predictions", loc="left", fontweight="bold")
ax.legend(frameon=False)
ax = axes[1]
sub = oos_null[oos_null.protocol=="rolling-origin"]
labs = ["A","B","C","D"]; xs = np.arange(4)
for i, ym in enumerate(["2023-06","2023-08"]):
    v = [sub[(sub.month==ym)&(sub.spec==NAMES[k])]["r"].iloc[0] for k in labs]
    ax.bar(xs+(i-0.5)*0.38, v, 0.38,
           color=[Cpal["crisis"],Cpal["normal"]][i],
           label="Jun 2023" if i==0 else "Aug 2023")
ax.set_xticks(xs); ax.set_xticklabels(["A\nper-tech","B\nconst cap","C\ndemand","D\naggregate"],
                                      fontsize=6.5)
ax.set_ylabel("Pooled correlation r"); ax.set_ylim(0,1.05)
ax.set_title("(b) Against null models", loc="left", fontweight="bold")
ax.legend(frameon=False)
savefig(fig, "Figure9_oos_timing_skill"); plt.show()
# Out:
#   Figure9_oos_timing_skill: 4488x1920px = 7.48x3.20in | RGBA -> RGB

# %% [markdown]
# ### Figure 10 — sensitivity

# %%
if gsa is not None:
    LAB = {'ls_NW':'Load share (NW)','ls_NE':'Load share (NE)','ls_Dhaka':'Load share (Dhaka)',
           'ls_SW':'Load share (SW)','ls_CTG':'Load share (CTG)','corridor_cap':'Corridor capacity',
           'mc_gas':'Marginal cost (gas)','mc_coal':'Marginal cost (coal)',
           'mc_import':'Marginal cost (import)','mc_LF':'Marginal cost (liquid fuel)',
           'shed_penalty':'Shedding penalty','av_gas':'Gas availability',
           'av_coal':'Coal availability','av_LF':'Liquid-fuel availability',
           'av_import':'Import availability','av_hydro':'Hydro availability'}
    r10 = gsa.copy(); r10["is_av"] = r10["param"].str.startswith("av_")
    fig, axes = plt.subplots(1,2, figsize=(7.48,3.2),
                             gridspec_kw={"width_ratios":[1.25,1]})
    ax = axes[0]; top = r10.sort_values("mu_star")
    ax.barh([LAB[p] for p in top["param"]], top["mu_star"],
            color=[Cpal["crisis"] if a else Cpal["grey"] for a in top["is_av"]])
    ax.set_xlabel("Elementary-effect measure μ* (MW/h)")
    ax.set_title("(a) Parameter influence on crisis shedding", loc="left", fontweight="bold")
    ax.legend(handles=[mpatches.Patch(color=Cpal["crisis"], label="Availability"),
                       mpatches.Patch(color=Cpal["grey"], label="Network / economic / load-share")],
              frameon=False, loc="lower right")
    ax = axes[1]
    lab10 = r10[r10["mu_star"]>50].sort_values("mu_star", ascending=False)
    ax.scatter(r10["mu_star"], r10["sigma"],
               color=[Cpal["crisis"] if a else Cpal["grey"] for a in r10["is_av"]], s=26, zorder=3)
    # coal and liquid fuel sit almost on top of each other, so offsets are set
    # per parameter rather than cycled, with leader lines long enough to separate
    # coal and liquid fuel nearly coincide, so labels sit ABOVE their points at
    # staggered heights rather than radiating outward, which collides
    OFF = {"av_gas":(0,20,"center","bottom"), "av_LF":(0,20,"center","bottom"),
           "av_coal":(0,48,"center","bottom"), "av_import":(-10,0,"right","center")}
    for _, row in lab10.iterrows():
        dx, dy, ha, va = OFF.get(row["param"], (0,20,"center","bottom"))
        ax.annotate(LAB[row["param"]], (row["mu_star"], row["sigma"]), fontsize=6.5,
                    xytext=(dx,dy), textcoords="offset points", ha=ha, va=va,
                    arrowprops=dict(arrowstyle="-", lw=0.4, color="#888888",
                                    shrinkA=0, shrinkB=3))
    n_small = int((r10["mu_star"]<=50).sum())
    ax.text(0.97, 0.06, f"{n_small} further parameters\ncluster at μ* ≈ 0",
            transform=ax.transAxes, ha="right", va="bottom",
            fontsize=6.5, color="#6C757D")
    mx = max(r10["mu_star"].max(),1)
    ax.plot([0,mx],[0,mx],"k--",lw=0.8); ax.set_xlim(-mx*0.06, mx*1.30)
    ax.set_ylim(top=max(r10["sigma"].max(),1)*1.32)
    ax.set_xlabel("μ*"); ax.set_ylabel("σ")
    ax.set_title("(b) μ*–σ diagnostic", loc="left", fontweight="bold")
    savefig(fig, "Figure10_gsa"); plt.show()
else:
    print("skipped (RUN_GSA = False)")
# Out:
#   Figure10_gsa: 4488x1920px = 7.48x3.20in | RGBA -> RGB

# %% [markdown]
# ### Figure 11 — capacity sweep

# %%
if sweep_df is not None:
    fig, axes = plt.subplots(1,2, figsize=(7.48,3.0))
    mcol = {"2023-06":Cpal["crisis"],"2023-08":Cpal["normal"]}
    mst  = {"Gas":"-o","Import":"--s"}
    ax = axes[0]
    for (ym,tech), dd in sweep_df.groupby(["month","tech"]):
        ax.plot(dd.added_MW, dd.avg_eff, mst[tech], color=mcol[ym], ms=3.5, lw=1.4,
                label=f"{'Jun' if ym=='2023-06' else 'Aug'} 2023 – {tech}")
    ax.set_xlabel("Fuel-secured capacity added (MW)")
    ax.set_ylabel("Average effectiveness (MW/MW)"); ax.set_ylim(0,1)
    ax.set_title("(a) Average effectiveness", loc="left", fontweight="bold")
    ax.legend(frameon=False, fontsize=6.5)
    ax = axes[1]
    for (ym,tech), dd in sweep_df.groupby(["month","tech"]):
        ax.plot(dd.added_MW, dd.marg_eff, mst[tech], color=mcol[ym], ms=3.5, lw=1.4)
    ax.set_xlabel("Fuel-secured capacity added (MW)")
    ax.set_ylabel("Marginal effectiveness (MW/MW)"); ax.set_ylim(0,1)
    ax.set_title("(b) Marginal effectiveness", loc="left", fontweight="bold")
    savefig(fig, "Figure11_capacity_sweep"); plt.show()
else:
    print("skipped (RUN_SWEEP = False)")
# Out:
#   Figure11_capacity_sweep: 4488x1800px = 7.48x3.00in | RGBA -> RGB

# %% [markdown]
# ### Figure 12 — capacity-assumption robustness

# %%
lams = np.arange(0.55,1.46,0.025)
gt_s, gt_0, idle_m = [], [], []
for lam in lams:
    idle = sum((CAPS[t]*lam-shed[t].fillna(0.0)).clip(lower=0) for t in THERMAL)
    gt_s.append(100*float((idle>shed["Loadshed"]).mean()))
    gt_0.append(100*float((idle>0).mean())); idle_m.append(float(idle.mean()))
fig, axes = plt.subplots(1,2, figsize=(7.48,3.0))
ax = axes[0]
ax.plot(lams, gt_s, color=Cpal["crisis"], lw=1.8, label="Idle > shortfall")
ax.plot(lams, gt_0, color=Cpal["normal"], lw=1.4, ls="--", label="Idle > 0")
ax.axvspan(IMPLIED_LAMBDA, lams.max(), color=Cpal["ren"], alpha=0.12)
ax.axvline(1.0, color="k", lw=0.8, ls=":"); ax.axhline(95, color=Cpal["grey"], lw=0.8, ls=":")
ax.annotate("as modelled", xy=(1.0,71), xytext=(-30,0), fontsize=6.5,
            textcoords="offset points", ha="right", va="center",
            arrowprops=dict(arrowstyle="->", lw=0.5, color="k"))
ax.annotate("range implied\nby the record", xy=(IMPLIED_LAMBDA+0.14,66), fontsize=6.5,
            color="#2C6E49", ha="center", va="center")
ax.set_xlabel("Thermal nameplate scaling factor λ")
ax.set_ylabel("Share of shedding hours (%)"); ax.set_ylim(58,102)
ax.set_title("(a) Robustness of the idle-capacity finding", loc="left", fontweight="bold")
ax.legend(frameon=False, loc="lower right")
ax = axes[1]
ax.plot(lams, idle_m, color=Cpal["crisis"], lw=1.8)
ax.axhline(shed["Loadshed"].mean(), color="k", ls="--", lw=1.0)
ax.annotate(f"mean shortfall {shed['Loadshed'].mean():.0f} MW",
            xy=(1.30, shed["Loadshed"].mean()), xytext=(0,16),
            textcoords="offset points", fontsize=6.5, ha="center")
ax.axvspan(IMPLIED_LAMBDA, lams.max(), color=Cpal["ren"], alpha=0.12)
ax.axvline(1.0, color="k", lw=0.8, ls=":")
ax.set_xlabel("Thermal nameplate scaling factor λ")
ax.set_ylabel("Mean idle thermal capacity (MW)")
ax.set_title("(b) Idle margin against the shortfall", loc="left", fontweight="bold")
savefig(fig, "Figure12_capacity_robustness"); plt.show()
# Out:
#   Figure12_capacity_robustness: 4488x1800px = 7.48x3.00in | RGBA -> RGB

# %% [markdown]
# ### Figure 13 — effectiveness distribution

# %%
order = ["Hydro","Coal","Liquid Fuel","Gas","Import","Fuel-secured"]
series = {t: hi[f"{t}_inherits"].values for t in DISPATCHABLE}
series["Fuel-secured"] = hi["secured"].values
fig, axes = plt.subplots(1,2, figsize=(7.48,3.2), gridspec_kw={"width_ratios":[1,1.35]})
ax = axes[0]
bp = ax.boxplot([series[t] for t in order], vert=False, widths=0.6, patch_artist=True,
                medianprops=dict(color="k", lw=1.2),
                flierprops=dict(marker="o", ms=2, alpha=0.5))
cols13 = [Cpal["ren"],Cpal["coal"],Cpal["liquid"],Cpal["gas"],Cpal["imp"],Cpal["accent"]]
for patch,c in zip(bp["boxes"], cols13): patch.set_facecolor(c); patch.set_alpha(0.65)
for i,t in enumerate(order): ax.scatter(series[t].mean(), i+1, marker="D", s=14, color="k", zorder=5)
ax.set_yticklabels(order); ax.set_xlim(0,1.08)
ax.set_xlabel("Shedding avoided per MW added (MW/MW)")
ax.set_title(f"(a) Across {N_HI} high-stress months", loc="left", fontweight="bold")
ax.scatter([],[], marker="D", s=14, color="k", label="mean")
ax.legend(frameon=False, loc="upper left", handletextpad=0.3, bbox_to_anchor=(0.0,1.02))
ax = axes[1]
xt = pd.to_datetime(interv["month"]+"-01")
for t,c in [("Import",Cpal["imp"]),("Gas",Cpal["gas"]),
            ("Coal",Cpal["coal"]),("Liquid Fuel",Cpal["liquid"])]:
    ax.plot(xt, interv[f"{t}_inherits"], "-o", ms=2.2, lw=1.2, color=c, label=t)
ax.axhline(0.011, color=Cpal["grey"], ls="--", lw=1.0, label="Battery storage (<0.011)")
ax.set_ylim(-0.03,1.18); ax.set_ylabel("Effectiveness (MW/MW)")
ax.set_title("(b) Month by month, 2022–2024", loc="left", fontweight="bold")
ax.legend(ncol=2, loc="upper left", frameon=True, framealpha=0.95, facecolor="white",
          edgecolor="none", handlelength=1.6, columnspacing=1.0)
savefig(fig, "Figure13_effectiveness_distribution"); plt.show()
# Out:
#   Figure13_effectiveness_distribution: 4488x1920px = 7.48x3.20in | RGBA -> RGB

# %% [markdown]
# ### Figure 14 — seasonality

# %%
fig, axes = plt.subplots(1,2, figsize=(7.48,3.0))
x = np.arange(12); warm_i = [3,4,5,6,7,8,9]
ax = axes[0]
ax.bar(x, seas["mean_shed_mw"], 0.68,
       color=[Cpal["crisis"] if i in warm_i else Cpal["normal"] for i in x], alpha=0.85)
ax2 = ax.twinx(); ax2.spines["top"].set_visible(False)
ax2.plot(x, seas["mean_demand_mw"], "k--o", ms=2.5, lw=1.2)
ax.set_xticks(x); ax.set_xticklabels(seas["month"], fontsize=6.5)
ax.set_ylabel("Mean shedding (MW)"); ax2.set_ylabel("Mean demand (MW)"); ax2.set_ylim(0,14000)
ax.set_title("(a) Shedding is far more seasonal than demand", loc="left", fontweight="bold")
ax.legend(handles=[mpatches.Patch(color=Cpal["crisis"], alpha=0.85, label="Warm season (Apr–Oct)"),
                   mpatches.Patch(color=Cpal["normal"], alpha=0.85, label="Cool season (Nov–Mar)"),
                   plt.Line2D([],[],color="k",ls="--",marker="o",ms=2.5,lw=1.2,label="Mean demand")],
          loc="center left", bbox_to_anchor=(0.01,0.34), frameon=True, framealpha=0.95,
          facecolor="white", edgecolor="none", handlelength=1.6)
ax.text(0.98,0.97, f"demand {DEM_RATIO:.2f}×\nshedding {SHED_RATIO:.1f}×",
        transform=ax.transAxes, va="top", ha="right", fontsize=6.5)
ax = axes[1]
ax.bar(x, seas["mean_idle_mw"], 0.68, color=Cpal["grey"], alpha=0.8, label="Idle thermal")
ax.plot(x, seas["mean_shed_mw"], "-o", ms=3, lw=1.4, color=Cpal["crisis"], label="Mean shortfall")
ax.set_xticks(x); ax.set_xticklabels(seas["month"], fontsize=6.5); ax.set_ylabel("MW")
ax.set_title("(b) Idle capacity exceeds the shortfall year-round", loc="left", fontweight="bold")
ax.legend(frameon=False, loc="upper right")
savefig(fig, "Figure14_seasonality"); plt.show()
# Out:
#   Figure14_seasonality: 4488x1800px = 7.48x3.00in | RGBA -> RGB

# %% [markdown]
# ### Figure compliance check

# %%
import glob
print(f"  {'file':44s} {'px':>13s} {'inches':>13s} {'mode':>5s} {'OK':>4s}")
ok_all = True
for f in sorted(glob.glob(f"{OUT_FIG}/*.tiff")):
    im = Image.open(f); w,h = im.size; wi,hi2 = w/600, h/600
    ok = (im.mode=="RGB") and (3.2 <= wi <= 7.6); ok_all &= ok
    print(f"  {os.path.basename(f):44s} {f'{w}x{h}':>13s} {f'{wi:.2f}x{hi2:.2f}':>13s} "
          f"{im.mode:>5s} {'yes' if ok else 'NO':>4s}")
print("\n  " + ("ALL FIGURES MEET SUBMISSION REQUIREMENTS"
                if ok_all else "SOME FIGURES FAIL - see NO above"))
# Out:
#   file                                                    px        inches  mode   OK
#   Figure10_gsa.tiff                                4488x1920     7.48x3.20   RGB  yes
#   Figure11_capacity_sweep.tiff                     4488x1800     7.48x3.00   RGB  yes
#   Figure12_capacity_robustness.tiff                4488x1800     7.48x3.00   RGB  yes
#   Figure13_effectiveness_distribution.tiff         4488x1920     7.48x3.20   RGB  yes
#   Figure14_seasonality.tiff                        4488x1800     7.48x3.00   RGB  yes
#   Figure3_system_evolution.tiff                    4488x4800     7.48x8.00   RGB  yes
#   Figure4_monthly_shedding_changepoint.tiff        4488x1800     7.48x3.00   RGB  yes
#   Figure5_adequacy_paradox.tiff                    4488x1860     7.48x3.10   RGB  yes
#   Figure6_effect_sizes.tiff                        4488x2040     7.48x3.40   RGB  yes
#   Figure7_reconstruction_fidelity.tiff             4488x1800     7.48x3.00   RGB  yes
#   Figure8_ablation.tiff                            4488x1920     7.48x3.20   RGB  yes
#   Figure9_oos_timing_skill.tiff                    4488x1920     7.48x3.20   RGB  yes
#
#   ALL FIGURES MEET SUBMISSION REQUIREMENTS

# %% [markdown]
# ## 16. Alignment checklist
#
# Every number quoted in the manuscript, printed from this run. Check the
# manuscript against it line by line before submission.

# %%
rule("ALIGNMENT CHECKLIST")

print("\n§2.1 DATA")
print(f"  bounds {INTEG['start']} -> {INTEG['end']}")
print(f"  {INTEG['rows']:,} rows | missing {INTEG['missing']} | duplicated {INTEG['duplicated']}")
print(f"  Eq.2 max residual {INTEG['eq2_max']:.2e}")
print(f"  Eq.1 mean {INTEG['eq1_mean']:+} MW | mean abs {INTEG['eq1_mean_abs']} MW "
      f"| >1 MW in {INTEG['eq1_gap_gt1_pct']}% of hours")
print(f"  anomaly screen: {len(FLAG)} hours flagged, "
      f"{sum(1 for k in FLAG if df.loc[k,'datetime'].year>=2022)} inside 2022-2024")

print("\n§2.2 REGIMES")
print(f"  changepoint {CP['point_estimate']} (95% CI {CP['ci95_low']} to {CP['ci95_high']}, "
      f"exact recovery {CP['exact_recovery_pct']}%)")
print(f"  invariant to cost function, min_size and penalty (see TS_changepoint_robustness)")
print(f"  cluster: {len(CLUSTER)} non-consecutive months {CLUSTER[0]}-{CLUSTER[-1]}, "
      f"silhouette {SIL:.3f}")
print(f"  excluded within window ({len(EXCLUDED)}): {', '.join(EXCLUDED)}")

print("\n§2.4 MODEL")
print(f"  dispatchable fleet {sum(NETCAP.values()):,.0f} MW | virtual shedding {LS_TOTAL:,.1f} MW")
print(f"  closed form vs LP: max abs difference {cfv['abs_diff'].max():.8f} MW/h")
print(f"  max observed shortfall {df['Loadshed'].max():,.0f} MW at "
      f"{df.loc[df['Loadshed'].idxmax(),'datetime']}")
print("  battery 500 MW / 4 h at Dhaka, 0.95/0.95 (90.25% round trip), cyclic")

print("\n§3.1 IDLE CAPACITY")
print(f"  crisis {IDLE['crisis_hours']:,} h | shedding {IDLE['shedding_hours']:,} h")
print(f"  mean idle {IDLE['mean_idle']:,} MW vs mean shortfall {IDLE['mean_shortfall']} MW")
print(f"  idle > shortfall {IDLE['idle_gt_shortfall']}%  <- REPORT THIS NUMBER WITH THIS WORDING")
print(f"  idle > 0         {IDLE['idle_gt_zero']}%")

print("\n§3.2 CAPACITY ROBUSTNESS")
print(f"  implied lambda >= {IMPLIED_LAMBDA:.2f} ({ssum.max():,.0f} MW delivered simultaneously)")
for _, r in cap_rob.iterrows():
    print(f"    lambda {r['lam']:.2f}: idle>shortfall {r['idle_gt_shortfall_pct']:.2f}%")

print("\n§3.3 TRANSMISSION")
print(f"  June 2023 peak corridor utilisation (as shipped): {UTIL_JUN:.1f}%")
if trans is not None:
    print(f"  {N_CHANGED} of {len(trans)} months change by >1 MW/h at 30% derating")
    print(f"  peak utilisation across all crisis months (sized shedding): {UTIL_ALL:.1f}%")

print("\n§3.5 SEASONALITY")
print(f"  warm LOLP {warm.lolp_pct.mean():.1f}% shed {warm.mean_shed_mw.mean():.0f} MW "
      f"demand {warm.mean_demand_mw.mean():,.0f} MW")
print(f"  cool LOLP {cool.lolp_pct.mean():.1f}% shed {cool.mean_shed_mw.mean():.0f} MW "
      f"demand {cool.mean_demand_mw.mean():,.0f} MW")
print(f"  demand ratio {DEM_RATIO:.2f}x | shedding ratio {SHED_RATIO:.1f}x")

print("\n§3.4 PAYRA")
print(f"  raw before/after {raw:+.0f} MW | DiD {DID:+.4f} CF = {DID_MW:+,.0f} MW "
      f"= {DID_PCT:.0f}% of nameplate")
print(f"  OLS {OLS_B:+.4f} (se {OLS_SE:.4f}, p {OLS_P:.4g})")

print("\n§4 RELIABILITY")
for _, r in rel[rel.period.str.contains("-")].iterrows():
    print(f"  {r['period']:22s} LOLE {r['LOLE_h']:>6,} h | LOLP {r['LOLP_pct']:>5}% "
          f"| EENS {r['EENS_GWh_yr']:>7} GWh/yr")

print("\n§4.3 RECONSTRUCTION FIDELITY")
for _, r in val_df.iterrows():
    print(f"  {r['period']}: model {r['model']:>7.2f} bias {r['bias']:+7.2f} mae {r['mae']:>6.2f} "
          f"| clipped {r['clipped_MW_per_h']:>6.1f} MW/h ({r['dominant_carrier']})")

print("\n§4.4 ABLATION")
for _, r in abl_df.iterrows():
    print(f"  {r['period']} {r['config']:6s} obs {r['obs']:>7.2f} model {r['model']:>7.2f} "
          f"mae {r['mae']:>7.2f}")

print("\n§4.6 OUT-OF-SAMPLE")
for _, r in oos_null.iterrows():
    print(f"  {r['month']} {r['protocol']:15s} {r['spec'][:44]:44s} r={r['r']:.3f} mae={r['mae']:.1f}")

print("\n§4.6 SUPPORTING TESTS")
print(f"  fold-count sensitivity: pooled r " +
      ", ".join(f"K={r['K']} {r['pooled_r']:.3f}" for _, r in fold_sens[fold_sens.month=='2023-06'].iterrows()))
print(f"  negative results: every specification has R2 < 0 "
      f"(best {forward_cv['r2_mean'].max():.3f}, {forward_cv.loc[forward_cv['r2_mean'].idxmax(),'spec']})")
for _, r in testc_infeasible.iterrows():
    print(f"  excluded test C: {r['period']} infeasible in {r['infeasible_hours']} of "
          f"{r['hours']} hours ({r['share_pct']}%)")

print("\n§5.2 INTERVENTIONS")
print(f"  across {N_HI} months with baseline shedding above 100 MW/h:")
for _, r in iv_summary.iterrows():
    rf = "" if pd.isna(r["ranked_first"]) else f" first in {int(r['ranked_first'])}"
    print(f"    {r['technology']:13s} mean {r['mean']:.3f} sd {r['sd']:.3f} "
          f"range {r['min']:.3f}-{r['max']:.3f}{rf}")

print("\n§5.4 STORAGE")
for _, r in bat.iterrows():
    print(f"  {r['period']} {r['mode']:7s} effectiveness {r['effectiveness']:.4f} "
          f"charged {r['charged_mwh']:>7,.0f} MWh")
for _, r in ebal.iterrows():
    print(f"  {r['period']} energy balance {r['balance_gwh']:+,.0f} GWh")

print("\n§4.7 SENSITIVITY")
if gsa is not None:
    for _, r in gsa.head(5).iterrows():
        print(f"  {r['param']:14s} mu* {r['mu_star']:8.1f} sigma {r['sigma']:6.1f}")
    print(f"  max mu* among non-availability parameters: "
          f"{gsa[~gsa.param.str.startswith('av_')]['mu_star'].max():.4f}")
if sob is not None:
    for _, r in sob.iterrows():
        print(f"  {r['param']:14s} S1 {r['S1']:.4f}  ST {r['ST']:.4f}")
    print(f"  Morris and Sobol rankings identical: {RANKS_IDENTICAL}")
print(f"  correlated/independent sd ratio {SD_RATIO:.2f}x | "
      f"p05 {corr_shock.p05.iloc[0]:.0f} -> {corr_shock.p05.iloc[1]:.0f} MW/h")

rule(f"COMPLETE in {(time.time()-T_START)/60:.1f} min")
print(f"  tables  -> {OUT_TAB}")
print(f"  figures -> {OUT_FIG}")
# Out:
# ==============================================================================
# ALIGNMENT CHECKLIST
# ==============================================================================
#
# §2.1 DATA
#   bounds 2015-04-20 00:00:00 -> 2024-11-25 17:00:00
#   84,186 rows | missing 0 | duplicated 0
#   Eq.2 max residual 0.00e+00
#   Eq.1 mean +7.84 MW | mean abs 17.2 MW | >1 MW in 15.7% of hours
#   anomaly screen: 91 hours flagged, 9 inside 2022-2024
#
# §2.2 REGIMES
#   changepoint 2022-04 (95% CI 2022-04 to 2023-02, exact recovery 87.5%)
#   invariant to cost function, min_size and penalty (see TS_changepoint_robustness)
#   cluster: 20 non-consecutive months 2022-07-2024-11, silhouette 0.537
#   excluded within window (9): 2022-11, 2022-12, 2023-01, 2023-02, 2023-03, 2023-11, 2023-12, 2024-01, 2024-02
#
# §2.4 MODEL
#   dispatchable fleet 16,507 MW | virtual shedding 5,365.5 MW
#   closed form vs LP: max abs difference 0.00000000 MW/h
#   max observed shortfall 8,496 MW at 2022-10-04 15:00:00
#   battery 500 MW / 4 h at Dhaka, 0.95/0.95 (90.25% round trip), cyclic
#
# §3.1 IDLE CAPACITY
#   crisis 25,434 h | shedding 12,290 h
#   mean idle 4,416.7 MW vs mean shortfall 556.1 MW
#   idle > shortfall 99.77%  <- REPORT THIS NUMBER WITH THIS WORDING
#   idle > 0         99.98%
#
# §3.2 CAPACITY ROBUSTNESS
#   implied lambda >= 1.06 (15,697 MW delivered simultaneously)
#     lambda 0.60: idle>shortfall 64.74%
#     lambda 0.70: idle>shortfall 77.75%
#     lambda 0.80: idle>shortfall 89.21%
#     lambda 0.90: idle>shortfall 97.16%
#     lambda 1.00: idle>shortfall 99.77%
#     lambda 1.10: idle>shortfall 100.00%
#     lambda 1.20: idle>shortfall 100.00%
#     lambda 1.35: idle>shortfall 100.00%
#
# §3.3 TRANSMISSION
#   June 2023 peak corridor utilisation (as shipped): 26.0%
#   0 of 35 months change by >1 MW/h at 30% derating
#   peak utilisation across all crisis months (sized shedding): 51.4%
#
# §3.5 SEASONALITY
#   warm LOLP 64.5% shed 408 MW demand 12,169 MW
#   cool LOLP 22.0% shed 52 MW demand 8,868 MW
#   demand ratio 1.37x | shedding ratio 7.8x
#
# §3.4 PAYRA
#   raw before/after -301 MW | DiD -0.1278 CF = -530 MW = 40% of nameplate
#   OLS -0.1278 (se 0.0140, p 8.004e-20)
#
# §4 RELIABILITY
#   2015-2021 pre-crisis   LOLE     86 h | LOLP  0.15% | EENS     3.8 GWh/yr
#   2022-2024 crisis       LOLE 12,289 h | LOLP 48.32% | EENS  2354.1 GWh/yr
#
# §4.3 RECONSTRUCTION FIDELITY
#   2016-12: model    6.18 bias   +6.18 mae   6.18 | clipped    1.1 MW/h (Gas)
#   2022-08: model  904.24 bias +134.74 mae 158.75 | clipped  149.2 MW/h (Liquid Fuel)
#   2023-06: model 1038.81 bias  +56.97 mae  79.24 | clipped   79.1 MW/h (Gas)
#   2023-08: model  367.38 bias   +3.93 mae  13.18 | clipped    4.3 MW/h (Liquid Fuel)
#
# §4.4 ABLATION
#   2016-12 IC     obs    0.00 model    0.00 mae    0.00
#   2016-12 no_LF  obs    0.00 model    0.00 mae    0.00
#   2016-12 full   obs    0.00 model    6.18 mae    6.18
#   2022-08 IC     obs  769.49 model    0.00 mae  769.49
#   2022-08 no_LF  obs  769.49 model  478.46 mae  582.67
#   2022-08 full   obs  769.49 model  904.24 mae  158.75
#   2023-06 IC     obs  981.84 model    0.91 mae  980.93
#   2023-06 no_LF  obs  981.84 model  282.12 mae  763.91
#   2023-06 full   obs  981.84 model 1038.81 mae   79.24
#   2023-08 IC     obs  363.45 model    0.00 mae  363.45
#   2023-08 no_LF  obs  363.45 model   14.81 mae  354.46
#   2023-08 full   obs  363.45 model  367.38 mae   13.18
#
# §4.6 OUT-OF-SAMPLE
#   2023-06 rolling-origin  per-technology hour-of-day [as specified]    r=0.919 mae=475.0
#   2023-06 rolling-origin  constant capacity (null)                     r=0.749 mae=617.2
#   2023-06 rolling-origin  demand only (null)                           r=0.703 mae=11491.9
#   2023-06 rolling-origin  aggregate hour-of-day (null)                 r=0.919 mae=475.0
#   2023-06 forward-only    per-technology hour-of-day [as specified]    r=0.906 mae=214.8
#   2023-06 forward-only    aggregate hour-of-day (null)                 r=0.906 mae=214.8
#   2023-08 rolling-origin  per-technology hour-of-day [as specified]    r=0.783 mae=317.9
#   2023-08 rolling-origin  constant capacity (null)                     r=0.494 mae=513.6
#   2023-08 rolling-origin  demand only (null)                           r=0.522 mae=12206.0
#   2023-08 rolling-origin  aggregate hour-of-day (null)                 r=0.783 mae=317.9
#   2023-08 forward-only    per-technology hour-of-day [as specified]    r=0.763 mae=388.9
#   2023-08 forward-only    aggregate hour-of-day (null)                 r=0.763 mae=388.9
#
# §4.6 SUPPORTING TESTS
#   fold-count sensitivity: pooled r K=4 0.917, K=5 0.919, K=6 0.923, K=8 0.926
#   negative results: every specification has R2 < 0 (best -0.182, AR(1))
#   excluded test C: 2023-06 infeasible in 287 of 720 hours (39.9%)
#   excluded test C: 2023-08 infeasible in 261 of 744 hours (35.1%)
#
# §5.2 INTERVENTIONS
#   across 26 months with baseline shedding above 100 MW/h:
#     Gas           mean 0.492 sd 0.199 range 0.152-0.760 first in 2
#     Coal          mean 0.356 sd 0.241 range 0.061-0.852 first in 3
#     Liquid Fuel   mean 0.371 sd 0.146 range 0.125-0.743 first in 3
#     Import        mean 0.543 sd 0.238 range 0.189-1.000 first in 17
#     Hydro         mean 0.324 sd 0.270 range 0.039-0.934 first in 1
#     Fuel-secured  mean 0.569 sd 0.239 range 0.194-1.000
#
# §5.4 STORAGE
#   2016-12 hourly  effectiveness 0.0105 charged   4,315 MWh
#   2016-12 daily   effectiveness 0.0056 charged   2,289 MWh
#   2023-06 hourly  effectiveness 0.0038 charged   1,526 MWh
#   2023-06 daily   effectiveness 0.0017 charged     694 MWh
#   2023-08 hourly  effectiveness 0.0028 charged   1,162 MWh
#   2023-08 daily   effectiveness 0.0007 charged     300 MWh
#   2016-12 energy balance +4 GWh
#   2022-08 energy balance -672 GWh
#   2023-06 energy balance -746 GWh
#   2023-08 energy balance -272 GWh
#
# §4.7 SENSITIVITY
#   av_gas         mu*   1120.9 sigma  477.1
#   av_LF          mu*    529.8 sigma   61.1
#   av_coal        mu*    491.2 sigma   45.6
#   av_import      mu*    176.7 sigma   68.7
#   av_hydro       mu*      9.7 sigma    1.3
#   max mu* among non-availability parameters: 0.0000
#   av_gas         S1 0.7190  ST 0.7211
#   av_LF          S1 0.1469  ST 0.1478
#   av_coal        S1 0.1138  ST 0.1152
#   av_import      S1 0.0180  ST 0.0183
#   av_hydro       S1 0.0000  ST 0.0000
#   Morris and Sobol rankings identical: True
#   correlated/independent sd ratio 1.29x | p05 380 -> 142 MW/h
#
# ==============================================================================
# COMPLETE in 40.7 min
# ==============================================================================
#   tables  -> /content/outputs/tables
#   figures -> /content/outputs/figures

# %% [markdown]
# ## 17. Export

# %%
import shutil, glob
shutil.make_archive("/content/manuscript_outputs", "zip", "/content/outputs")
print("tables :", len(glob.glob(f"{OUT_TAB}/*.csv")))
print("figures:", len(glob.glob(f"{OUT_FIG}/*.tiff")), "tiff +",
      len(glob.glob(f"{OUT_FIG}/*.pdf")), "pdf")

from google.colab import files
files.download("/content/manuscript_outputs.zip")
# Out:
# tables : 34
# figures: 12 tiff + 12 pdf

# %% [markdown]
# ## 18. Inspect Network File

# %%
import pypsa
import pandas as pd
import shutil

pd.set_option("display.width", 200)
pd.set_option("display.max_rows", 100)

# Use the network downloaded in the main input/setup cell
BASE = BASE_PATH
BACKUP = BASE.replace(".nc", "_BACKUP.nc")

# Keep a local backup before inspecting or modifying the network
shutil.copy2(BASE, BACKUP)

n = pypsa.Network(BASE)

print("buses        ", len(n.buses), list(n.buses.index))
print("generators   ", len(n.generators))
print("lines        ", len(n.lines))
print("loads        ", len(n.loads))
print("storage units", len(n.storage_units))

display(
    n.generators[
        ["bus", "carrier", "p_nom", "marginal_cost"]
    ]
)

display(
    n.lines[
        ["bus0", "bus1", "s_nom"]
    ]
)

display(
    n.generators
    .groupby("carrier")["p_nom"]
    .sum()
    .round(1)
)
# Out:
# buses         5 ['NW', 'NE', 'Dhaka', 'SW', 'CTG']
# generators    38
# lines         6
# loads         5
# storage units 5
#                        bus        carrier        p_nom  marginal_cost
# name
# Gas_NW                  NW            Gas   332.200000           20.0
# Gas_NE                  NE            Gas  2989.800000           20.0
# Gas_Dhaka            Dhaka            Gas  1993.200000           20.0
# Gas_SW                  SW            Gas   332.200000           20.0
# Gas_CTG                CTG            Gas   996.600000           20.0
# Coal_NW                 NW           Coal   828.727024           30.0
# Coal_SW                 SW           Coal  1864.635804           30.0
# Coal_CTG               CTG           Coal  1450.272292           30.0
# Import_NW               NW         Import   491.850000           40.0
# Import_NE               NE         Import   327.900000           40.0
# Import_Dhaka         Dhaka         Import   163.950000           40.0
# Import_SW               SW         Import    54.650000           40.0
# Import_CTG             CTG         Import    54.650000           40.0
# Hydro_NW                NW          Hydro    10.550000            0.0
# Hydro_NE                NE          Hydro    42.200000            0.0
# Hydro_Dhaka          Dhaka          Hydro    10.550000            0.0
# Hydro_SW                SW          Hydro    10.550000            0.0
# Hydro_CTG              CTG          Hydro   137.150000            0.0
# Solar_NW                NW          Solar    78.150426            0.0
# Solar_NE                NE          Solar    58.612819            0.0
# Solar_Dhaka          Dhaka          Solar    97.688032            0.0
# Solar_SW                SW          Solar    58.612819            0.0
# Solar_CTG              CTG          Solar    97.688032            0.0
# Wind_NW                 NW           Wind     2.903377            0.0
# Wind_NE                 NE           Wind     2.903377            0.0
# Wind_Dhaka           Dhaka           Wind     2.903377            0.0
# Wind_SW                 SW           Wind    10.161820            0.0
# Wind_CTG               CTG           Wind    10.161820            0.0
# Load Shedding_NW        NW  Load Shedding   536.550000        10000.0
# Load Shedding_NE        NE  Load Shedding   643.860000        10000.0
# Load Shedding_Dhaka  Dhaka  Load Shedding  2682.750000        10000.0
# Load Shedding_SW        SW  Load Shedding   536.550000        10000.0
# Load Shedding_CTG      CTG  Load Shedding   965.790000        10000.0
# LiquidFuel_NW           NW    Liquid Fuel   399.513000           60.0
# LiquidFuel_NE           NE    Liquid Fuel   479.415600           60.0
# LiquidFuel_Dhaka     Dhaka    Liquid Fuel  1997.565000           60.0
# LiquidFuel_SW           SW    Liquid Fuel   399.513000           60.0
# LiquidFuel_CTG         CTG    Liquid Fuel   719.123400           60.0
#           bus0   bus1   s_nom
# name
# NW-Dhaka    NW  Dhaka  6500.0
# NE-Dhaka    NE  Dhaka  7000.0
# SW-Dhaka    SW  Dhaka  6000.0
# CTG-Dhaka  CTG  Dhaka  5000.0
# NW-SW       NW     SW  3000.0
# NE-CTG      NE    CTG  3000.0
# carrier
# Coal             4143.6
# Gas              6644.0
# Hydro             211.0
# Import           1093.0
# Liquid Fuel      3995.1
# Load Shedding    5365.5
# Solar             390.8
# Wind               29.0
# Name: p_nom, dtype: float64
